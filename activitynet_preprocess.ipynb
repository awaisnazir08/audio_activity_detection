# %%
import ndjson
import json
import os
from audio_extract import extract_audio
import requests

# %%
# !ls
# Out:
# 'Action video labels - 2_14_2025.ndjson'   anet_val.json
#  activitynet_annotations.json		   anet_val_video.txt
#  activitynet_preprocess.ipynb		   rawframes
#  anet_train.json			   split_custom_data.py
#  anet_train_video.txt			   videos

# %%
META_DATA_PATH = 'Action video labels - 2_14_2025.ndjson'
VIDEOS_DIRECTORY = 'videos'
AUDIOS_DIRECTORY = 'Audios'
TIMESTAMP_ANNOTATIONS = 'activitynet_annotations.json'

# %%
len(os.listdir('rawframes'))
# Out:
# 315

# %%
#sample
"""
{
  "video1": {
      "duration_second": 211.53,
      "duration_frame": 6337,
      "annotations": [
          {
              "segment": [
                  30.025882995319815,
                  205.2318595943838
              ],
              "label": "Rock climbing"
          }
      ],
      "feature_frame": 6336,
      "fps": 30.0,
      "rfps": 29.9579255898
  },
"""
# Out:
# '\n{\n  "video1": {\n      "duration_second": 211.53,\n      "duration_frame": 6337,\n      "annotations": [\n          {\n              "segment": [\n                  30.025882995319815,\n                  205.2318595943838\n              ],\n              "label": "Rock climbing"\n          }\n      ],\n      "feature_frame": 6336,\n      "fps": 30.0,\n      "rfps": 29.9579255898\n  },\n'

# %%
activities_to_track = ['crash', 'drift', 'jump', 'spin', 'breakdown', 'stuck']

# %%
processed_data = {}

# %%
def download_video(video_url, video_name, video_path):
    """
    Downloads a video from the given URL and saves it with the specified name in the videos folder.
    
    Args:
        video_url (str): The URL of the video to be downloaded.
        video_name (str): The name of the video file.
        videos_folder (str): The path to the folder where the video will be saved.
    """
    if os.path.exists(video_path):
        print(f"Video '{video_path}' already exists. Skipping download.")
        return
    
    try:
        response = requests.get(video_url, stream=True)
        if response.status_code == 200:
            with open(video_path, 'wb') as file:
                for chunk in response.iter_content(chunk_size=1024):
                    file.write(chunk)
            print(f"Video '{video_name}' downloaded successfully.")
        else:
            print(f"Error downloading video '{video_name}': {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading video '{video_name}': {e}")

# %%
with open (META_DATA_PATH, 'r') as file:
    metadata = ndjson.load(file)
    for item in metadata:
        video_url = item['data_row']['row_data']
        video_name = item['data_row']['external_id']
        if video_name == 'vid_771.mp4':
            continue
        processed_data[video_name[:-4]] = {}
        processed_data[video_name[:-4]]['duration_second'] = item['media_attributes']['frame_count'] / item['media_attributes']['frame_rate']
        processed_data[video_name[:-4]]['duration_frame'] = item['media_attributes']['frame_count']
        processed_data[video_name[:-4]]['annotations'] = []
        
        video_path = os.path.join(VIDEOS_DIRECTORY, video_name)
        download_video(video_url, video_name, video_path)
        
        # audio_name = video_name[:-3] + 'mp3'
        # audio_path = os.path.join(AUDIOS_DIRECTORY, audio_name)
        
        # # video_to_audio(video_path, audio_path)
        # video_frame_rate = item['media_attributes']['frame_rate']
        # frames = item["projects"]["clvksmh1x038b07z80gv75tec"]["labels"][0]["annotations"]["frames"]
        
        # # Loop through and extract frame numbers
        # activities = {}
        # for frame, annotations in frames.items():
        #     frame = int(frame)
        #     classifications = annotations.get("classifications", [])
        #     for classification in classifications:
        #         label_value = classification["value"]
        #         if label_value not in activities_to_track:
        #             continue
        #         if label_value not in activities:
        #             activities[label_value] = []
        #         activities[label_value].append(round(frame / video_frame_rate, 2))
        
        # for key, times_array in activities.items():
        #     times_array.sort()
        #     if (len(times_array) % 2) != 0:
        #         print(video_name)
            
            
        #     for i in range(0, len(times_array), 2):
        #         annotation_item = {}
        #         annotation_item['segment'] = [times_array[i], times_array[i + 1]]
        #         annotation_item['label'] = key
        #         processed_data[video_name[:-4]]['annotations'].append(annotation_item)
# Out:
# Video 'vid_554.mp4' downloaded successfully.
# Video 'vid_555.mp4' downloaded successfully.
# Video 'vid_561.mp4' downloaded successfully.
# Video 'vid_562.mp4' downloaded successfully.
# Video 'vid_563.mp4' downloaded successfully.
# Video 'vid_564.mp4' downloaded successfully.
# Video 'vid_565.mp4' downloaded successfully.
# Video 'vid_566.mp4' downloaded successfully.
# Video 'vid_567.mp4' downloaded successfully.
# Video 'vid_568.mp4' downloaded successfully.
# Video 'vid_569.mp4' downloaded successfully.
# Video 'vid_570.mp4' downloaded successfully.
# Video 'vid_573.mp4' downloaded successfully.
# Video 'vid_574.mp4' downloaded successfully.
# Video 'vid_575.mp4' downloaded successfully.
# Video 'vid_576.mp4' downloaded successfully.
# Video 'vid_577.mp4' downloaded successfully.
# Video 'vid_578.mp4' downloaded successfully.
# Video 'vid_579.mp4' downloaded successfully.
# Video 'vid_580.mp4' downloaded successfully.
# Video 'vid_581.mp4' downloaded successfully.
# Video 'vid_582.mp4' downloaded successfully.
# Video 'vid_583.mp4' downloaded successfully.
# Video 'vid_736.mp4' downloaded successfully.
# Video 'vid_737.mp4' downloaded successfully.
# Video 'vid_738.mp4' downloaded successfully.
# Video 'vid_739.mp4' downloaded successfully.
# Video 'vid_740.mp4' downloaded successfully.
# Video 'vid_741.mp4' downloaded successfully.
# Video 'vid_742.mp4' downloaded successfully.
# Video 'vid_743.mp4' downloaded successfully.
# Video 'vid_744.mp4' downloaded successfully.
# Video 'vid_745.mp4' downloaded successfully.
# Video 'vid_746.mp4' downloaded successfully.
# Video 'vid_747.mp4' downloaded successfully.
# Video 'vid_748.mp4' downloaded successfully.
# Video 'vid_749.mp4' downloaded successfully.
# Video 'vid_750.mp4' downloaded successfully.
# Video 'vid_751.mp4' downloaded successfully.
# Video 'vid_752.mp4' downloaded successfully.
# Video 'vid_753.mp4' downloaded successfully.
# Video 'vid_754.mp4' downloaded successfully.
# Video 'vid_755.mp4' downloaded successfully.
# Video 'vid_756.mp4' downloaded successfully.
# Video 'vid_757.mp4' downloaded successfully.
# Video 'vid_758.mp4' downloaded successfully.
# Video 'vid_759.mp4' downloaded successfully.
# Video 'vid_760.mp4' downloaded successfully.
# Video 'vid_761.mp4' downloaded successfully.
# Video 'vid_762.mp4' downloaded successfully.
# Video 'vid_763.mp4' downloaded successfully.
# Video 'vid_764.mp4' downloaded successfully.
# Video 'vid_765.mp4' downloaded successfully.
# Video 'vid_767.mp4' downloaded successfully.
# Video 'vid_768.mp4' downloaded successfully.
# Video 'vid_769.mp4' downloaded successfully.
# Video 'vid_770.mp4' downloaded successfully.
# Video 'vid_772.mp4' downloaded successfully.
# Video 'vid_773.mp4' downloaded successfully.
# Video 'vid_774.mp4' downloaded successfully.
# Video 'vid_775.mp4' downloaded successfully.
# Video 'vid_776.mp4' downloaded successfully.
# Video 'vid_777.mp4' downloaded successfully.
# Video 'vid_778.mp4' downloaded successfully.
# Video 'vid_779.mp4' downloaded successfully.
# Video 'vid_780.mp4' downloaded successfully.
# Video 'vid_781.mp4' downloaded successfully.
# Video 'vid_782.mp4' downloaded successfully.
# Video 'vid_783.mp4' downloaded successfully.
# Video 'vid_784.mp4' downloaded successfully.
# Video 'vid_590.mp4' downloaded successfully.
# Video 'vid_611.mp4' downloaded successfully.
# Video 'vid_613.mp4' downloaded successfully.
# Video 'vid_645.mp4' downloaded successfully.
# Video 'vid_707.mp4' downloaded successfully.
# Video 'vid_708.mp4' downloaded successfully.
# Video 'vid_709.mp4' downloaded successfully.
# Video 'vid_710.mp4' downloaded successfully.
# Video 'vid_785.mp4' downloaded successfully.
# Video 'vid_786.mp4' downloaded successfully.
# Video 'vid_787.mp4' downloaded successfully.
# Video 'vid_788.mp4' downloaded successfully.
# Video 'vid_789.mp4' downloaded successfully.
# Video 'vid_790.mp4' downloaded successfully.
# Video 'vid_791.mp4' downloaded successfully.
# Video 'vid_792.mp4' downloaded successfully.
# Video 'vid_793.mp4' downloaded successfully.
# Video 'vid_794.mp4' downloaded successfully.
# Video 'vid_795.mp4' downloaded successfully.
# Video 'vid_796.mp4' downloaded successfully.
# Video 'vid_797.mp4' downloaded successfully.
# Video 'vid_798.mp4' downloaded successfully.
# Video 'vid_799.mp4' downloaded successfully.
# Video 'vid_800.mp4' downloaded successfully.
# Video 'vid_801.mp4' downloaded successfully.
# Video 'vid_802.mp4' downloaded successfully.
# Video 'vid_803.mp4' downloaded successfully.
# Video 'vid_804.mp4' downloaded successfully.
# Video 'vid_805.mp4' downloaded successfully.
# Video 'vid_806.mp4' downloaded successfully.
# Video 'vid_807.mp4' downloaded successfully.
# Video 'vid_808.mp4' downloaded successfully.
# Video 'vid_809.mp4' downloaded successfully.
# Video 'vid_810.mp4' downloaded successfully.
# Video 'vid_811.mp4' downloaded successfully.
# Video 'vid_812.mp4' downloaded successfully.
# Video 'vid_813.mp4' downloaded successfully.
# Video 'vid_814.mp4' downloaded successfully.
# Video 'vid_815.mp4' downloaded successfully.
# Video 'vid_816.mp4' downloaded successfully.
# Video 'vid_817.mp4' downloaded successfully.
# Video 'vid_818.mp4' downloaded successfully.
# Video 'vid_819.mp4' downloaded successfully.
# Video 'vid_820.mp4' downloaded successfully.
# Video 'vid_821.mp4' downloaded successfully.
# Video 'vid_822.mp4' downloaded successfully.
# Video 'vid_823.mp4' downloaded successfully.
# Video 'vid_824.mp4' downloaded successfully.
# Video 'vid_825.mp4' downloaded successfully.
# Video 'vid_826.mp4' downloaded successfully.
# Video 'vid_827.mp4' downloaded successfully.
# Video 'vid_828.mp4' downloaded successfully.
# Video 'vid_829.mp4' downloaded successfully.
# Video 'vid_830.mp4' downloaded successfully.
# Video 'vid_831.mp4' downloaded successfully.
# Video 'vid_832.mp4' downloaded successfully.
# Video 'vid_833.mp4' downloaded successfully.
# Video 'vid_834.mp4' downloaded successfully.
# Video 'vid_835.mp4' downloaded successfully.
# Video 'vid_836.mp4' downloaded successfully.
# Video 'vid_837.mp4' downloaded successfully.
# Video 'vid_838.mp4' downloaded successfully.
# Video 'vid_839.mp4' downloaded successfully.
# Video 'vid_840.mp4' downloaded successfully.
# Video 'vid_841.mp4' downloaded successfully.
# Video 'vid_842.mp4' downloaded successfully.
# Video 'vid_843.mp4' downloaded successfully.
# Video 'vid_844.mp4' downloaded successfully.
# Video 'vid_845.mp4' downloaded successfully.
# Video 'vid_846.mp4' downloaded successfully.
# Video 'vid_847.mp4' downloaded successfully.
# Video 'vid_848.mp4' downloaded successfully.
# Video 'vid_849.mp4' downloaded successfully.
# Video 'vid_850.mp4' downloaded successfully.
# Video 'vid_851.mp4' downloaded successfully.
# Video 'vid_852.mp4' downloaded successfully.
# Video 'vid_853.mp4' downloaded successfully.
# Video 'vid_854.mp4' downloaded successfully.
# Video 'vid_855.mp4' downloaded successfully.
# Video 'vid_856.mp4' downloaded successfully.
# Video 'vid_857.mp4' downloaded successfully.
# Video 'vid_858.mp4' downloaded successfully.
# Video 'vid_859.mp4' downloaded successfully.
# Video 'vid_860.mp4' downloaded successfully.
# Video 'vid_861.mp4' downloaded successfully.
# Video 'vid_862.mp4' downloaded successfully.
# Video 'vid_863.mp4' downloaded successfully.
# Video 'vid_864.mp4' downloaded successfully.
# Video 'vid_865.mp4' downloaded successfully.
# Video 'vid_866.mp4' downloaded successfully.
# Video 'vid_867.mp4' downloaded successfully.
# Video 'vid_868.mp4' downloaded successfully.
# Video 'vid_869.mp4' downloaded successfully.
# Video 'vid_870.mp4' downloaded successfully.
# Video 'vid_871.mp4' downloaded successfully.
# Video 'vid_872.mp4' downloaded successfully.
# Video 'vid_873.mp4' downloaded successfully.
# Video 'vid_874.mp4' downloaded successfully.
# Video 'vid_875.mp4' downloaded successfully.
# Video 'vid_876.mp4' downloaded successfully.
# Video 'vid_877.mp4' downloaded successfully.
# Video 'vid_878.mp4' downloaded successfully.
# Video 'vid_879.mp4' downloaded successfully.
# Video 'vid_880.mp4' downloaded successfully.
# Video 'vid_881.mp4' downloaded successfully.
# Video 'vid_882.mp4' downloaded successfully.
# Video 'vid_883.mp4' downloaded successfully.
# Video 'vid_884.mp4' downloaded successfully.
# Video 'vid_885.mp4' downloaded successfully.
# Video 'vid_886.mp4' downloaded successfully.
# Video 'vid_887.mp4' downloaded successfully.
# Video 'vid_888.mp4' downloaded successfully.
# Video 'vid_889.mp4' downloaded successfully.
# Video 'vid_890.mp4' downloaded successfully.
# Video 'vid_891.mp4' downloaded successfully.
# Video 'vid_892.mp4' downloaded successfully.
# Video 'vid_893.mp4' downloaded successfully.
# Video 'vid_894.mp4' downloaded successfully.
# Video 'vid_895.mp4' downloaded successfully.
# Video 'vid_896.mp4' downloaded successfully.
# Video 'vid_897.mp4' downloaded successfully.
# Video 'vid_898.mp4' downloaded successfully.
# Video 'vid_899.mp4' downloaded successfully.
# Video 'vid_900.mp4' downloaded successfully.
# Video 'vid_901.mp4' downloaded successfully.
# Video 'vid_902.mp4' downloaded successfully.
# Video 'vid_903.mp4' downloaded successfully.
# Video 'vid_904.mp4' downloaded successfully.
# Video 'vid_905.mp4' downloaded successfully.
# Video 'vid_906.mp4' downloaded successfully.
# Video 'vid_907.mp4' downloaded successfully.
# Video 'vid_908.mp4' downloaded successfully.
# Video 'vid_909.mp4' downloaded successfully.
# Video 'vid_910.mp4' downloaded successfully.
# Video 'vid_911.mp4' downloaded successfully.
# Video 'vid_912.mp4' downloaded successfully.
# Video 'vid_913.mp4' downloaded successfully.
# Video 'vid_914.mp4' downloaded successfully.
# Video 'vid_915.mp4' downloaded successfully.
# Video 'vid_916.mp4' downloaded successfully.
# Video 'vid_917.mp4' downloaded successfully.
# Video 'vid_918.mp4' downloaded successfully.
# Video 'vid_919.mp4' downloaded successfully.
# Video 'vid_920.mp4' downloaded successfully.
# Video 'vid_921.mp4' downloaded successfully.
# Video 'vid_922.mp4' downloaded successfully.
# Video 'vid_923.mp4' downloaded successfully.
# Video 'vid_924.mp4' downloaded successfully.
# Video 'vid_925.mp4' downloaded successfully.
# Video 'vid_926.mp4' downloaded successfully.
# Video 'vid_927.mp4' downloaded successfully.
# Video 'vid_928.mp4' downloaded successfully.
# Video 'vid_929.mp4' downloaded successfully.
# Video 'vid_930.mp4' downloaded successfully.
# Video 'vid_931.mp4' downloaded successfully.
# Video 'vid_932.mp4' downloaded successfully.
# Video 'vid_933.mp4' downloaded successfully.
# Video 'vid_934.mp4' downloaded successfully.
# Video 'vid_935.mp4' downloaded successfully.
# Video 'vid_936.mp4' downloaded successfully.
# Video 'vid_937.mp4' downloaded successfully.
# Video 'vid_938.mp4' downloaded successfully.
# Video 'vid_939.mp4' downloaded successfully.
# Video 'vid_940.mp4' downloaded successfully.
# Video 'vid_941.mp4' downloaded successfully.
# Video 'vid_942.mp4' downloaded successfully.
# Video 'vid_943.mp4' downloaded successfully.
# Video 'vid_944.mp4' downloaded successfully.
# Video 'vid_945.mp4' downloaded successfully.
# Video 'vid_946.mp4' downloaded successfully.
# Video 'vid_947.mp4' downloaded successfully.
# Video 'vid_948.mp4' downloaded successfully.
# Video 'vid_949.mp4' downloaded successfully.
# Video 'vid_950.mp4' downloaded successfully.
# Video 'vid_951.mp4' downloaded successfully.
# Video 'vid_952.mp4' downloaded successfully.
# Video 'vid_953.mp4' downloaded successfully.
# Video 'vid_954.mp4' downloaded successfully.
# Video 'vid_955.mp4' downloaded successfully.
# Video 'vid_956.mp4' downloaded successfully.
# Video 'vid_957.mp4' downloaded successfully.
# Video 'vid_958.mp4' downloaded successfully.
# Video 'vid_959.mp4' downloaded successfully.
# Video 'vid_960.mp4' downloaded successfully.
# Video 'vid_961.mp4' downloaded successfully.
# Video 'vid_962.mp4' downloaded successfully.
# Video 'vid_963.mp4' downloaded successfully.
# Video 'vid_964.mp4' downloaded successfully.
# Video 'vid_965.mp4' downloaded successfully.
# Video 'vid_966.mp4' downloaded successfully.
# Video 'vid_967.mp4' downloaded successfully.
# Video 'vid_968.mp4' downloaded successfully.
# Video 'vid_969.mp4' downloaded successfully.
# Video 'vid_970.mp4' downloaded successfully.
# Video 'vid_971.mp4' downloaded successfully.
# Video 'vid_972.mp4' downloaded successfully.
# Video 'vid_973.mp4' downloaded successfully.
# Video 'vid_974.mp4' downloaded successfully.
# Video 'vid_975.mp4' downloaded successfully.
# Video 'vid_976.mp4' downloaded successfully.
# Video 'vid_977.mp4' downloaded successfully.
# Video 'vid_978.mp4' downloaded successfully.
# Video 'vid_979.mp4' downloaded successfully.
# Video 'vid_980.mp4' downloaded successfully.
# Video 'vid_981.mp4' downloaded successfully.
# Video 'vid_982.mp4' downloaded successfully.
# Video 'vid_983.mp4' downloaded successfully.
# Video 'vid_984.mp4' downloaded successfully.
# Video 'vid_985.mp4' downloaded successfully.
# Video 'vid_986.mp4' downloaded successfully.
# Video 'vid_987.mp4' downloaded successfully.
# Video 'vid_988.mp4' downloaded successfully.
# Video 'vid_989.mp4' downloaded successfully.
# Video 'vid_990.mp4' downloaded successfully.
# Video 'vid_991.mp4' downloaded successfully.
# Video 'vid_992.mp4' downloaded successfully.
# Video 'vid_993.mp4' downloaded successfully.
# Video 'vid_994.mp4' downloaded successfully.
# Video 'vid_995.mp4' downloaded successfully.
# Video 'vid_996.mp4' downloaded successfully.
# Video 'vid_997.mp4' downloaded successfully.
# Video 'vid_998.mp4' downloaded successfully.
# Video 'vid_999.mp4' downloaded successfully.
# Video 'vid_1000.mp4' downloaded successfully.
# Video 'vid_1001.mp4' downloaded successfully.
# Video 'vid_1002.mp4' downloaded successfully.
# Video 'vid_1003.mp4' downloaded successfully.
# Video 'vid_1004.mp4' downloaded successfully.
# Video 'vid_1005.mp4' downloaded successfully.
# Video 'vid_1006.mp4' downloaded successfully.
# Video 'vid_1007.mp4' downloaded successfully.
# Video 'vid_1008.mp4' downloaded successfully.
# Video 'vid_1009.mp4' downloaded successfully.
# Video 'vid_1010.mp4' downloaded successfully.
# Video 'vid_1011.mp4' downloaded successfully.
# Video 'vid_1012.mp4' downloaded successfully.
# Video 'vid_1013.mp4' downloaded successfully.
# Video 'vid_1014.mp4' downloaded successfully.
# Video 'vid_1015.mp4' downloaded successfully.
# Video 'vid_1016.mp4' downloaded successfully.
# Video 'vid_1017.mp4' downloaded successfully.
# Video 'vid_1018.mp4' downloaded successfully.
# Video 'vid_1019.mp4' downloaded successfully.
# Video 'vid_1020.mp4' downloaded successfully.
# Video 'vid_766.mp4' downloaded successfully.

# %%
processed_data
# Out:
# {'vid_554': {'duration_second': 6.0,
#   'duration_frame': 150,
#   'annotations': [{'segment': [3.36, 4.68], 'label': 'drift'}]},
#  'vid_555': {'duration_second': 3.8,
#   'duration_frame': 95,
#   'annotations': [{'segment': [1.72, 2.0], 'label': 'crash'},
#    {'segment': [1.08, 1.88], 'label': 'jump'},
#    {'segment': [1.72, 2.12], 'label': 'drift'}]},
#  'vid_561': {'duration_second': 3.48, 'duration_frame': 87, 'annotations': []},
#  'vid_562': {'duration_second': 7.32,
#   'duration_frame': 183,
#   'annotations': [{'segment': [0.88, 2.08], 'label': 'drift'},
#    {'segment': [2.64, 4.68], 'label': 'drift'}]},
#  'vid_563': {'duration_second': 3.52,
#   'duration_frame': 88,
#   'annotations': [{'segment': [0.88, 2.0], 'label': 'drift'},
#    {'segment': [1.16, 1.96], 'label': 'jump'},
#    {'segment': [1.4, 2.08], 'label': 'crash'}]},
#  'vid_564': {'duration_second': 8.0,
#   'duration_frame': 200,
#   'annotations': [{'segment': [1.52, 2.36], 'label': 'jump'}]},
#  'vid_565': {'duration_second': 8.6,
#   'duration_frame': 215,
#   'annotations': [{'segment': [1.44, 2.44], 'label': 'spin'}]},
#  'vid_566': {'duration_second': 5.68,
#   'duration_frame': 142,
#   'annotations': [{'segment': [0.88, 2.64], 'label': 'spin'}]},
#  'vid_567': {'duration_second': 11.24,
#   'duration_frame': 281,
#   'annotations': [{'segment': [5.96, 7.24], 'label': 'spin'}]},
#  'vid_568': {'duration_second': 12.2,
#   'duration_frame': 305,
#   'annotations': [{'segment': [0.96, 2.32], 'label': 'spin'}]},
#  'vid_569': {'duration_second': 9.36,
#   'duration_frame': 234,
#   'annotations': []},
#  'vid_570': {'duration_second': 9.56,
#   'duration_frame': 239,
#   'annotations': []},
#  'vid_573': {'duration_second': 8.2,
#   'duration_frame': 205,
#   'annotations': [{'segment': [1.16, 1.72], 'label': 'jump'}]},
#  'vid_574': {'duration_second': 17.68,
#   'duration_frame': 442,
#   'annotations': [{'segment': [3.32, 5.48], 'label': 'spin'}]},
#  'vid_575': {'duration_second': 11.44,
#   'duration_frame': 286,
#   'annotations': [{'segment': [1.36, 2.48], 'label': 'jump'}]},
#  'vid_576': {'duration_second': 5.48,
#   'duration_frame': 137,
#   'annotations': [{'segment': [1.2, 1.68], 'label': 'jump'}]},
#  'vid_577': {'duration_second': 9.08,
#   'duration_frame': 227,
#   'annotations': [{'segment': [1.68, 2.16], 'label': 'jump'}]},
#  'vid_578': {'duration_second': 8.24,
#   'duration_frame': 206,
#   'annotations': [{'segment': [1.56, 2.44], 'label': 'jump'}]},
#  'vid_579': {'duration_second': 10.0,
#   'duration_frame': 250,
#   'annotations': [{'segment': [5.88, 6.28], 'label': 'drift'}]},
#  'vid_580': {'duration_second': 10.0,
#   'duration_frame': 250,
#   'annotations': [{'segment': [0.96, 1.84], 'label': 'spin'},
#    {'segment': [4.44, 5.28], 'label': 'drift'}]},
#  'vid_581': {'duration_second': 12.28,
#   'duration_frame': 307,
#   'annotations': [{'segment': [6.4, 6.88], 'label': 'drift'}]},
#  'vid_582': {'duration_second': 5.72,
#   'duration_frame': 143,
#   'annotations': []},
#  'vid_583': {'duration_second': 7.6,
#   'duration_frame': 190,
#   'annotations': [{'segment': [1.24, 2.08], 'label': 'spin'}]},
#  'vid_736': {'duration_second': 11.52,
#   'duration_frame': 288,
#   'annotations': [{'segment': [2.72, 4.84], 'label': 'drift'},
#    {'segment': [5.48, 7.08], 'label': 'crash'},
#    {'segment': [4.88, 7.28], 'label': 'spin'}]},
#  'vid_737': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [2.76, 3.92], 'label': 'spin'}]},
#  'vid_738': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [0.8, 1.64], 'label': 'drift'},
#    {'segment': [1.64, 3.16], 'label': 'spin'}]},
#  'vid_739': {'duration_second': 6.72,
#   'duration_frame': 168,
#   'annotations': []},
#  'vid_740': {'duration_second': 4.56,
#   'duration_frame': 114,
#   'annotations': [{'segment': [0.44, 1.52], 'label': 'drift'},
#    {'segment': [1.32, 3.2], 'label': 'crash'}]},
#  'vid_741': {'duration_second': 8.16,
#   'duration_frame': 204,
#   'annotations': [{'segment': [3.4, 4.36], 'label': 'crash'}]},
#  'vid_742': {'duration_second': 20.04,
#   'duration_frame': 501,
#   'annotations': [{'segment': [9.52, 11.16], 'label': 'drift'},
#    {'segment': [1.44, 3.04], 'label': 'crash'},
#    {'segment': [11.64, 17.96], 'label': 'crash'},
#    {'segment': [0.88, 1.36], 'label': 'spin'},
#    {'segment': [10.28, 11.44], 'label': 'spin'}]},
#  'vid_743': {'duration_second': 8.72,
#   'duration_frame': 218,
#   'annotations': [{'segment': [2.36, 3.44], 'label': 'drift'},
#    {'segment': [3.48, 4.16], 'label': 'spin'},
#    {'segment': [4.2, 5.12], 'label': 'crash'}]},
#  'vid_744': {'duration_second': 10.24,
#   'duration_frame': 256,
#   'annotations': [{'segment': [1.36, 3.48], 'label': 'drift'},
#    {'segment': [3.52, 5.76], 'label': 'spin'}]},
#  'vid_745': {'duration_second': 17.12,
#   'duration_frame': 428,
#   'annotations': []},
#  'vid_746': {'duration_second': 13.96,
#   'duration_frame': 349,
#   'annotations': [{'segment': [5.88, 6.88], 'label': 'crash'}]},
#  'vid_747': {'duration_second': 12.72,
#   'duration_frame': 318,
#   'annotations': [{'segment': [3.4, 5.24], 'label': 'drift'},
#    {'segment': [5.28, 7.32], 'label': 'crash'},
#    {'segment': [5.52, 7.24], 'label': 'spin'}]},
#  'vid_748': {'duration_second': 6.04,
#   'duration_frame': 151,
#   'annotations': [{'segment': [2.92, 3.4], 'label': 'crash'}]},
#  'vid_749': {'duration_second': 10.64,
#   'duration_frame': 266,
#   'annotations': [{'segment': [5.28, 5.48], 'label': 'crash'},
#    {'segment': [7.6, 10.32], 'label': 'drift'}]},
#  'vid_750': {'duration_second': 6.88,
#   'duration_frame': 172,
#   'annotations': [{'segment': [0.6, 2.24], 'label': 'crash'}]},
#  'vid_751': {'duration_second': 9.84,
#   'duration_frame': 246,
#   'annotations': [{'segment': [4.12, 5.88], 'label': 'drift'}]},
#  'vid_752': {'duration_second': 6.84,
#   'duration_frame': 171,
#   'annotations': [{'segment': [3.24, 4.64], 'label': 'crash'}]},
#  'vid_753': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': [{'segment': [4.52, 6.2], 'label': 'crash'}]},
#  'vid_754': {'duration_second': 8.48,
#   'duration_frame': 212,
#   'annotations': [{'segment': [3.04, 4.0], 'label': 'drift'},
#    {'segment': [3.56, 4.32], 'label': 'spin'}]},
#  'vid_755': {'duration_second': 11.0,
#   'duration_frame': 275,
#   'annotations': []},
#  'vid_756': {'duration_second': 4.88,
#   'duration_frame': 122,
#   'annotations': [{'segment': [1.84, 2.8], 'label': 'crash'}]},
#  'vid_757': {'duration_second': 15.2,
#   'duration_frame': 380,
#   'annotations': [{'segment': [11.84, 13.0], 'label': 'crash'}]},
#  'vid_758': {'duration_second': 7.4,
#   'duration_frame': 185,
#   'annotations': [{'segment': [4.2, 5.4], 'label': 'crash'},
#    {'segment': [2.96, 4.16], 'label': 'spin'}]},
#  'vid_759': {'duration_second': 10.04,
#   'duration_frame': 251,
#   'annotations': [{'segment': [0.04, 5.16], 'label': 'drift'},
#    {'segment': [3.12, 7.76], 'label': 'spin'}]},
#  'vid_760': {'duration_second': 11.52,
#   'duration_frame': 288,
#   'annotations': [{'segment': [7.04, 8.08], 'label': 'spin'}]},
#  'vid_761': {'duration_second': 9.6,
#   'duration_frame': 240,
#   'annotations': [{'segment': [5.68, 6.08], 'label': 'crash'}]},
#  'vid_762': {'duration_second': 6.96,
#   'duration_frame': 174,
#   'annotations': [{'segment': [1.0, 2.08], 'label': 'spin'},
#    {'segment': [2.48, 3.76], 'label': 'spin'}]},
#  'vid_763': {'duration_second': 8.72,
#   'duration_frame': 218,
#   'annotations': [{'segment': [5.4, 6.56], 'label': 'spin'}]},
#  'vid_764': {'duration_second': 9.12,
#   'duration_frame': 228,
#   'annotations': [{'segment': [4.8, 6.08], 'label': 'crash'}]},
#  'vid_765': {'duration_second': 11.48,
#   'duration_frame': 287,
#   'annotations': [{'segment': [4.8, 5.6], 'label': 'crash'}]},
#  'vid_767': {'duration_second': 9.32,
#   'duration_frame': 233,
#   'annotations': [{'segment': [5.28, 5.84], 'label': 'crash'}]},
#  'vid_768': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': [{'segment': [5.72, 6.44], 'label': 'crash'}]},
#  'vid_769': {'duration_second': 4.92,
#   'duration_frame': 123,
#   'annotations': [{'segment': [1.2, 2.28], 'label': 'crash'},
#    {'segment': [0.8, 1.16], 'label': 'spin'}]},
#  'vid_770': {'duration_second': 15.6,
#   'duration_frame': 390,
#   'annotations': [{'segment': [3.2, 5.04], 'label': 'spin'},
#    {'segment': [5.92, 9.88], 'label': 'spin'},
#    {'segment': [3.64, 5.88], 'label': 'drift'},
#    {'segment': [10.08, 10.96], 'label': 'crash'}]},
#  'vid_772': {'duration_second': 11.76,
#   'duration_frame': 294,
#   'annotations': [{'segment': [1.04, 1.76], 'label': 'spin'},
#    {'segment': [1.76, 2.48], 'label': 'crash'},
#    {'segment': [8.08, 8.76], 'label': 'crash'},
#    {'segment': [6.56, 8.04], 'label': 'drift'}]},
#  'vid_773': {'duration_second': 4.72,
#   'duration_frame': 118,
#   'annotations': [{'segment': [1.56, 2.4], 'label': 'crash'}]},
#  'vid_774': {'duration_second': 12.36,
#   'duration_frame': 309,
#   'annotations': [{'segment': [7.32, 11.96], 'label': 'crash'}]},
#  'vid_775': {'duration_second': 10.64,
#   'duration_frame': 266,
#   'annotations': [{'segment': [3.32, 4.52], 'label': 'drift'},
#    {'segment': [4.56, 5.6], 'label': 'crash'}]},
#  'vid_776': {'duration_second': 8.32,
#   'duration_frame': 208,
#   'annotations': [{'segment': [4.44, 5.48], 'label': 'spin'}]},
#  'vid_777': {'duration_second': 10.12,
#   'duration_frame': 253,
#   'annotations': [{'segment': [2.04, 3.24], 'label': 'crash'}]},
#  'vid_778': {'duration_second': 12.16,
#   'duration_frame': 304,
#   'annotations': [{'segment': [1.72, 2.16], 'label': 'crash'}]},
#  'vid_779': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [2.16, 2.8], 'label': 'crash'}]},
#  'vid_780': {'duration_second': 7.76,
#   'duration_frame': 194,
#   'annotations': [{'segment': [0.04, 1.96], 'label': 'drift'}]},
#  'vid_781': {'duration_second': 5.28,
#   'duration_frame': 132,
#   'annotations': [{'segment': [1.12, 2.68], 'label': 'spin'},
#    {'segment': [2.72, 3.48], 'label': 'crash'}]},
#  'vid_782': {'duration_second': 2.8, 'duration_frame': 70, 'annotations': []},
#  'vid_783': {'duration_second': 8.6,
#   'duration_frame': 215,
#   'annotations': [{'segment': [4.76, 5.88], 'label': 'crash'}]},
#  'vid_784': {'duration_second': 4.84,
#   'duration_frame': 121,
#   'annotations': [{'segment': [0.68, 2.48], 'label': 'spin'}]},
#  'vid_590': {'duration_second': 11.733333333333333,
#   'duration_frame': 352,
#   'annotations': [{'segment': [6.5, 8.57], 'label': 'drift'}]},
#  'vid_611': {'duration_second': 5.88,
#   'duration_frame': 147,
#   'annotations': [{'segment': [1.68, 3.52], 'label': 'spin'}]},
#  'vid_613': {'duration_second': 9.2,
#   'duration_frame': 276,
#   'annotations': [{'segment': [6.27, 8.27], 'label': 'drift'},
#    {'segment': [5.83, 6.77], 'label': 'spin'}]},
#  'vid_645': {'duration_second': 10.733333333333333,
#   'duration_frame': 322,
#   'annotations': [{'segment': [6.1, 8.67], 'label': 'drift'}]},
#  'vid_707': {'duration_second': 7.766666666666667,
#   'duration_frame': 233,
#   'annotations': [{'segment': [2.57, 3.57], 'label': 'spin'},
#    {'segment': [3.6, 6.03], 'label': 'drift'}]},
#  'vid_708': {'duration_second': 8.666666666666666,
#   'duration_frame': 260,
#   'annotations': [{'segment': [4.07, 5.83], 'label': 'drift'},
#    {'segment': [4.07, 5.83], 'label': 'spin'}]},
#  'vid_709': {'duration_second': 8.066666666666666,
#   'duration_frame': 242,
#   'annotations': [{'segment': [3.7, 5.87], 'label': 'drift'}]},
#  'vid_710': {'duration_second': 10.033333333333333,
#   'duration_frame': 301,
#   'annotations': [{'segment': [5.73, 6.97], 'label': 'drift'}]},
#  'vid_785': {'duration_second': 9.08,
#   'duration_frame': 227,
#   'annotations': [{'segment': [1.16, 2.48], 'label': 'jump'},
#    {'segment': [7.32, 8.16], 'label': 'drift'}]},
#  'vid_786': {'duration_second': 4.44,
#   'duration_frame': 111,
#   'annotations': [{'segment': [0.96, 2.04], 'label': 'jump'}]},
#  'vid_787': {'duration_second': 11.8,
#   'duration_frame': 295,
#   'annotations': [{'segment': [1.68, 2.48], 'label': 'jump'},
#    {'segment': [4.96, 6.2], 'label': 'drift'}]},
#  'vid_788': {'duration_second': 8.64,
#   'duration_frame': 216,
#   'annotations': [{'segment': [1.16, 1.88], 'label': 'jump'},
#    {'segment': [1.92, 3.04], 'label': 'spin'},
#    {'segment': [4.56, 5.48], 'label': 'spin'},
#    {'segment': [3.08, 4.52], 'label': 'drift'}]},
#  'vid_789': {'duration_second': 5.64,
#   'duration_frame': 141,
#   'annotations': [{'segment': [0.64, 1.52], 'label': 'jump'}]},
#  'vid_790': {'duration_second': 6.16,
#   'duration_frame': 154,
#   'annotations': [{'segment': [1.48, 2.84], 'label': 'jump'}]},
#  'vid_791': {'duration_second': 4.52,
#   'duration_frame': 113,
#   'annotations': [{'segment': [1.04, 2.04], 'label': 'jump'},
#    {'segment': [2.08, 2.88], 'label': 'drift'}]},
#  'vid_792': {'duration_second': 9.12,
#   'duration_frame': 228,
#   'annotations': [{'segment': [4.6, 5.72], 'label': 'jump'}]},
#  'vid_793': {'duration_second': 6.08,
#   'duration_frame': 152,
#   'annotations': [{'segment': [0.8, 2.04], 'label': 'jump'}]},
#  'vid_794': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [0.84, 1.88], 'label': 'jump'}]},
#  'vid_795': {'duration_second': 8.52,
#   'duration_frame': 213,
#   'annotations': [{'segment': [1.96, 2.96], 'label': 'jump'},
#    {'segment': [3.76, 4.36], 'label': 'jump'},
#    {'segment': [5.52, 6.16], 'label': 'jump'},
#    {'segment': [4.4, 4.84], 'label': 'drift'},
#    {'segment': [4.88, 5.48], 'label': 'spin'}]},
#  'vid_796': {'duration_second': 6.12,
#   'duration_frame': 153,
#   'annotations': [{'segment': [0.92, 2.28], 'label': 'jump'}]},
#  'vid_797': {'duration_second': 7.68,
#   'duration_frame': 192,
#   'annotations': [{'segment': [1.2, 2.24], 'label': 'jump'},
#    {'segment': [2.96, 3.8], 'label': 'jump'}]},
#  'vid_798': {'duration_second': 6.96,
#   'duration_frame': 174,
#   'annotations': [{'segment': [0.96, 1.84], 'label': 'jump'},
#    {'segment': [4.76, 5.64], 'label': 'drift'}]},
#  'vid_799': {'duration_second': 6.68,
#   'duration_frame': 167,
#   'annotations': [{'segment': [1.36, 2.72], 'label': 'jump'}]},
#  'vid_800': {'duration_second': 7.92,
#   'duration_frame': 198,
#   'annotations': [{'segment': [1.24, 2.44], 'label': 'spin'},
#    {'segment': [4.68, 5.44], 'label': 'spin'},
#    {'segment': [1.8, 2.48], 'label': 'jump'},
#    {'segment': [3.16, 4.28], 'label': 'drift'}]},
#  'vid_801': {'duration_second': 10.16,
#   'duration_frame': 254,
#   'annotations': [{'segment': [2.36, 3.24], 'label': 'jump'}]},
#  'vid_802': {'duration_second': 9.72,
#   'duration_frame': 243,
#   'annotations': [{'segment': [1.16, 2.0], 'label': 'jump'},
#    {'segment': [2.52, 3.64], 'label': 'jump'}]},
#  'vid_803': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [1.12, 1.88], 'label': 'jump'}]},
#  'vid_804': {'duration_second': 12.2,
#   'duration_frame': 305,
#   'annotations': [{'segment': [2.24, 3.16], 'label': 'jump'},
#    {'segment': [3.2, 4.08], 'label': 'crash'}]},
#  'vid_805': {'duration_second': 9.32,
#   'duration_frame': 233,
#   'annotations': [{'segment': [7.0, 8.2], 'label': 'drift'},
#    {'segment': [1.32, 2.56], 'label': 'jump'}]},
#  'vid_806': {'duration_second': 5.44,
#   'duration_frame': 136,
#   'annotations': [{'segment': [1.44, 2.56], 'label': 'jump'}]},
#  'vid_807': {'duration_second': 12.92,
#   'duration_frame': 323,
#   'annotations': [{'segment': [1.52, 2.4], 'label': 'jump'}]},
#  'vid_808': {'duration_second': 8.2,
#   'duration_frame': 205,
#   'annotations': [{'segment': [1.16, 1.96], 'label': 'jump'},
#    {'segment': [4.48, 6.64], 'label': 'jump'},
#    {'segment': [2.04, 2.6], 'label': 'drift'}]},
#  'vid_809': {'duration_second': 8.52,
#   'duration_frame': 213,
#   'annotations': [{'segment': [2.36, 3.24], 'label': 'jump'},
#    {'segment': [4.64, 5.88], 'label': 'drift'}]},
#  'vid_810': {'duration_second': 5.28,
#   'duration_frame': 132,
#   'annotations': [{'segment': [2.36, 3.08], 'label': 'jump'},
#    {'segment': [3.16, 4.04], 'label': 'drift'}]},
#  'vid_811': {'duration_second': 5.56,
#   'duration_frame': 139,
#   'annotations': [{'segment': [1.12, 2.28], 'label': 'jump'}]},
#  'vid_812': {'duration_second': 9.64,
#   'duration_frame': 241,
#   'annotations': [{'segment': [1.04, 1.64], 'label': 'jump'},
#    {'segment': [4.48, 4.96], 'label': 'drift'},
#    {'segment': [5.0, 5.48], 'label': 'spin'}]},
#  'vid_813': {'duration_second': 7.84,
#   'duration_frame': 196,
#   'annotations': [{'segment': [0.8, 1.48], 'label': 'jump'}]},
#  'vid_814': {'duration_second': 5.72,
#   'duration_frame': 143,
#   'annotations': [{'segment': [0.88, 1.76], 'label': 'jump'},
#    {'segment': [1.8, 2.8], 'label': 'drift'}]},
#  'vid_815': {'duration_second': 5.48,
#   'duration_frame': 137,
#   'annotations': [{'segment': [0.88, 1.76], 'label': 'jump'}]},
#  'vid_816': {'duration_second': 9.48,
#   'duration_frame': 237,
#   'annotations': [{'segment': [1.92, 2.84], 'label': 'jump'}]},
#  'vid_817': {'duration_second': 6.8,
#   'duration_frame': 170,
#   'annotations': [{'segment': [0.92, 2.0], 'label': 'jump'}]},
#  'vid_818': {'duration_second': 10.4,
#   'duration_frame': 312,
#   'annotations': [{'segment': [3.27, 4.1], 'label': 'drift'},
#    {'segment': [6.73, 8.13], 'label': 'spin'}]},
#  'vid_819': {'duration_second': 9.4,
#   'duration_frame': 235,
#   'annotations': [{'segment': [1.12, 2.24], 'label': 'jump'},
#    {'segment': [4.76, 6.16], 'label': 'spin'}]},
#  'vid_820': {'duration_second': 7.72,
#   'duration_frame': 193,
#   'annotations': [{'segment': [1.08, 2.32], 'label': 'jump'}]},
#  'vid_821': {'duration_second': 8.64,
#   'duration_frame': 216,
#   'annotations': [{'segment': [1.44, 2.48], 'label': 'jump'},
#    {'segment': [4.4, 5.2], 'label': 'jump'}]},
#  'vid_822': {'duration_second': 7.64,
#   'duration_frame': 191,
#   'annotations': [{'segment': [1.08, 1.92], 'label': 'jump'}]},
#  'vid_823': {'duration_second': 10.36,
#   'duration_frame': 259,
#   'annotations': [{'segment': [1.0, 2.08], 'label': 'jump'},
#    {'segment': [2.12, 2.6], 'label': 'spin'}]},
#  'vid_824': {'duration_second': 6.52,
#   'duration_frame': 163,
#   'annotations': [{'segment': [0.88, 1.76], 'label': 'jump'}]},
#  'vid_825': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': [{'segment': [1.0, 1.8], 'label': 'jump'},
#    {'segment': [7.0, 7.72], 'label': 'jump'},
#    {'segment': [4.24, 5.52], 'label': 'drift'}]},
#  'vid_826': {'duration_second': 8.68,
#   'duration_frame': 217,
#   'annotations': [{'segment': [2.6, 3.28], 'label': 'jump'}]},
#  'vid_827': {'duration_second': 12.56,
#   'duration_frame': 314,
#   'annotations': [{'segment': [1.84, 2.72], 'label': 'jump'}]},
#  'vid_828': {'duration_second': 4.88,
#   'duration_frame': 122,
#   'annotations': [{'segment': [0.84, 1.84], 'label': 'jump'}]},
#  'vid_829': {'duration_second': 5.96,
#   'duration_frame': 149,
#   'annotations': [{'segment': [1.8, 2.76], 'label': 'jump'}]},
#  'vid_830': {'duration_second': 10.24,
#   'duration_frame': 256,
#   'annotations': [{'segment': [1.24, 2.12], 'label': 'jump'}]},
#  'vid_831': {'duration_second': 6.4,
#   'duration_frame': 160,
#   'annotations': [{'segment': [1.08, 1.88], 'label': 'jump'}]},
#  'vid_832': {'duration_second': 11.0,
#   'duration_frame': 275,
#   'annotations': [{'segment': [3.52, 4.72], 'label': 'jump'},
#    {'segment': [4.76, 5.2], 'label': 'spin'},
#    {'segment': [5.24, 6.72], 'label': 'drift'}]},
#  'vid_833': {'duration_second': 8.4,
#   'duration_frame': 210,
#   'annotations': [{'segment': [3.04, 3.92], 'label': 'jump'}]},
#  'vid_834': {'duration_second': 6.88,
#   'duration_frame': 172,
#   'annotations': [{'segment': [1.48, 2.24], 'label': 'jump'},
#    {'segment': [3.24, 4.92], 'label': 'spin'}]},
#  'vid_835': {'duration_second': 6.2,
#   'duration_frame': 155,
#   'annotations': [{'segment': [1.28, 2.12], 'label': 'jump'}]},
#  'vid_836': {'duration_second': 3.96,
#   'duration_frame': 99,
#   'annotations': [{'segment': [1.08, 2.12], 'label': 'jump'}]},
#  'vid_837': {'duration_second': 5.16,
#   'duration_frame': 129,
#   'annotations': [{'segment': [1.12, 2.08], 'label': 'jump'}]},
#  'vid_838': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': [{'segment': [4.92, 5.68], 'label': 'jump'},
#    {'segment': [5.72, 6.16], 'label': 'drift'},
#    {'segment': [6.2, 7.0], 'label': 'spin'},
#    {'segment': [8.16, 8.88], 'label': 'spin'}]},
#  'vid_839': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': [{'segment': [1.32, 2.24], 'label': 'jump'},
#    {'segment': [4.8, 5.8], 'label': 'jump'},
#    {'segment': [2.28, 3.44], 'label': 'drift'},
#    {'segment': [5.84, 6.36], 'label': 'drift'}]},
#  'vid_840': {'duration_second': 8.32,
#   'duration_frame': 208,
#   'annotations': [{'segment': [1.76, 2.72], 'label': 'jump'}]},
#  'vid_841': {'duration_second': 9.52,
#   'duration_frame': 238,
#   'annotations': [{'segment': [1.32, 2.76], 'label': 'jump'}]},
#  'vid_842': {'duration_second': 7.2,
#   'duration_frame': 180,
#   'annotations': [{'segment': [1.88, 2.92], 'label': 'jump'}]},
#  'vid_843': {'duration_second': 7.56,
#   'duration_frame': 189,
#   'annotations': [{'segment': [1.08, 2.04], 'label': 'jump'}]},
#  'vid_844': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [0.52, 1.76], 'label': 'jump'}]},
#  'vid_845': {'duration_second': 7.88,
#   'duration_frame': 197,
#   'annotations': [{'segment': [1.56, 2.92], 'label': 'jump'}]},
#  'vid_846': {'duration_second': 6.8,
#   'duration_frame': 170,
#   'annotations': [{'segment': [1.56, 2.48], 'label': 'jump'}]},
#  'vid_847': {'duration_second': 5.56,
#   'duration_frame': 139,
#   'annotations': [{'segment': [0.44, 1.68], 'label': 'jump'}]},
#  'vid_848': {'duration_second': 9.2,
#   'duration_frame': 230,
#   'annotations': [{'segment': [1.08, 1.8], 'label': 'jump'}]},
#  'vid_849': {'duration_second': 7.52,
#   'duration_frame': 188,
#   'annotations': [{'segment': [1.68, 2.72], 'label': 'jump'},
#    {'segment': [3.4, 4.6], 'label': 'drift'}]},
#  'vid_850': {'duration_second': 6.64,
#   'duration_frame': 166,
#   'annotations': [{'segment': [1.4, 2.08], 'label': 'jump'},
#    {'segment': [2.12, 3.04], 'label': 'spin'},
#    {'segment': [4.52, 5.6], 'label': 'spin'},
#    {'segment': [3.68, 4.48], 'label': 'drift'}]},
#  'vid_851': {'duration_second': 6.96,
#   'duration_frame': 174,
#   'annotations': [{'segment': [1.8, 2.8], 'label': 'jump'},
#    {'segment': [3.84, 4.36], 'label': 'drift'}]},
#  'vid_852': {'duration_second': 6.4,
#   'duration_frame': 160,
#   'annotations': [{'segment': [1.88, 2.84], 'label': 'jump'}]},
#  'vid_853': {'duration_second': 9.32,
#   'duration_frame': 233,
#   'annotations': [{'segment': [0.36, 1.36], 'label': 'jump'}]},
#  'vid_854': {'duration_second': 12.24,
#   'duration_frame': 306,
#   'annotations': [{'segment': [1.4, 2.72], 'label': 'jump'},
#    {'segment': [2.76, 4.56], 'label': 'spin'},
#    {'segment': [9.92, 11.4], 'label': 'spin'},
#    {'segment': [7.56, 8.84], 'label': 'drift'}]},
#  'vid_855': {'duration_second': 5.64,
#   'duration_frame': 141,
#   'annotations': [{'segment': [0.64, 1.68], 'label': 'jump'},
#    {'segment': [5.2, 5.64], 'label': 'drift'}]},
#  'vid_856': {'duration_second': 3.08,
#   'duration_frame': 77,
#   'annotations': [{'segment': [0.32, 1.08], 'label': 'jump'}]},
#  'vid_857': {'duration_second': 6.8,
#   'duration_frame': 170,
#   'annotations': [{'segment': [1.68, 2.68], 'label': 'jump'},
#    {'segment': [2.72, 3.6], 'label': 'drift'}]},
#  'vid_858': {'duration_second': 11.08,
#   'duration_frame': 277,
#   'annotations': [{'segment': [1.28, 2.08], 'label': 'jump'},
#    {'segment': [2.12, 3.52], 'label': 'spin'},
#    {'segment': [4.64, 5.48], 'label': 'spin'}]},
#  'vid_859': {'duration_second': 8.16,
#   'duration_frame': 204,
#   'annotations': [{'segment': [1.68, 2.56], 'label': 'jump'},
#    {'segment': [5.16, 5.8], 'label': 'jump'}]},
#  'vid_860': {'duration_second': 8.72,
#   'duration_frame': 218,
#   'annotations': [{'segment': [1.36, 2.48], 'label': 'jump'}]},
#  'vid_861': {'duration_second': 6.56,
#   'duration_frame': 164,
#   'annotations': [{'segment': [1.12, 2.44], 'label': 'jump'}]},
#  'vid_862': {'duration_second': 9.08,
#   'duration_frame': 227,
#   'annotations': [{'segment': [1.36, 2.56], 'label': 'jump'},
#    {'segment': [4.72, 6.04], 'label': 'jump'}]},
#  'vid_863': {'duration_second': 8.92,
#   'duration_frame': 223,
#   'annotations': [{'segment': [3.48, 4.32], 'label': 'jump'},
#    {'segment': [5.72, 6.92], 'label': 'jump'}]},
#  'vid_864': {'duration_second': 6.6,
#   'duration_frame': 165,
#   'annotations': [{'segment': [1.32, 2.32], 'label': 'jump'}]},
#  'vid_865': {'duration_second': 7.4,
#   'duration_frame': 185,
#   'annotations': [{'segment': [1.04, 2.24], 'label': 'jump'}]},
#  'vid_866': {'duration_second': 11.52,
#   'duration_frame': 288,
#   'annotations': [{'segment': [5.04, 5.96], 'label': 'jump'},
#    {'segment': [6.0, 6.92], 'label': 'spin'}]},
#  'vid_867': {'duration_second': 5.56,
#   'duration_frame': 139,
#   'annotations': [{'segment': [1.24, 2.12], 'label': 'jump'}]},
#  'vid_868': {'duration_second': 9.84,
#   'duration_frame': 246,
#   'annotations': [{'segment': [3.92, 4.88], 'label': 'jump'}]},
#  'vid_869': {'duration_second': 7.2,
#   'duration_frame': 180,
#   'annotations': [{'segment': [2.92, 3.6], 'label': 'jump'}]},
#  'vid_870': {'duration_second': 5.6,
#   'duration_frame': 140,
#   'annotations': [{'segment': [1.4, 2.16], 'label': 'jump'},
#    {'segment': [2.76, 3.48], 'label': 'drift'}]},
#  'vid_871': {'duration_second': 10.32,
#   'duration_frame': 258,
#   'annotations': [{'segment': [1.96, 2.84], 'label': 'jump'}]},
#  'vid_872': {'duration_second': 51.16,
#   'duration_frame': 1279,
#   'annotations': [{'segment': [2.6, 4.08], 'label': 'crash'}]},
#  'vid_873': {'duration_second': 15.08,
#   'duration_frame': 377,
#   'annotations': []},
#  'vid_874': {'duration_second': 14.88,
#   'duration_frame': 372,
#   'annotations': [{'segment': [9.6, 10.28], 'label': 'drift'},
#    {'segment': [10.68, 12.0], 'label': 'spin'}]},
#  'vid_875': {'duration_second': 12.36,
#   'duration_frame': 309,
#   'annotations': []},
#  'vid_876': {'duration_second': 19.96,
#   'duration_frame': 499,
#   'annotations': []},
#  'vid_877': {'duration_second': 15.6,
#   'duration_frame': 390,
#   'annotations': []},
#  'vid_878': {'duration_second': 19.72,
#   'duration_frame': 493,
#   'annotations': []},
#  'vid_879': {'duration_second': 11.76,
#   'duration_frame': 294,
#   'annotations': [{'segment': [6.24, 7.92], 'label': 'drift'}]},
#  'vid_880': {'duration_second': 8.4, 'duration_frame': 210, 'annotations': []},
#  'vid_881': {'duration_second': 10.96,
#   'duration_frame': 274,
#   'annotations': []},
#  'vid_882': {'duration_second': 16.0,
#   'duration_frame': 400,
#   'annotations': []},
#  'vid_883': {'duration_second': 14.2,
#   'duration_frame': 355,
#   'annotations': [{'segment': [9.48, 10.48], 'label': 'drift'}]},
#  'vid_884': {'duration_second': 12.92,
#   'duration_frame': 323,
#   'annotations': [{'segment': [6.84, 7.84], 'label': 'drift'}]},
#  'vid_885': {'duration_second': 5.88,
#   'duration_frame': 147,
#   'annotations': [{'segment': [2.68, 4.12], 'label': 'drift'}]},
#  'vid_886': {'duration_second': 14.16,
#   'duration_frame': 354,
#   'annotations': []},
#  'vid_887': {'duration_second': 15.32,
#   'duration_frame': 383,
#   'annotations': []},
#  'vid_888': {'duration_second': 11.84,
#   'duration_frame': 296,
#   'annotations': [{'segment': [7.8, 8.64], 'label': 'drift'}]},
#  'vid_889': {'duration_second': 18.76,
#   'duration_frame': 469,
#   'annotations': [{'segment': [2.88, 3.72], 'label': 'jump'}]},
#  'vid_890': {'duration_second': 16.56,
#   'duration_frame': 414,
#   'annotations': []},
#  'vid_891': {'duration_second': 13.88,
#   'duration_frame': 347,
#   'annotations': [{'segment': [8.56, 9.4], 'label': 'drift'}]},
#  'vid_892': {'duration_second': 8.12,
#   'duration_frame': 203,
#   'annotations': [{'segment': [4.32, 5.72], 'label': 'drift'}]},
#  'vid_893': {'duration_second': 11.6,
#   'duration_frame': 290,
#   'annotations': []},
#  'vid_894': {'duration_second': 15.76,
#   'duration_frame': 394,
#   'annotations': []},
#  'vid_895': {'duration_second': 14.88,
#   'duration_frame': 372,
#   'annotations': [{'segment': [8.72, 9.84], 'label': 'drift'}]},
#  'vid_896': {'duration_second': 6.12,
#   'duration_frame': 153,
#   'annotations': [{'segment': [3.8, 5.0], 'label': 'drift'}]},
#  'vid_897': {'duration_second': 11.12,
#   'duration_frame': 278,
#   'annotations': [{'segment': [9.24, 10.76], 'label': 'drift'}]},
#  'vid_898': {'duration_second': 17.52,
#   'duration_frame': 438,
#   'annotations': []},
#  'vid_899': {'duration_second': 11.88,
#   'duration_frame': 297,
#   'annotations': [{'segment': [6.56, 7.28], 'label': 'drift'}]},
#  'vid_900': {'duration_second': 6.04,
#   'duration_frame': 151,
#   'annotations': [{'segment': [3.32, 4.8], 'label': 'drift'}]},
#  'vid_901': {'duration_second': 16.04,
#   'duration_frame': 401,
#   'annotations': []},
#  'vid_902': {'duration_second': 16.96,
#   'duration_frame': 424,
#   'annotations': []},
#  'vid_903': {'duration_second': 27.92,
#   'duration_frame': 698,
#   'annotations': [{'segment': [9.76, 10.68], 'label': 'drift'},
#    {'segment': [22.8, 24.0], 'label': 'drift'}]},
#  'vid_904': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': []},
#  'vid_905': {'duration_second': 6.24,
#   'duration_frame': 156,
#   'annotations': []},
#  'vid_906': {'duration_second': 14.36,
#   'duration_frame': 359,
#   'annotations': []},
#  'vid_907': {'duration_second': 17.32,
#   'duration_frame': 433,
#   'annotations': []},
#  'vid_908': {'duration_second': 14.96,
#   'duration_frame': 374,
#   'annotations': [{'segment': [10.28, 11.2], 'label': 'drift'}]},
#  'vid_909': {'duration_second': 12.88,
#   'duration_frame': 322,
#   'annotations': []},
#  'vid_910': {'duration_second': 7.44,
#   'duration_frame': 186,
#   'annotations': []},
#  'vid_911': {'duration_second': 10.36,
#   'duration_frame': 259,
#   'annotations': []},
#  'vid_912': {'duration_second': 16.16,
#   'duration_frame': 404,
#   'annotations': []},
#  'vid_913': {'duration_second': 14.56,
#   'duration_frame': 364,
#   'annotations': [{'segment': [9.52, 10.08], 'label': 'drift'}]},
#  'vid_914': {'duration_second': 12.48,
#   'duration_frame': 312,
#   'annotations': []},
#  'vid_915': {'duration_second': 7.96,
#   'duration_frame': 199,
#   'annotations': []},
#  'vid_916': {'duration_second': 16.12,
#   'duration_frame': 403,
#   'annotations': []},
#  'vid_917': {'duration_second': 13.44,
#   'duration_frame': 336,
#   'annotations': []},
#  'vid_918': {'duration_second': 6.68,
#   'duration_frame': 167,
#   'annotations': []},
#  'vid_919': {'duration_second': 15.24,
#   'duration_frame': 381,
#   'annotations': []},
#  'vid_920': {'duration_second': 17.76,
#   'duration_frame': 444,
#   'annotations': []},
#  'vid_921': {'duration_second': 12.76,
#   'duration_frame': 319,
#   'annotations': []},
#  'vid_922': {'duration_second': 17.04,
#   'duration_frame': 426,
#   'annotations': []},
#  'vid_923': {'duration_second': 7.12,
#   'duration_frame': 178,
#   'annotations': []},
#  'vid_924': {'duration_second': 13.24,
#   'duration_frame': 331,
#   'annotations': []},
#  'vid_925': {'duration_second': 15.16,
#   'duration_frame': 379,
#   'annotations': []},
#  'vid_926': {'duration_second': 14.64,
#   'duration_frame': 366,
#   'annotations': [{'segment': [10.44, 11.12], 'label': 'drift'}]},
#  'vid_927': {'duration_second': 6.2, 'duration_frame': 155, 'annotations': []},
#  'vid_928': {'duration_second': 13.48,
#   'duration_frame': 337,
#   'annotations': [{'segment': [5.16, 6.68], 'label': 'drift'}]},
#  'vid_929': {'duration_second': 18.12,
#   'duration_frame': 453,
#   'annotations': []},
#  'vid_930': {'duration_second': 15.8,
#   'duration_frame': 395,
#   'annotations': []},
#  'vid_931': {'duration_second': 13.16,
#   'duration_frame': 329,
#   'annotations': []},
#  'vid_932': {'duration_second': 13.2,
#   'duration_frame': 330,
#   'annotations': []},
#  'vid_933': {'duration_second': 18.28,
#   'duration_frame': 457,
#   'annotations': []},
#  'vid_934': {'duration_second': 11.88,
#   'duration_frame': 297,
#   'annotations': []},
#  'vid_935': {'duration_second': 6.56,
#   'duration_frame': 164,
#   'annotations': []},
#  'vid_936': {'duration_second': 12.24,
#   'duration_frame': 306,
#   'annotations': []},
#  'vid_937': {'duration_second': 16.84,
#   'duration_frame': 421,
#   'annotations': []},
#  'vid_938': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': []},
#  'vid_939': {'duration_second': 7.64,
#   'duration_frame': 191,
#   'annotations': [{'segment': [2.76, 3.48], 'label': 'jump'}]},
#  'vid_940': {'duration_second': 12.4,
#   'duration_frame': 310,
#   'annotations': []},
#  'vid_941': {'duration_second': 19.36,
#   'duration_frame': 484,
#   'annotations': []},
#  'vid_942': {'duration_second': 25.68,
#   'duration_frame': 642,
#   'annotations': [{'segment': [21.72, 22.4], 'label': 'drift'},
#    {'segment': [21.6, 22.8], 'label': 'spin'}]},
#  'vid_943': {'duration_second': 16.56,
#   'duration_frame': 414,
#   'annotations': []},
#  'vid_944': {'duration_second': 8.0, 'duration_frame': 200, 'annotations': []},
#  'vid_945': {'duration_second': 13.52,
#   'duration_frame': 338,
#   'annotations': []},
#  'vid_946': {'duration_second': 15.84,
#   'duration_frame': 396,
#   'annotations': []},
#  'vid_947': {'duration_second': 6.8, 'duration_frame': 170, 'annotations': []},
#  'vid_948': {'duration_second': 12.72,
#   'duration_frame': 318,
#   'annotations': []},
#  'vid_949': {'duration_second': 17.92,
#   'duration_frame': 448,
#   'annotations': []},
#  'vid_950': {'duration_second': 15.0,
#   'duration_frame': 375,
#   'annotations': [{'segment': [8.56, 9.0], 'label': 'spin'},
#    {'segment': [9.36, 10.48], 'label': 'drift'}]},
#  'vid_951': {'duration_second': 12.52,
#   'duration_frame': 313,
#   'annotations': []},
#  'vid_952': {'duration_second': 6.76,
#   'duration_frame': 169,
#   'annotations': []},
#  'vid_953': {'duration_second': 15.8,
#   'duration_frame': 395,
#   'annotations': []},
#  'vid_954': {'duration_second': 17.76,
#   'duration_frame': 444,
#   'annotations': []},
#  'vid_955': {'duration_second': 15.08,
#   'duration_frame': 377,
#   'annotations': []},
#  'vid_956': {'duration_second': 14.04,
#   'duration_frame': 351,
#   'annotations': []},
#  'vid_957': {'duration_second': 6.88,
#   'duration_frame': 172,
#   'annotations': []},
#  'vid_958': {'duration_second': 13.6,
#   'duration_frame': 340,
#   'annotations': []},
#  'vid_959': {'duration_second': 16.44,
#   'duration_frame': 411,
#   'annotations': []},
#  'vid_960': {'duration_second': 14.6,
#   'duration_frame': 365,
#   'annotations': []},
#  'vid_961': {'duration_second': 12.48,
#   'duration_frame': 312,
#   'annotations': []},
#  'vid_962': {'duration_second': 7.08,
#   'duration_frame': 177,
#   'annotations': []},
#  'vid_963': {'duration_second': 17.56,
#   'duration_frame': 439,
#   'annotations': []},
#  'vid_964': {'duration_second': 20.28,
#   'duration_frame': 507,
#   'annotations': []},
#  'vid_965': {'duration_second': 17.84,
#   'duration_frame': 446,
#   'annotations': [{'segment': [10.68, 11.6], 'label': 'drift'}]},
#  'vid_966': {'duration_second': 17.96,
#   'duration_frame': 449,
#   'annotations': []},
#  'vid_967': {'duration_second': 29.12,
#   'duration_frame': 728,
#   'annotations': [{'segment': [10.84, 11.56], 'label': 'drift'}]},
#  'vid_968': {'duration_second': 9.44,
#   'duration_frame': 236,
#   'annotations': []},
#  'vid_969': {'duration_second': 16.68,
#   'duration_frame': 417,
#   'annotations': []},
#  'vid_970': {'duration_second': 16.32,
#   'duration_frame': 408,
#   'annotations': []},
#  'vid_971': {'duration_second': 16.52,
#   'duration_frame': 413,
#   'annotations': []},
#  'vid_972': {'duration_second': 7.28,
#   'duration_frame': 182,
#   'annotations': []},
#  'vid_973': {'duration_second': 11.96,
#   'duration_frame': 299,
#   'annotations': []},
#  'vid_974': {'duration_second': 16.96,
#   'duration_frame': 424,
#   'annotations': []},
#  'vid_975': {'duration_second': 14.72,
#   'duration_frame': 368,
#   'annotations': []},
#  'vid_976': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': []},
#  'vid_977': {'duration_second': 5.8, 'duration_frame': 145, 'annotations': []},
#  'vid_978': {'duration_second': 13.52,
#   'duration_frame': 338,
#   'annotations': [{'segment': [0.76, 2.0], 'label': 'drift'}]},
#  'vid_979': {'duration_second': 17.52,
#   'duration_frame': 438,
#   'annotations': []},
#  'vid_980': {'duration_second': 16.8,
#   'duration_frame': 420,
#   'annotations': []},
#  'vid_981': {'duration_second': 15.28,
#   'duration_frame': 382,
#   'annotations': [{'segment': [10.0, 11.32], 'label': 'drift'}]},
#  'vid_982': {'duration_second': 6.24,
#   'duration_frame': 156,
#   'annotations': []},
#  'vid_983': {'duration_second': 13.92,
#   'duration_frame': 348,
#   'annotations': []},
#  'vid_984': {'duration_second': 18.16,
#   'duration_frame': 454,
#   'annotations': []},
#  'vid_985': {'duration_second': 14.8,
#   'duration_frame': 370,
#   'annotations': []},
#  'vid_986': {'duration_second': 9.2, 'duration_frame': 230, 'annotations': []},
#  'vid_987': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': []},
#  'vid_988': {'duration_second': 6.28,
#   'duration_frame': 157,
#   'annotations': []},
#  'vid_989': {'duration_second': 11.12,
#   'duration_frame': 278,
#   'annotations': [{'segment': [4.92, 6.2], 'label': 'drift'}]},
#  'vid_990': {'duration_second': 16.24,
#   'duration_frame': 406,
#   'annotations': []},
#  'vid_991': {'duration_second': 14.48,
#   'duration_frame': 362,
#   'annotations': []},
#  'vid_992': {'duration_second': 12.68,
#   'duration_frame': 317,
#   'annotations': []},
#  'vid_993': {'duration_second': 6.52,
#   'duration_frame': 163,
#   'annotations': []},
#  'vid_994': {'duration_second': 13.24,
#   'duration_frame': 331,
#   'annotations': [{'segment': [4.92, 6.48], 'label': 'drift'}]},
#  'vid_995': {'duration_second': 17.24,
#   'duration_frame': 431,
#   'annotations': []},
#  'vid_996': {'duration_second': 15.44,
#   'duration_frame': 386,
#   'annotations': []},
#  'vid_997': {'duration_second': 23.16,
#   'duration_frame': 579,
#   'annotations': [{'segment': [10.24, 10.84], 'label': 'drift'}]},
#  'vid_998': {'duration_second': 16.76,
#   'duration_frame': 419,
#   'annotations': []},
#  'vid_999': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': []},
#  'vid_1000': {'duration_second': 14.52,
#   'duration_frame': 363,
#   'annotations': []},
#  'vid_1001': {'duration_second': 16.12,
#   'duration_frame': 403,
#   'annotations': []},
#  'vid_1002': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': []},
#  'vid_1003': {'duration_second': 11.56,
#   'duration_frame': 289,
#   'annotations': [{'segment': [4.2, 7.12], 'label': 'drift'}]},
#  'vid_1004': {'duration_second': 19.08,
#   'duration_frame': 477,
#   'annotations': []},
#  'vid_1005': {'duration_second': 20.92,
#   'duration_frame': 523,
#   'annotations': [{'segment': [6.0, 7.84], 'label': 'spin'}]},
#  'vid_1006': {'duration_second': 18.88,
#   'duration_frame': 472,
#   'annotations': []},
#  'vid_1007': {'duration_second': 14.84,
#   'duration_frame': 371,
#   'annotations': []},
#  'vid_1008': {'duration_second': 7.0,
#   'duration_frame': 175,
#   'annotations': []},
#  'vid_1009': {'duration_second': 13.96,
#   'duration_frame': 349,
#   'annotations': [{'segment': [6.0, 7.84], 'label': 'drift'}]},
#  'vid_1010': {'duration_second': 16.2,
#   'duration_frame': 405,
#   'annotations': []},
#  'vid_1011': {'duration_second': 14.76,
#   'duration_frame': 369,
#   'annotations': []},
#  'vid_1012': {'duration_second': 12.8,
#   'duration_frame': 320,
#   'annotations': [{'segment': [5.24, 6.68], 'label': 'drift'}]},
#  'vid_1013': {'duration_second': 18.36,
#   'duration_frame': 459,
#   'annotations': []},
#  'vid_1014': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': [{'segment': [4.88, 6.88], 'label': 'drift'}]},
#  'vid_1015': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': []},
#  'vid_1016': {'duration_second': 21.28,
#   'duration_frame': 532,
#   'annotations': []},
#  'vid_1017': {'duration_second': 5.233333333333333,
#   'duration_frame': 157,
#   'annotations': [{'segment': [0.6, 2.03], 'label': 'spin'}]},
#  'vid_1018': {'duration_second': 8.166666666666666,
#   'duration_frame': 245,
#   'annotations': [{'segment': [3.13, 4.87], 'label': 'spin'}]},
#  'vid_1019': {'duration_second': 8.4,
#   'duration_frame': 252,
#   'annotations': [{'segment': [4.0, 5.53], 'label': 'spin'}]},
#  'vid_1020': {'duration_second': 8.566666666666666,
#   'duration_frame': 257,
#   'annotations': [{'segment': [4.57, 5.7], 'label': 'spin'}]},
#  'vid_766': {'duration_second': 8.7,
#   'duration_frame': 261,
#   'annotations': [{'segment': [6.4, 7.23], 'label': 'spin'},
#    {'segment': [5.07, 6.37], 'label': 'drift'}]}}

# %%
len(processed_data)
# Out:
# 315

# %%
with open(TIMESTAMP_ANNOTATIONS, "w") as json_file:
    json.dump(processed_data, json_file, indent=4)

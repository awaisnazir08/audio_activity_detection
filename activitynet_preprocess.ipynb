# %%
import ndjson
import json
import os
from audio_extract import extract_audio
import requests

# %%
META_DATA_PATH = 'Audio_data_labelbox/Action video labels - 2_14_2025.ndjson'
VIDEOS_DIRECTORY = 'Videos'
AUDIOS_DIRECTORY = 'Audios'
TIMESTAMP_ANNOTATIONS = 'activitynet_annotations.json'

# %%
#sample
"""
{
  "video1": {
      "duration_second": 211.53,
      "duration_frame": 6337,
      "annotations": [
          {
              "segment": [
                  30.025882995319815,
                  205.2318595943838
              ],
              "label": "Rock climbing"
          }
      ],
      "feature_frame": 6336,
      "fps": 30.0,
      "rfps": 29.9579255898
  },
"""

# %%
processed_data = {}
with open (META_DATA_PATH, 'r') as file:
    metadata = ndjson.load(file)
    for item in metadata:
        video_url = item['data_row']['row_data']
        video_name = item['data_row']['external_id']
        if video_name == 'vid_771.mp4':
            continue
        processed_data[video_name[:-4]] = {}
        processed_data[video_name[:-4]]['duration_second'] = item['media_attributes']['frame_count'] / item['media_attributes']['frame_rate']
        processed_data[video_name[:-4]]['duration_frame'] = item['media_attributes']['frame_count']
        processed_data[video_name[:-4]]['annotations'] = []
        
        video_path = os.path.join(VIDEOS_DIRECTORY, video_name)
        # download_video(video_url, video_name, video_path)
        
        audio_name = video_name[:-3] + 'mp3'
        audio_path = os.path.join(AUDIOS_DIRECTORY, audio_name)
        
        # video_to_audio(video_path, audio_path)
        video_frame_rate = item['media_attributes']['frame_rate']
        frames = item["projects"]["clvksmh1x038b07z80gv75tec"]["labels"][0]["annotations"]["frames"]
        
        # Loop through and extract frame numbers
        activities = {}
        for frame, annotations in frames.items():
            frame = int(frame)
            classifications = annotations.get("classifications", [])
            for classification in classifications:
                label_value = classification["value"]
                if label_value not in activities:
                    activities[label_value] = []
                activities[label_value].append(round(frame / video_frame_rate, 2))
        
        for key, times_array in activities.items():
            times_array.sort()
            if (len(times_array) % 2) != 0:
                print(video_name)
            
            
            for i in range(0, len(times_array), 2):
                annotation_item = {}
                annotation_item['segment'] = [times_array[i], times_array[i + 1]]
                annotation_item['label'] = key
                processed_data[video_name[:-4]]['annotations'].append(annotation_item)

# %%
processed_data
# Out:
# {'vid_554': {'duration_second': 6.0,
#   'duration_frame': 150,
#   'annotations': [{'segment': [0.96, 5.08], 'label': 'turn'},
#    {'segment': [3.36, 4.68], 'label': 'drift'},
#    {'segment': [0.84, 5.04], 'label': 'high_speed'},
#    {'segment': [0.28, 6.0], 'label': 'long_noise'}]},
#  'vid_555': {'duration_second': 3.8,
#   'duration_frame': 95,
#   'annotations': [{'segment': [1.72, 2.0], 'label': 'crash'},
#    {'segment': [1.08, 1.88], 'label': 'jump'},
#    {'segment': [1.72, 2.12], 'label': 'drift'},
#    {'segment': [1.92, 3.8], 'label': 'long_noise'}]},
#  'vid_561': {'duration_second': 3.48,
#   'duration_frame': 87,
#   'annotations': [{'segment': [0.08, 3.48], 'label': 'long_noise'}]},
#  'vid_562': {'duration_second': 7.32,
#   'duration_frame': 183,
#   'annotations': [{'segment': [0.88, 2.08], 'label': 'drift'},
#    {'segment': [2.64, 4.68], 'label': 'drift'},
#    {'segment': [0.88, 2.08], 'label': 'turn'},
#    {'segment': [2.56, 5.16], 'label': 'turn'},
#    {'segment': [0.88, 5.16], 'label': 'high_speed'},
#    {'segment': [0.72, 7.32], 'label': 'long_noise'}]},
#  'vid_563': {'duration_second': 3.52,
#   'duration_frame': 88,
#   'annotations': [{'segment': [0.88, 2.0], 'label': 'drift'},
#    {'segment': [1.16, 1.96], 'label': 'jump'},
#    {'segment': [1.4, 2.08], 'label': 'crash'},
#    {'segment': [0.6, 3.52], 'label': 'long_noise'}]},
#  'vid_564': {'duration_second': 8.0,
#   'duration_frame': 200,
#   'annotations': [{'segment': [0.32, 8.0], 'label': 'long_noise'},
#    {'segment': [1.52, 2.36], 'label': 'jump'},
#    {'segment': [5.24, 5.84], 'label': 'turn'}]},
#  'vid_565': {'duration_second': 8.6,
#   'duration_frame': 215,
#   'annotations': [{'segment': [0.6, 8.6], 'label': 'long_noise'},
#    {'segment': [1.44, 2.44], 'label': 'spin'},
#    {'segment': [5.44, 6.64], 'label': 'turn'}]},
#  'vid_566': {'duration_second': 5.68,
#   'duration_frame': 142,
#   'annotations': [{'segment': [0.08, 5.68], 'label': 'long_noise'},
#    {'segment': [0.88, 2.64], 'label': 'spin'}]},
#  'vid_567': {'duration_second': 11.24,
#   'duration_frame': 281,
#   'annotations': [{'segment': [0.36, 11.24], 'label': 'long_noise'},
#    {'segment': [5.96, 7.24], 'label': 'spin'}]},
#  'vid_568': {'duration_second': 12.2,
#   'duration_frame': 305,
#   'annotations': [{'segment': [0.96, 2.32], 'label': 'spin'},
#    {'segment': [0.04, 12.2], 'label': 'long_noise'},
#    {'segment': [3.0, 4.16], 'label': 'turn'},
#    {'segment': [1.52, 4.52], 'label': 'crowd_noise'}]},
#  'vid_569': {'duration_second': 9.36,
#   'duration_frame': 234,
#   'annotations': [{'segment': [0.04, 9.36], 'label': 'long_noise'},
#    {'segment': [0.88, 1.84], 'label': 'turn'},
#    {'segment': [2.44, 3.44], 'label': 'turn'}]},
#  'vid_570': {'duration_second': 9.56,
#   'duration_frame': 239,
#   'annotations': [{'segment': [0.04, 9.56], 'label': 'long_noise'},
#    {'segment': [1.32, 2.64], 'label': 'turn'},
#    {'segment': [3.2, 3.96], 'label': 'turn'}]},
#  'vid_573': {'duration_second': 8.2,
#   'duration_frame': 205,
#   'annotations': [{'segment': [0.12, 8.2], 'label': 'long_noise'},
#    {'segment': [1.16, 1.72], 'label': 'jump'},
#    {'segment': [3.6, 4.68], 'label': 'turn'}]},
#  'vid_574': {'duration_second': 17.68,
#   'duration_frame': 442,
#   'annotations': [{'segment': [0.04, 17.68], 'label': 'long_noise'},
#    {'segment': [3.32, 5.48], 'label': 'spin'},
#    {'segment': [5.52, 7.16], 'label': 'stuck'},
#    {'segment': [10.16, 12.56], 'label': 'turn'}]},
#  'vid_575': {'duration_second': 11.44,
#   'duration_frame': 286,
#   'annotations': [{'segment': [0.32, 11.44], 'label': 'long_noise'},
#    {'segment': [1.36, 2.48], 'label': 'jump'},
#    {'segment': [5.16, 6.12], 'label': 'turn'}]},
#  'vid_576': {'duration_second': 5.48,
#   'duration_frame': 137,
#   'annotations': [{'segment': [0.04, 5.48], 'label': 'long_noise'},
#    {'segment': [1.2, 1.68], 'label': 'jump'}]},
#  'vid_577': {'duration_second': 9.08,
#   'duration_frame': 227,
#   'annotations': [{'segment': [1.0, 9.08], 'label': 'long_noise'},
#    {'segment': [1.68, 2.16], 'label': 'jump'},
#    {'segment': [5.32, 6.24], 'label': 'turn'}]},
#  'vid_578': {'duration_second': 8.24,
#   'duration_frame': 206,
#   'annotations': [{'segment': [1.04, 8.24], 'label': 'long_noise'},
#    {'segment': [1.56, 2.44], 'label': 'jump'},
#    {'segment': [4.84, 5.56], 'label': 'turn'}]},
#  'vid_579': {'duration_second': 10.0,
#   'duration_frame': 250,
#   'annotations': [{'segment': [0.08, 10.0], 'label': 'long_noise'},
#    {'segment': [5.76, 6.2], 'label': 'tyre_screech_noise'},
#    {'segment': [5.88, 6.28], 'label': 'drift'}]},
#  'vid_580': {'duration_second': 10.0,
#   'duration_frame': 250,
#   'annotations': [{'segment': [0.96, 1.84], 'label': 'spin'},
#    {'segment': [1.88, 10.0], 'label': 'long_noise'},
#    {'segment': [4.44, 5.28], 'label': 'drift'},
#    {'segment': [6.8, 7.72], 'label': 'turn'}]},
#  'vid_581': {'duration_second': 12.28,
#   'duration_frame': 307,
#   'annotations': [{'segment': [0.04, 12.28], 'label': 'long_noise'},
#    {'segment': [1.84, 3.68], 'label': 'turn'},
#    {'segment': [6.92, 7.92], 'label': 'turn'},
#    {'segment': [8.32, 9.68], 'label': 'turn'},
#    {'segment': [6.4, 6.88], 'label': 'drift'}]},
#  'vid_582': {'duration_second': 5.72,
#   'duration_frame': 143,
#   'annotations': [{'segment': [0.2, 5.72], 'label': 'long_noise'},
#    {'segment': [0.88, 1.4], 'label': 'turn'},
#    {'segment': [3.72, 4.56], 'label': 'turn'}]},
#  'vid_583': {'duration_second': 7.6,
#   'duration_frame': 190,
#   'annotations': [{'segment': [0.48, 7.6], 'label': 'long_noise'},
#    {'segment': [1.2, 2.16], 'label': 'turn'},
#    {'segment': [3.24, 4.08], 'label': 'turn'},
#    {'segment': [1.24, 2.08], 'label': 'spin'}]},
#  'vid_736': {'duration_second': 11.52,
#   'duration_frame': 288,
#   'annotations': [{'segment': [2.8, 3.72], 'label': 'turn'},
#    {'segment': [2.72, 4.84], 'label': 'drift'},
#    {'segment': [5.6, 6.16], 'label': 'crash_noise'},
#    {'segment': [5.48, 7.08], 'label': 'crash'},
#    {'segment': [4.88, 7.28], 'label': 'spin'},
#    {'segment': [4.88, 11.48], 'label': 'crowd_noise'},
#    {'segment': [5.44, 6.68], 'label': 'veichal_issue'},
#    {'segment': [0.04, 6.08], 'label': 'long_noise'},
#    {'segment': [2.48, 3.28], 'label': 'cut'}]},
#  'vid_737': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [0.04, 2.76], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 3.04], 'label': 'long_noise'},
#    {'segment': [2.76, 3.92], 'label': 'spin'},
#    {'segment': [4.0, 5.88], 'label': 'breakdown'},
#    {'segment': [2.6, 5.88], 'label': 'crowd_noise'},
#    {'segment': [1.08, 2.24], 'label': 'turn'}]},
#  'vid_738': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [0.04, 1.08], 'label': 'turn'},
#    {'segment': [0.04, 5.24], 'label': 'long_noise'},
#    {'segment': [0.8, 1.64], 'label': 'drift'},
#    {'segment': [1.64, 3.16], 'label': 'spin'},
#    {'segment': [3.2, 5.2], 'label': 'stuck'},
#    {'segment': [0.6, 2.04], 'label': 'crowd_noise'},
#    {'segment': [3.2, 4.44], 'label': 'crowd_noise'}]},
#  'vid_739': {'duration_second': 6.72,
#   'duration_frame': 168,
#   'annotations': [{'segment': [1.28, 1.76], 'label': 'veichal_issue'},
#    {'segment': [2.64, 6.68], 'label': 'breakdown'},
#    {'segment': [1.32, 6.68], 'label': 'crowd_noise'},
#    {'segment': [1.68, 1.96], 'label': 'crash_noise'},
#    {'segment': [2.68, 3.24], 'label': 'crash_noise'},
#    {'segment': [0.88, 1.44], 'label': 'tyre_screech_noise'}]},
#  'vid_740': {'duration_second': 4.56,
#   'duration_frame': 114,
#   'annotations': [{'segment': [0.44, 1.52], 'label': 'drift'},
#    {'segment': [3.24, 4.52], 'label': 'breakdown'},
#    {'segment': [2.2, 4.52], 'label': 'crowd_noise'},
#    {'segment': [0.04, 1.24], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 2.6], 'label': 'long_noise'},
#    {'segment': [1.32, 3.2], 'label': 'crash'},
#    {'segment': [1.32, 1.72], 'label': 'crash_noise'}]},
#  'vid_741': {'duration_second': 8.16,
#   'duration_frame': 204,
#   'annotations': [{'segment': [0.36, 1.28], 'label': 'turn'},
#    {'segment': [4.44, 8.12], 'label': 'breakdown'},
#    {'segment': [6.36, 7.0], 'label': 'crowd_noise'},
#    {'segment': [7.64, 8.12], 'label': 'crowd_noise'},
#    {'segment': [0.64, 3.36], 'label': 'tyre_screech_noise'},
#    {'segment': [3.4, 4.36], 'label': 'crash'},
#    {'segment': [3.4, 4.68], 'label': 'crash_noise'},
#    {'segment': [0.04, 4.0], 'label': 'long_noise'}]},
#  'vid_742': {'duration_second': 20.04,
#   'duration_frame': 501,
#   'annotations': [{'segment': [9.2, 11.08], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 4.24], 'label': 'long_noise'},
#    {'segment': [5.92, 11.72], 'label': 'long_noise'},
#    {'segment': [2.84, 5.76], 'label': 'stuck'},
#    {'segment': [2.0, 2.2], 'label': 'crowd_noise'},
#    {'segment': [9.52, 11.16], 'label': 'drift'},
#    {'segment': [1.44, 3.04], 'label': 'crash'},
#    {'segment': [11.64, 17.96], 'label': 'crash'},
#    {'segment': [18.8, 20.0], 'label': 'breakdown'},
#    {'segment': [0.88, 1.36], 'label': 'spin'},
#    {'segment': [10.28, 11.44], 'label': 'spin'},
#    {'segment': [1.36, 2.92], 'label': 'crash_noise'},
#    {'segment': [11.8, 17.4], 'label': 'crash_noise'}]},
#  'vid_743': {'duration_second': 8.72,
#   'duration_frame': 218,
#   'annotations': [{'segment': [0.04, 5.0], 'label': 'long_noise'},
#    {'segment': [6.12, 8.72], 'label': 'long_noise'},
#    {'segment': [2.36, 3.44], 'label': 'drift'},
#    {'segment': [3.48, 4.16], 'label': 'spin'},
#    {'segment': [4.2, 5.12], 'label': 'crash'},
#    {'segment': [4.28, 5.16], 'label': 'crash_noise'},
#    {'segment': [5.2, 8.68], 'label': 'stuck'}]},
#  'vid_744': {'duration_second': 10.24,
#   'duration_frame': 256,
#   'annotations': [{'segment': [1.36, 3.48], 'label': 'drift'},
#    {'segment': [4.8, 7.92], 'label': 'crowd_noise'},
#    {'segment': [0.04, 10.2], 'label': 'long_noise'},
#    {'segment': [3.52, 5.76], 'label': 'spin'},
#    {'segment': [7.32, 7.64], 'label': 'stuck'}]},
#  'vid_745': {'duration_second': 17.12,
#   'duration_frame': 428,
#   'annotations': [{'segment': [1.68, 2.36], 'label': 'crowd_noise'},
#    {'segment': [4.76, 8.44], 'label': 'crowd_noise'},
#    {'segment': [11.32, 17.08], 'label': 'crowd_noise'},
#    {'segment': [0.04, 1.12], 'label': 'long_noise'},
#    {'segment': [2.12, 17.08], 'label': 'long_noise'},
#    {'segment': [2.4, 12.0], 'label': 'cut'},
#    {'segment': [12.04, 13.44], 'label': 'turn'},
#    {'segment': [1.2, 1.6], 'label': 'tyre_screech_noise'}]},
#  'vid_746': {'duration_second': 13.96,
#   'duration_frame': 349,
#   'annotations': [{'segment': [3.12, 4.48], 'label': 'tyre_screech_noise'},
#    {'segment': [5.04, 13.92], 'label': 'crowd_noise'},
#    {'segment': [8.08, 13.92], 'label': 'breakdown'},
#    {'segment': [5.88, 6.88], 'label': 'crash'},
#    {'segment': [5.76, 6.44], 'label': 'crash_noise'},
#    {'segment': [0.04, 6.96], 'label': 'long_noise'}]},
#  'vid_747': {'duration_second': 12.72,
#   'duration_frame': 318,
#   'annotations': [{'segment': [0.04, 4.8], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 5.24], 'label': 'long_noise'},
#    {'segment': [3.4, 5.24], 'label': 'drift'},
#    {'segment': [5.28, 7.32], 'label': 'crash'},
#    {'segment': [5.28, 9.24], 'label': 'crash_noise'},
#    {'segment': [5.52, 7.24], 'label': 'spin'},
#    {'segment': [8.88, 12.68], 'label': 'breakdown'},
#    {'segment': [5.44, 12.68], 'label': 'crowd_noise'}]},
#  'vid_748': {'duration_second': 6.04,
#   'duration_frame': 151,
#   'annotations': [{'segment': [0.04, 1.92], 'label': 'turn'},
#    {'segment': [0.04, 6.04], 'label': 'long_noise'},
#    {'segment': [0.48, 3.88], 'label': 'tyre_screech_noise'},
#    {'segment': [2.92, 6.0], 'label': 'crash_noise'},
#    {'segment': [2.92, 3.4], 'label': 'crash'}]},
#  'vid_749': {'duration_second': 10.64,
#   'duration_frame': 266,
#   'annotations': [{'segment': [1.92, 3.64], 'label': 'turn'},
#    {'segment': [5.28, 5.48], 'label': 'crash'},
#    {'segment': [5.24, 5.76], 'label': 'crash_noise'},
#    {'segment': [0.04, 5.2], 'label': 'long_noise'},
#    {'segment': [8.28, 10.64], 'label': 'long_noise'},
#    {'segment': [7.6, 10.32], 'label': 'drift'},
#    {'segment': [2.16, 2.88], 'label': 'tyre_screech_noise'}]},
#  'vid_750': {'duration_second': 6.88,
#   'duration_frame': 172,
#   'annotations': [{'segment': [0.6, 2.24], 'label': 'crash'},
#    {'segment': [0.04, 2.28], 'label': 'crash_noise'},
#    {'segment': [0.04, 6.88], 'label': 'long_noise'},
#    {'segment': [2.32, 6.84], 'label': 'stuck'},
#    {'segment': [2.96, 6.84], 'label': 'crowd_noise'}]},
#  'vid_751': {'duration_second': 9.84,
#   'duration_frame': 246,
#   'annotations': [{'segment': [0.04, 6.32], 'label': 'long_noise'},
#    {'segment': [1.28, 3.6], 'label': 'tyre_screech_noise'},
#    {'segment': [3.4, 4.08], 'label': 'cut'},
#    {'segment': [4.12, 5.88], 'label': 'drift'},
#    {'segment': [6.36, 8.36], 'label': 'stuck'},
#    {'segment': [8.44, 9.8], 'label': 'breakdown'},
#    {'segment': [6.56, 9.64], 'label': 'crowd_noise'}]},
#  'vid_752': {'duration_second': 6.84,
#   'duration_frame': 171,
#   'annotations': [{'segment': [0.04, 4.48], 'label': 'long_noise'},
#    {'segment': [3.24, 4.64], 'label': 'crash'},
#    {'segment': [4.68, 6.8], 'label': 'breakdown'},
#    {'segment': [5.0, 6.8], 'label': 'crowd_noise'}]},
#  'vid_753': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': [{'segment': [0.04, 5.76], 'label': 'long_noise'},
#    {'segment': [3.64, 6.2], 'label': 'tyre_screech_noise'},
#    {'segment': [4.52, 6.2], 'label': 'crash'},
#    {'segment': [4.48, 5.2], 'label': 'crash_noise'},
#    {'segment': [6.24, 9.12], 'label': 'breakdown'},
#    {'segment': [6.28, 9.12], 'label': 'crowd_noise'}]},
#  'vid_754': {'duration_second': 8.48,
#   'duration_frame': 212,
#   'annotations': [{'segment': [0.04, 4.44], 'label': 'long_noise'},
#    {'segment': [2.52, 5.64], 'label': 'cut'},
#    {'segment': [3.04, 4.0], 'label': 'drift'},
#    {'segment': [3.56, 4.32], 'label': 'spin'},
#    {'segment': [5.68, 8.44], 'label': 'breakdown'},
#    {'segment': [3.88, 8.44], 'label': 'crowd_noise'}]},
#  'vid_755': {'duration_second': 11.0,
#   'duration_frame': 275,
#   'annotations': [{'segment': [0.04, 4.72], 'label': 'long_noise'},
#    {'segment': [1.92, 3.92], 'label': 'tyre_screech_noise'},
#    {'segment': [3.96, 6.04], 'label': 'cut'},
#    {'segment': [5.36, 10.96], 'label': 'crowd_noise'},
#    {'segment': [9.8, 10.96], 'label': 'breakdown'},
#    {'segment': [9.08, 9.76], 'label': 'stuck'}]},
#  'vid_756': {'duration_second': 4.88,
#   'duration_frame': 122,
#   'annotations': [{'segment': [0.04, 2.52], 'label': 'long_noise'},
#    {'segment': [0.68, 1.84], 'label': 'turn'},
#    {'segment': [1.84, 2.8], 'label': 'crash'},
#    {'segment': [1.96, 4.84], 'label': 'breakdown'},
#    {'segment': [0.76, 1.64], 'label': 'tyre_screech_noise'},
#    {'segment': [1.88, 2.48], 'label': 'crash_noise'}]},
#  'vid_757': {'duration_second': 15.2,
#   'duration_frame': 380,
#   'annotations': [{'segment': [0.04, 4.52], 'label': 'long_noise'},
#    {'segment': [5.52, 11.8], 'label': 'long_noise'},
#    {'segment': [1.44, 4.52], 'label': 'tyre_screech_noise'},
#    {'segment': [4.56, 6.84], 'label': 'cut'},
#    {'segment': [11.84, 13.0], 'label': 'crash'},
#    {'segment': [11.32, 15.16], 'label': 'crowd_noise'}]},
#  'vid_758': {'duration_second': 7.4,
#   'duration_frame': 185,
#   'annotations': [{'segment': [0.04, 4.6], 'label': 'long_noise'},
#    {'segment': [1.32, 4.2], 'label': 'tyre_screech_noise'},
#    {'segment': [4.2, 5.4], 'label': 'crash'},
#    {'segment': [2.96, 4.16], 'label': 'spin'},
#    {'segment': [3.76, 5.04], 'label': 'crash_noise'},
#    {'segment': [4.24, 7.36], 'label': 'breakdown'},
#    {'segment': [5.6, 7.36], 'label': 'crowd_noise'}]},
#  'vid_759': {'duration_second': 10.04,
#   'duration_frame': 251,
#   'annotations': [{'segment': [0.04, 5.16], 'label': 'drift'},
#    {'segment': [3.12, 7.76], 'label': 'spin'},
#    {'segment': [8.0, 10.0], 'label': 'crowd_noise'},
#    {'segment': [1.08, 6.68], 'label': 'long_noise'}]},
#  'vid_760': {'duration_second': 11.52,
#   'duration_frame': 288,
#   'annotations': [{'segment': [0.04, 1.16], 'label': 'tyre_screech_noise'},
#    {'segment': [6.28, 8.28], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 9.0], 'label': 'long_noise'},
#    {'segment': [8.32, 11.48], 'label': 'breakdown'},
#    {'segment': [8.48, 11.48], 'label': 'crowd_noise'},
#    {'segment': [7.04, 8.08], 'label': 'spin'}]},
#  'vid_761': {'duration_second': 9.6,
#   'duration_frame': 240,
#   'annotations': [{'segment': [0.04, 6.32], 'label': 'long_noise'},
#    {'segment': [5.88, 6.32], 'label': 'crash_noise'},
#    {'segment': [0.92, 2.84], 'label': 'turn'},
#    {'segment': [3.44, 6.24], 'label': 'tyre_screech_noise'},
#    {'segment': [6.28, 9.56], 'label': 'breakdown'},
#    {'segment': [5.84, 9.56], 'label': 'crowd_noise'},
#    {'segment': [5.68, 6.08], 'label': 'crash'}]},
#  'vid_762': {'duration_second': 6.96,
#   'duration_frame': 174,
#   'annotations': [{'segment': [0.44, 2.08], 'label': 'tyre_screech_noise'},
#    {'segment': [1.0, 2.08], 'label': 'spin'},
#    {'segment': [2.48, 3.76], 'label': 'spin'},
#    {'segment': [0.04, 3.96], 'label': 'long_noise'},
#    {'segment': [4.0, 6.92], 'label': 'breakdown'},
#    {'segment': [4.6, 6.84], 'label': 'crowd_noise'}]},
#  'vid_763': {'duration_second': 8.72,
#   'duration_frame': 218,
#   'annotations': [{'segment': [0.04, 1.12], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 3.48], 'label': 'long_noise'},
#    {'segment': [3.76, 8.68], 'label': 'long_noise'},
#    {'segment': [5.4, 6.56], 'label': 'spin'}]},
#  'vid_764': {'duration_second': 9.12,
#   'duration_frame': 228,
#   'annotations': [{'segment': [0.04, 4.76], 'label': 'long_noise'},
#    {'segment': [4.8, 6.08], 'label': 'crash'},
#    {'segment': [4.92, 6.08], 'label': 'crash_noise'},
#    {'segment': [5.76, 6.16], 'label': 'crowd_noise'},
#    {'segment': [8.08, 9.08], 'label': 'crowd_noise'},
#    {'segment': [6.2, 9.08], 'label': 'stuck'}]},
#  'vid_765': {'duration_second': 11.48,
#   'duration_frame': 287,
#   'annotations': [{'segment': [0.04, 11.44], 'label': 'long_noise'},
#    {'segment': [3.32, 4.76], 'label': 'tyre_screech_noise'},
#    {'segment': [4.8, 5.6], 'label': 'crash'},
#    {'segment': [5.08, 5.56], 'label': 'crash_noise'},
#    {'segment': [5.44, 5.64], 'label': 'crowd_noise'},
#    {'segment': [8.4, 9.28], 'label': 'crowd_noise'}]},
#  'vid_767': {'duration_second': 9.32,
#   'duration_frame': 233,
#   'annotations': [{'segment': [0.04, 5.24], 'label': 'long_noise'},
#    {'segment': [7.44, 9.32], 'label': 'long_noise'},
#    {'segment': [5.28, 5.84], 'label': 'crash'},
#    {'segment': [5.28, 5.64], 'label': 'crash_noise'},
#    {'segment': [5.88, 6.04], 'label': 'tyre_screech_noise'},
#    {'segment': [5.88, 9.28], 'label': 'stuck'},
#    {'segment': [5.96, 9.28], 'label': 'crowd_noise'}]},
#  'vid_768': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': [{'segment': [0.04, 5.72], 'label': 'long_noise'},
#    {'segment': [7.24, 8.56], 'label': 'long_noise'},
#    {'segment': [5.72, 6.44], 'label': 'crash'},
#    {'segment': [2.72, 4.08], 'label': 'tyre_screech_noise'},
#    {'segment': [0.68, 1.84], 'label': 'turn'},
#    {'segment': [5.76, 6.92], 'label': 'crash_noise'},
#    {'segment': [6.6, 8.52], 'label': 'crowd_noise'}]},
#  'vid_769': {'duration_second': 4.92,
#   'duration_frame': 123,
#   'annotations': [{'segment': [0.04, 2.36], 'label': 'long_noise'},
#    {'segment': [1.2, 2.28], 'label': 'crash'},
#    {'segment': [0.48, 1.16], 'label': 'tyre_screech_noise'},
#    {'segment': [0.8, 1.16], 'label': 'spin'},
#    {'segment': [1.28, 2.32], 'label': 'crash_noise'},
#    {'segment': [2.32, 4.88], 'label': 'stuck'}]},
#  'vid_770': {'duration_second': 15.6,
#   'duration_frame': 390,
#   'annotations': [{'segment': [0.04, 15.56], 'label': 'long_noise'},
#    {'segment': [2.76, 3.16], 'label': 'tyre_screech_noise'},
#    {'segment': [1.76, 2.88], 'label': 'turn'},
#    {'segment': [3.2, 5.04], 'label': 'spin'},
#    {'segment': [5.92, 9.88], 'label': 'spin'},
#    {'segment': [3.64, 5.88], 'label': 'drift'},
#    {'segment': [9.92, 11.28], 'label': 'crash_noise'},
#    {'segment': [10.08, 10.96], 'label': 'crash'},
#    {'segment': [11.32, 12.36], 'label': 'stuck'}]},
#  'vid_772': {'duration_second': 11.76,
#   'duration_frame': 294,
#   'annotations': [{'segment': [0.04, 3.12], 'label': 'long_noise'},
#    {'segment': [6.0, 9.0], 'label': 'long_noise'},
#    {'segment': [0.6, 1.36], 'label': 'tyre_screech_noise'},
#    {'segment': [5.92, 6.52], 'label': 'tyre_screech_noise'},
#    {'segment': [1.04, 1.76], 'label': 'spin'},
#    {'segment': [1.76, 2.48], 'label': 'crash'},
#    {'segment': [8.08, 8.76], 'label': 'crash'},
#    {'segment': [1.76, 2.88], 'label': 'crash_noise'},
#    {'segment': [8.0, 8.68], 'label': 'crash_noise'},
#    {'segment': [2.92, 4.8], 'label': 'stuck'},
#    {'segment': [2.52, 4.76], 'label': 'crowd_noise'},
#    {'segment': [8.36, 11.72], 'label': 'crowd_noise'},
#    {'segment': [8.8, 11.72], 'label': 'breakdown'},
#    {'segment': [6.56, 8.04], 'label': 'drift'},
#    {'segment': [6.96, 7.72], 'label': 'cut'}]},
#  'vid_773': {'duration_second': 4.72,
#   'duration_frame': 118,
#   'annotations': [{'segment': [0.04, 0.64], 'label': 'long_noise'},
#    {'segment': [0.68, 1.52], 'label': 'tyre_screech_noise'},
#    {'segment': [1.56, 2.4], 'label': 'crash'},
#    {'segment': [2.44, 4.72], 'label': 'stuck'}]},
#  'vid_774': {'duration_second': 12.36,
#   'duration_frame': 309,
#   'annotations': [{'segment': [0.04, 0.72], 'label': 'long_noise'},
#    {'segment': [2.16, 3.04], 'label': 'long_noise'},
#    {'segment': [4.16, 7.28], 'label': 'long_noise'},
#    {'segment': [0.76, 2.12], 'label': 'turn'},
#    {'segment': [3.08, 4.12], 'label': 'turn'},
#    {'segment': [7.32, 11.96], 'label': 'crash'},
#    {'segment': [8.0, 10.64], 'label': 'crash_noise'},
#    {'segment': [12.0, 12.36], 'label': 'breakdown'},
#    {'segment': [10.96, 11.88], 'label': 'crowd_noise'}]},
#  'vid_775': {'duration_second': 10.64,
#   'duration_frame': 266,
#   'annotations': [{'segment': [0.04, 4.44], 'label': 'long_noise'},
#    {'segment': [8.32, 10.64], 'label': 'long_noise'},
#    {'segment': [2.4, 3.28], 'label': 'turn'},
#    {'segment': [3.32, 4.52], 'label': 'drift'},
#    {'segment': [4.56, 5.6], 'label': 'crash'},
#    {'segment': [5.08, 5.76], 'label': 'crash_noise'},
#    {'segment': [5.48, 8.12], 'label': 'crowd_noise'}]},
#  'vid_776': {'duration_second': 8.32,
#   'duration_frame': 208,
#   'annotations': [{'segment': [0.04, 5.28], 'label': 'long_noise'},
#    {'segment': [1.52, 2.64], 'label': 'tyre_screech_noise'},
#    {'segment': [4.44, 5.48], 'label': 'spin'},
#    {'segment': [5.52, 8.32], 'label': 'stuck'},
#    {'segment': [5.52, 8.32], 'label': 'breakdown'}]},
#  'vid_777': {'duration_second': 10.12,
#   'duration_frame': 253,
#   'annotations': [{'segment': [0.04, 10.12], 'label': 'long_noise'},
#    {'segment': [1.04, 2.0], 'label': 'turn'},
#    {'segment': [3.28, 3.88], 'label': 'turn'},
#    {'segment': [2.04, 3.24], 'label': 'crash'},
#    {'segment': [2.56, 3.16], 'label': 'crash_noise'},
#    {'segment': [9.12, 10.08], 'label': 'crowd_noise'}]},
#  'vid_778': {'duration_second': 12.16,
#   'duration_frame': 304,
#   'annotations': [{'segment': [0.04, 12.16], 'label': 'long_noise'},
#    {'segment': [1.8, 9.72], 'label': 'tyre_screech_noise'},
#    {'segment': [1.04, 1.68], 'label': 'turn'},
#    {'segment': [1.72, 2.16], 'label': 'crash'},
#    {'segment': [1.88, 2.16], 'label': 'crash_noise'}]},
#  'vid_779': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [1.08, 2.12], 'label': 'tyre_screech_noise'},
#    {'segment': [2.16, 2.8], 'label': 'crash'},
#    {'segment': [2.56, 3.16], 'label': 'crash_noise'},
#    {'segment': [3.2, 5.24], 'label': 'breakdown'},
#    {'segment': [0.84, 1.84], 'label': 'long_noise'}]},
#  'vid_780': {'duration_second': 7.76,
#   'duration_frame': 194,
#   'annotations': [{'segment': [0.04, 1.96], 'label': 'drift'},
#    {'segment': [0.04, 4.0], 'label': 'long_noise'},
#    {'segment': [6.16, 7.76], 'label': 'long_noise'},
#    {'segment': [2.0, 3.88], 'label': 'tyre_screech_noise'},
#    {'segment': [3.92, 7.76], 'label': 'stuck'}]},
#  'vid_781': {'duration_second': 5.28,
#   'duration_frame': 132,
#   'annotations': [{'segment': [0.04, 3.16], 'label': 'long_noise'},
#    {'segment': [0.48, 1.08], 'label': 'tyre_screech_noise'},
#    {'segment': [2.84, 3.44], 'label': 'tyre_screech_noise'},
#    {'segment': [1.12, 2.68], 'label': 'spin'},
#    {'segment': [2.72, 3.48], 'label': 'crash'},
#    {'segment': [3.52, 5.28], 'label': 'breakdown'}]},
#  'vid_782': {'duration_second': 2.8,
#   'duration_frame': 70,
#   'annotations': [{'segment': [0.04, 1.16], 'label': 'long_noise'}]},
#  'vid_783': {'duration_second': 8.6,
#   'duration_frame': 215,
#   'annotations': [{'segment': [0.04, 4.72], 'label': 'long_noise'},
#    {'segment': [4.76, 5.88], 'label': 'crash'},
#    {'segment': [4.24, 8.6], 'label': 'crowd_noise'},
#    {'segment': [5.92, 8.6], 'label': 'stuck'}]},
#  'vid_784': {'duration_second': 4.84,
#   'duration_frame': 121,
#   'annotations': [{'segment': [0.04, 1.16], 'label': 'long_noise'},
#    {'segment': [0.68, 2.48], 'label': 'spin'},
#    {'segment': [2.64, 4.84], 'label': 'crowd_noise'}]},
#  'vid_590': {'duration_second': 11.733333333333333,
#   'duration_frame': 352,
#   'annotations': [{'segment': [4.53, 11.73], 'label': 'long_noise'},
#    {'segment': [6.5, 8.57], 'label': 'drift'},
#    {'segment': [2.9, 5.07], 'label': 'turn'}]},
#  'vid_611': {'duration_second': 5.88,
#   'duration_frame': 147,
#   'annotations': [{'segment': [0.24, 5.88], 'label': 'long_noise'},
#    {'segment': [1.68, 3.52], 'label': 'spin'},
#    {'segment': [1.04, 1.56], 'label': 'tyre_screech_noise'}]},
#  'vid_613': {'duration_second': 9.2,
#   'duration_frame': 276,
#   'annotations': [{'segment': [1.4, 9.2], 'label': 'long_noise'},
#    {'segment': [3.57, 6.23], 'label': 'tyre_screech_noise'},
#    {'segment': [6.27, 8.27], 'label': 'drift'},
#    {'segment': [3.5, 4.1], 'label': 'turn'},
#    {'segment': [5.83, 6.77], 'label': 'spin'}]},
#  'vid_645': {'duration_second': 10.733333333333333,
#   'duration_frame': 322,
#   'annotations': [{'segment': [0.73, 10.73], 'label': 'long_noise'},
#    {'segment': [3.8, 5.03], 'label': 'turn'},
#    {'segment': [5.07, 5.83], 'label': 'tyre_screech_noise'},
#    {'segment': [6.1, 8.67], 'label': 'drift'}]},
#  'vid_707': {'duration_second': 7.766666666666667,
#   'duration_frame': 233,
#   'annotations': [{'segment': [0.03, 7.77], 'label': 'long_noise'},
#    {'segment': [1.17, 2.53], 'label': 'turn'},
#    {'segment': [5.87, 7.5], 'label': 'turn'},
#    {'segment': [2.57, 3.57], 'label': 'spin'},
#    {'segment': [3.6, 6.03], 'label': 'drift'}]},
#  'vid_708': {'duration_second': 8.666666666666666,
#   'duration_frame': 260,
#   'annotations': [{'segment': [0.03, 8.67], 'label': 'long_noise'},
#    {'segment': [1.8, 4.0], 'label': 'tyre_screech_noise'},
#    {'segment': [4.07, 5.83], 'label': 'drift'},
#    {'segment': [4.07, 5.83], 'label': 'spin'}]},
#  'vid_709': {'duration_second': 8.066666666666666,
#   'duration_frame': 242,
#   'annotations': [{'segment': [0.03, 8.07], 'label': 'long_noise'},
#    {'segment': [1.47, 3.67], 'label': 'tyre_screech_noise'},
#    {'segment': [3.7, 5.87], 'label': 'drift'},
#    {'segment': [5.6, 6.63], 'label': 'turn'}]},
#  'vid_710': {'duration_second': 10.033333333333333,
#   'duration_frame': 301,
#   'annotations': [{'segment': [0.03, 10.03], 'label': 'long_noise'},
#    {'segment': [3.93, 5.7], 'label': 'tyre_screech_noise'},
#    {'segment': [5.73, 6.97], 'label': 'drift'},
#    {'segment': [7.0, 8.67], 'label': 'turn'}]},
#  'vid_785': {'duration_second': 9.08,
#   'duration_frame': 227,
#   'annotations': [{'segment': [1.16, 2.48], 'label': 'jump'},
#    {'segment': [2.12, 7.28], 'label': 'crowd_noise'},
#    {'segment': [7.32, 8.16], 'label': 'drift'},
#    {'segment': [0.04, 9.04], 'label': 'long_noise'},
#    {'segment': [2.72, 3.96], 'label': 'turn'}]},
#  'vid_786': {'duration_second': 4.44,
#   'duration_frame': 111,
#   'annotations': [{'segment': [0.96, 2.04], 'label': 'jump'},
#    {'segment': [0.68, 4.44], 'label': 'crowd_noise'},
#    {'segment': [3.48, 4.2], 'label': 'tyre_screech_noise'}]},
#  'vid_787': {'duration_second': 11.8,
#   'duration_frame': 295,
#   'annotations': [{'segment': [0.04, 11.8], 'label': 'long_noise'},
#    {'segment': [1.68, 2.48], 'label': 'jump'},
#    {'segment': [2.84, 3.64], 'label': 'turn'},
#    {'segment': [8.12, 9.76], 'label': 'turn'},
#    {'segment': [4.2, 5.92], 'label': 'tyre_screech_noise'},
#    {'segment': [4.96, 6.2], 'label': 'drift'}]},
#  'vid_788': {'duration_second': 8.64,
#   'duration_frame': 216,
#   'annotations': [{'segment': [0.04, 8.64], 'label': 'long_noise'},
#    {'segment': [8.24, 8.64], 'label': 'crowd_noise'},
#    {'segment': [1.16, 1.88], 'label': 'jump'},
#    {'segment': [1.92, 3.04], 'label': 'spin'},
#    {'segment': [4.56, 5.48], 'label': 'spin'},
#    {'segment': [3.08, 4.52], 'label': 'drift'},
#    {'segment': [5.2, 5.68], 'label': 'turn'}]},
#  'vid_789': {'duration_second': 5.64,
#   'duration_frame': 141,
#   'annotations': [{'segment': [0.04, 5.64], 'label': 'long_noise'},
#    {'segment': [0.64, 1.52], 'label': 'jump'},
#    {'segment': [3.4, 4.56], 'label': 'turn'}]},
#  'vid_790': {'duration_second': 6.16,
#   'duration_frame': 154,
#   'annotations': [{'segment': [1.48, 2.84], 'label': 'jump'},
#    {'segment': [0.8, 6.16], 'label': 'long_noise'}]},
#  'vid_791': {'duration_second': 4.52,
#   'duration_frame': 113,
#   'annotations': [{'segment': [0.04, 4.52], 'label': 'long_noise'},
#    {'segment': [1.04, 2.04], 'label': 'jump'},
#    {'segment': [2.08, 2.88], 'label': 'drift'}]},
#  'vid_792': {'duration_second': 9.12,
#   'duration_frame': 228,
#   'annotations': [{'segment': [0.04, 9.12], 'label': 'long_noise'},
#    {'segment': [0.04, 3.16], 'label': 'crowd_noise'},
#    {'segment': [6.2, 9.12], 'label': 'crowd_noise'},
#    {'segment': [0.8, 1.64], 'label': 'turn'},
#    {'segment': [7.24, 8.44], 'label': 'turn'},
#    {'segment': [4.6, 5.72], 'label': 'jump'}]},
#  'vid_793': {'duration_second': 6.08,
#   'duration_frame': 152,
#   'annotations': [{'segment': [0.04, 6.08], 'label': 'crowd_noise'},
#    {'segment': [0.8, 2.04], 'label': 'jump'},
#    {'segment': [3.32, 5.52], 'label': 'long_noise'}]},
#  'vid_794': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [0.04, 2.64], 'label': 'crowd_noise'},
#    {'segment': [0.84, 1.88], 'label': 'jump'},
#    {'segment': [2.68, 5.92], 'label': 'long_noise'}]},
#  'vid_795': {'duration_second': 8.52,
#   'duration_frame': 213,
#   'annotations': [{'segment': [0.04, 8.52], 'label': 'long_noise'},
#    {'segment': [1.96, 2.96], 'label': 'jump'},
#    {'segment': [3.76, 4.36], 'label': 'jump'},
#    {'segment': [5.52, 6.16], 'label': 'jump'},
#    {'segment': [3.0, 3.72], 'label': 'turn'},
#    {'segment': [4.4, 4.84], 'label': 'drift'},
#    {'segment': [4.88, 5.48], 'label': 'spin'}]},
#  'vid_796': {'duration_second': 6.12,
#   'duration_frame': 153,
#   'annotations': [{'segment': [0.04, 1.0], 'label': 'crowd_noise'},
#    {'segment': [0.92, 2.28], 'label': 'jump'},
#    {'segment': [1.04, 6.12], 'label': 'long_noise'}]},
#  'vid_797': {'duration_second': 7.68,
#   'duration_frame': 192,
#   'annotations': [{'segment': [0.04, 4.48], 'label': 'crowd_noise'},
#    {'segment': [7.2, 7.52], 'label': 'crowd_noise'},
#    {'segment': [1.2, 2.24], 'label': 'jump'},
#    {'segment': [2.96, 3.8], 'label': 'jump'},
#    {'segment': [3.84, 4.96], 'label': 'turn'},
#    {'segment': [4.76, 7.68], 'label': 'long_noise'}]},
#  'vid_798': {'duration_second': 6.96,
#   'duration_frame': 174,
#   'annotations': [{'segment': [0.96, 1.84], 'label': 'jump'},
#    {'segment': [1.44, 3.96], 'label': 'crowd_noise'},
#    {'segment': [4.0, 4.72], 'label': 'turn'},
#    {'segment': [4.76, 5.64], 'label': 'drift'},
#    {'segment': [3.56, 6.96], 'label': 'long_noise'}]},
#  'vid_799': {'duration_second': 6.68,
#   'duration_frame': 167,
#   'annotations': [{'segment': [0.04, 1.8], 'label': 'crowd_noise'},
#    {'segment': [0.04, 6.68], 'label': 'long_noise'},
#    {'segment': [1.36, 2.72], 'label': 'jump'}]},
#  'vid_800': {'duration_second': 7.92,
#   'duration_frame': 198,
#   'annotations': [{'segment': [0.04, 7.92], 'label': 'long_noise'},
#    {'segment': [0.04, 0.32], 'label': 'crowd_noise'},
#    {'segment': [2.52, 3.12], 'label': 'crowd_noise'},
#    {'segment': [7.56, 7.84], 'label': 'crowd_noise'},
#    {'segment': [1.24, 2.44], 'label': 'spin'},
#    {'segment': [4.68, 5.44], 'label': 'spin'},
#    {'segment': [1.8, 2.48], 'label': 'jump'},
#    {'segment': [3.16, 4.28], 'label': 'drift'},
#    {'segment': [5.48, 6.72], 'label': 'turn'}]},
#  'vid_801': {'duration_second': 10.16,
#   'duration_frame': 254,
#   'annotations': [{'segment': [0.04, 10.16], 'label': 'long_noise'},
#    {'segment': [0.76, 1.48], 'label': 'turn'},
#    {'segment': [8.44, 9.72], 'label': 'turn'},
#    {'segment': [0.52, 2.32], 'label': 'crowd_noise'},
#    {'segment': [3.12, 5.48], 'label': 'crowd_noise'},
#    {'segment': [2.36, 3.24], 'label': 'jump'},
#    {'segment': [5.52, 6.8], 'label': 'tyre_screech_noise'}]},
#  'vid_802': {'duration_second': 9.72,
#   'duration_frame': 243,
#   'annotations': [{'segment': [0.04, 9.72], 'label': 'long_noise'},
#    {'segment': [3.8, 9.72], 'label': 'high_speed'},
#    {'segment': [1.16, 2.0], 'label': 'jump'},
#    {'segment': [2.52, 3.64], 'label': 'jump'},
#    {'segment': [1.92, 3.76], 'label': 'crowd_noise'}]},
#  'vid_803': {'duration_second': 5.92,
#   'duration_frame': 148,
#   'annotations': [{'segment': [0.04, 5.92], 'label': 'long_noise'},
#    {'segment': [1.12, 1.88], 'label': 'jump'},
#    {'segment': [1.92, 2.92], 'label': 'cut'}]},
#  'vid_804': {'duration_second': 12.2,
#   'duration_frame': 305,
#   'annotations': [{'segment': [0.04, 4.28], 'label': 'long_noise'},
#    {'segment': [7.52, 12.2], 'label': 'long_noise'},
#    {'segment': [4.12, 12.2], 'label': 'cut'},
#    {'segment': [1.36, 2.2], 'label': 'turn'},
#    {'segment': [2.24, 3.16], 'label': 'jump'},
#    {'segment': [3.2, 4.08], 'label': 'crash'},
#    {'segment': [3.2, 5.12], 'label': 'crash_noise'}]},
#  'vid_805': {'duration_second': 9.32,
#   'duration_frame': 233,
#   'annotations': [{'segment': [0.04, 2.72], 'label': 'long_noise'},
#    {'segment': [7.0, 9.32], 'label': 'long_noise'},
#    {'segment': [7.0, 8.8], 'label': 'tyre_screech_noise'},
#    {'segment': [7.0, 8.2], 'label': 'drift'},
#    {'segment': [1.76, 6.96], 'label': 'crowd_noise'},
#    {'segment': [1.32, 2.56], 'label': 'jump'},
#    {'segment': [3.44, 4.28], 'label': 'turn'}]},
#  'vid_806': {'duration_second': 5.44,
#   'duration_frame': 136,
#   'annotations': [{'segment': [0.04, 5.44], 'label': 'long_noise'},
#    {'segment': [0.72, 2.48], 'label': 'crowd_noise'},
#    {'segment': [4.52, 5.44], 'label': 'crowd_noise'},
#    {'segment': [1.44, 2.56], 'label': 'jump'}]},
#  'vid_807': {'duration_second': 12.92,
#   'duration_frame': 323,
#   'annotations': [{'segment': [0.04, 12.92], 'label': 'long_noise'},
#    {'segment': [1.52, 2.4], 'label': 'jump'},
#    {'segment': [3.0, 3.76], 'label': 'crowd_noise'},
#    {'segment': [2.76, 3.24], 'label': 'turn'},
#    {'segment': [3.8, 4.6], 'label': 'turn'},
#    {'segment': [8.48, 9.6], 'label': 'turn'},
#    {'segment': [4.64, 6.52], 'label': 'tyre_screech_noise'}]},
#  'vid_808': {'duration_second': 8.2,
#   'duration_frame': 205,
#   'annotations': [{'segment': [0.04, 8.2], 'label': 'long_noise'},
#    {'segment': [1.16, 1.96], 'label': 'jump'},
#    {'segment': [4.48, 6.64], 'label': 'jump'},
#    {'segment': [2.0, 4.44], 'label': 'tyre_screech_noise'},
#    {'segment': [2.04, 2.6], 'label': 'drift'}]},
#  'vid_809': {'duration_second': 8.52,
#   'duration_frame': 213,
#   'annotations': [{'segment': [0.04, 8.52], 'label': 'long_noise'},
#    {'segment': [2.36, 3.24], 'label': 'jump'},
#    {'segment': [3.28, 4.4], 'label': 'turn'},
#    {'segment': [4.44, 5.76], 'label': 'tyre_screech_noise'},
#    {'segment': [4.64, 5.88], 'label': 'drift'}]},
#  'vid_810': {'duration_second': 5.28,
#   'duration_frame': 132,
#   'annotations': [{'segment': [0.04, 5.28], 'label': 'long_noise'},
#    {'segment': [2.36, 3.08], 'label': 'jump'},
#    {'segment': [3.12, 3.92], 'label': 'tyre_screech_noise'},
#    {'segment': [3.16, 4.04], 'label': 'drift'}]},
#  'vid_811': {'duration_second': 5.56,
#   'duration_frame': 139,
#   'annotations': [{'segment': [0.04, 5.56], 'label': 'long_noise'},
#    {'segment': [0.4, 1.0], 'label': 'crowd_noise'},
#    {'segment': [2.8, 5.56], 'label': 'crowd_noise'},
#    {'segment': [1.12, 2.28], 'label': 'jump'}]},
#  'vid_812': {'duration_second': 9.64,
#   'duration_frame': 241,
#   'annotations': [{'segment': [0.04, 1.0], 'label': 'crowd_noise'},
#    {'segment': [1.68, 3.48], 'label': 'crowd_noise'},
#    {'segment': [4.12, 4.44], 'label': 'crowd_noise'},
#    {'segment': [5.52, 9.64], 'label': 'crowd_noise'},
#    {'segment': [0.12, 2.04], 'label': 'long_noise'},
#    {'segment': [4.12, 9.64], 'label': 'long_noise'},
#    {'segment': [1.04, 1.64], 'label': 'jump'},
#    {'segment': [3.52, 4.16], 'label': 'turn'},
#    {'segment': [6.56, 7.72], 'label': 'turn'},
#    {'segment': [4.48, 4.96], 'label': 'drift'},
#    {'segment': [5.0, 5.48], 'label': 'spin'}]},
#  'vid_813': {'duration_second': 7.84,
#   'duration_frame': 196,
#   'annotations': [{'segment': [0.04, 7.84], 'label': 'long_noise'},
#    {'segment': [0.8, 1.48], 'label': 'jump'},
#    {'segment': [6.32, 7.0], 'label': 'turn'},
#    {'segment': [0.24, 1.4], 'label': 'crowd_noise'}]},
#  'vid_814': {'duration_second': 5.72,
#   'duration_frame': 143,
#   'annotations': [{'segment': [0.04, 5.72], 'label': 'long_noise'},
#    {'segment': [0.88, 1.76], 'label': 'jump'},
#    {'segment': [1.8, 2.8], 'label': 'drift'}]},
#  'vid_815': {'duration_second': 5.48,
#   'duration_frame': 137,
#   'annotations': [{'segment': [0.04, 0.84], 'label': 'tyre_screech_noise'},
#    {'segment': [1.8, 2.96], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 3.6], 'label': 'long_noise'},
#    {'segment': [4.44, 5.48], 'label': 'long_noise'},
#    {'segment': [0.88, 1.76], 'label': 'jump'},
#    {'segment': [3.64, 4.4], 'label': 'turn'}]},
#  'vid_816': {'duration_second': 9.48,
#   'duration_frame': 237,
#   'annotations': [{'segment': [0.04, 1.88], 'label': 'crowd_noise'},
#    {'segment': [2.88, 4.52], 'label': 'crowd_noise'},
#    {'segment': [1.92, 2.84], 'label': 'jump'},
#    {'segment': [4.56, 9.48], 'label': 'long_noise'},
#    {'segment': [7.4, 9.04], 'label': 'turn'}]},
#  'vid_817': {'duration_second': 6.8,
#   'duration_frame': 170,
#   'annotations': [{'segment': [0.04, 4.68], 'label': 'long_noise'},
#    {'segment': [5.92, 6.8], 'label': 'long_noise'},
#    {'segment': [0.92, 2.0], 'label': 'jump'},
#    {'segment': [4.72, 5.88], 'label': 'tyre_screech_noise'}]},
#  'vid_818': {'duration_second': 10.4,
#   'duration_frame': 312,
#   'annotations': [{'segment': [0.33, 3.23], 'label': 'crowd_noise'},
#    {'segment': [4.53, 5.07], 'label': 'crowd_noise'},
#    {'segment': [3.27, 4.1], 'label': 'drift'},
#    {'segment': [4.13, 5.0], 'label': 'turn'},
#    {'segment': [9.33, 10.07], 'label': 'turn'},
#    {'segment': [2.4, 10.4], 'label': 'long_noise'},
#    {'segment': [6.73, 8.13], 'label': 'spin'}]},
#  'vid_819': {'duration_second': 9.4,
#   'duration_frame': 235,
#   'annotations': [{'segment': [0.04, 3.44], 'label': 'crowd_noise'},
#    {'segment': [8.4, 9.4], 'label': 'crowd_noise'},
#    {'segment': [3.96, 9.4], 'label': 'long_noise'},
#    {'segment': [3.44, 4.72], 'label': 'tyre_screech_noise'},
#    {'segment': [1.12, 2.24], 'label': 'jump'},
#    {'segment': [2.28, 3.4], 'label': 'turn'},
#    {'segment': [6.0, 6.56], 'label': 'turn'},
#    {'segment': [4.76, 6.16], 'label': 'spin'}]},
#  'vid_820': {'duration_second': 7.72,
#   'duration_frame': 193,
#   'annotations': [{'segment': [0.04, 7.72], 'label': 'long_noise'},
#    {'segment': [2.44, 7.72], 'label': 'crowd_noise'},
#    {'segment': [1.08, 2.32], 'label': 'jump'}]},
#  'vid_821': {'duration_second': 8.64,
#   'duration_frame': 216,
#   'annotations': [{'segment': [0.04, 8.64], 'label': 'long_noise'},
#    {'segment': [0.8, 4.24], 'label': 'crowd_noise'},
#    {'segment': [5.24, 8.64], 'label': 'crowd_noise'},
#    {'segment': [1.44, 2.48], 'label': 'jump'},
#    {'segment': [4.4, 5.2], 'label': 'jump'},
#    {'segment': [3.32, 4.36], 'label': 'tyre_screech_noise'}]},
#  'vid_822': {'duration_second': 7.64,
#   'duration_frame': 191,
#   'annotations': [{'segment': [0.04, 7.64], 'label': 'long_noise'},
#    {'segment': [1.08, 1.92], 'label': 'jump'},
#    {'segment': [3.24, 4.0], 'label': 'turn'},
#    {'segment': [4.04, 5.44], 'label': 'tyre_screech_noise'}]},
#  'vid_823': {'duration_second': 10.36,
#   'duration_frame': 259,
#   'annotations': [{'segment': [0.04, 10.36], 'label': 'long_noise'},
#    {'segment': [1.0, 2.08], 'label': 'jump'},
#    {'segment': [2.12, 2.6], 'label': 'spin'},
#    {'segment': [1.48, 3.64], 'label': 'crowd_noise'},
#    {'segment': [4.04, 4.6], 'label': 'turn'}]},
#  'vid_824': {'duration_second': 6.52,
#   'duration_frame': 163,
#   'annotations': [{'segment': [0.04, 6.52], 'label': 'long_noise'},
#    {'segment': [0.88, 1.76], 'label': 'jump'},
#    {'segment': [4.32, 5.48], 'label': 'turn'}]},
#  'vid_825': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': [{'segment': [0.04, 8.56], 'label': 'long_noise'},
#    {'segment': [1.0, 1.8], 'label': 'jump'},
#    {'segment': [7.0, 7.72], 'label': 'jump'},
#    {'segment': [4.2, 5.36], 'label': 'tyre_screech_noise'},
#    {'segment': [4.24, 5.52], 'label': 'drift'}]},
#  'vid_826': {'duration_second': 8.68,
#   'duration_frame': 217,
#   'annotations': [{'segment': [0.04, 8.68], 'label': 'long_noise'},
#    {'segment': [2.6, 3.28], 'label': 'jump'},
#    {'segment': [1.08, 1.72], 'label': 'turn'},
#    {'segment': [5.8, 7.76], 'label': 'turn'}]},
#  'vid_827': {'duration_second': 12.56,
#   'duration_frame': 314,
#   'annotations': [{'segment': [0.04, 12.56], 'label': 'long_noise'},
#    {'segment': [1.84, 2.72], 'label': 'jump'},
#    {'segment': [2.72, 3.36], 'label': 'crowd_noise'},
#    {'segment': [3.96, 4.92], 'label': 'turn'}]},
#  'vid_828': {'duration_second': 4.88,
#   'duration_frame': 122,
#   'annotations': [{'segment': [0.04, 4.88], 'label': 'long_noise'},
#    {'segment': [0.84, 1.84], 'label': 'jump'},
#    {'segment': [2.84, 3.88], 'label': 'crowd_noise'}]},
#  'vid_829': {'duration_second': 5.96,
#   'duration_frame': 149,
#   'annotations': [{'segment': [0.04, 5.96], 'label': 'long_noise'},
#    {'segment': [1.8, 2.76], 'label': 'jump'}]},
#  'vid_830': {'duration_second': 10.24,
#   'duration_frame': 256,
#   'annotations': [{'segment': [0.04, 8.0], 'label': 'long_noise'},
#    {'segment': [9.12, 10.24], 'label': 'long_noise'},
#    {'segment': [1.24, 2.12], 'label': 'jump'},
#    {'segment': [1.52, 4.04], 'label': 'crowd_noise'},
#    {'segment': [8.04, 9.08], 'label': 'turn'}]},
#  'vid_831': {'duration_second': 6.4,
#   'duration_frame': 160,
#   'annotations': [{'segment': [0.04, 6.4], 'label': 'long_noise'},
#    {'segment': [1.08, 1.88], 'label': 'jump'}]},
#  'vid_832': {'duration_second': 11.0,
#   'duration_frame': 275,
#   'annotations': [{'segment': [0.04, 11.0], 'label': 'long_noise'},
#    {'segment': [2.28, 3.48], 'label': 'turn'},
#    {'segment': [3.52, 4.72], 'label': 'jump'},
#    {'segment': [4.76, 5.2], 'label': 'spin'},
#    {'segment': [5.2, 5.52], 'label': 'tyre_screech_noise'},
#    {'segment': [5.24, 6.72], 'label': 'drift'},
#    {'segment': [3.56, 6.4], 'label': 'crowd_noise'}]},
#  'vid_833': {'duration_second': 8.4,
#   'duration_frame': 210,
#   'annotations': [{'segment': [0.04, 8.4], 'label': 'long_noise'},
#    {'segment': [3.04, 3.92], 'label': 'jump'},
#    {'segment': [5.36, 6.24], 'label': 'turn'},
#    {'segment': [6.16, 7.52], 'label': 'crowd_noise'}]},
#  'vid_834': {'duration_second': 6.88,
#   'duration_frame': 172,
#   'annotations': [{'segment': [0.04, 6.88], 'label': 'long_noise'},
#    {'segment': [1.48, 2.24], 'label': 'jump'},
#    {'segment': [3.24, 4.92], 'label': 'spin'}]},
#  'vid_835': {'duration_second': 6.2,
#   'duration_frame': 155,
#   'annotations': [{'segment': [0.04, 6.2], 'label': 'long_noise'},
#    {'segment': [1.28, 2.12], 'label': 'jump'}]},
#  'vid_836': {'duration_second': 3.96,
#   'duration_frame': 99,
#   'annotations': [{'segment': [0.04, 3.96], 'label': 'long_noise'},
#    {'segment': [1.08, 2.12], 'label': 'jump'},
#    {'segment': [1.6, 2.28], 'label': 'crowd_noise'}]},
#  'vid_837': {'duration_second': 5.16,
#   'duration_frame': 129,
#   'annotations': [{'segment': [0.04, 5.16], 'label': 'long_noise'},
#    {'segment': [1.12, 2.08], 'label': 'jump'},
#    {'segment': [2.12, 3.08], 'label': 'tyre_screech_noise'}]},
#  'vid_838': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': [{'segment': [0.04, 13.08], 'label': 'long_noise'},
#    {'segment': [4.92, 5.68], 'label': 'jump'},
#    {'segment': [5.72, 6.16], 'label': 'drift'},
#    {'segment': [6.2, 7.0], 'label': 'spin'},
#    {'segment': [8.16, 8.88], 'label': 'spin'},
#    {'segment': [5.6, 12.68], 'label': 'crowd_noise'}]},
#  'vid_839': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': [{'segment': [0.04, 9.16], 'label': 'long_noise'},
#    {'segment': [1.32, 2.24], 'label': 'jump'},
#    {'segment': [4.8, 5.8], 'label': 'jump'},
#    {'segment': [2.28, 3.44], 'label': 'drift'},
#    {'segment': [5.84, 6.36], 'label': 'drift'},
#    {'segment': [2.48, 3.12], 'label': 'tyre_screech_noise'},
#    {'segment': [5.84, 6.36], 'label': 'tyre_screech_noise'}]},
#  'vid_840': {'duration_second': 8.32,
#   'duration_frame': 208,
#   'annotations': [{'segment': [0.04, 1.72], 'label': 'crowd_noise'},
#    {'segment': [2.76, 3.6], 'label': 'crowd_noise'},
#    {'segment': [5.84, 8.32], 'label': 'crowd_noise'},
#    {'segment': [0.04, 8.32], 'label': 'long_noise'},
#    {'segment': [1.76, 2.72], 'label': 'jump'}]},
#  'vid_841': {'duration_second': 9.52,
#   'duration_frame': 238,
#   'annotations': [{'segment': [0.04, 1.28], 'label': 'crowd_noise'},
#    {'segment': [2.8, 3.52], 'label': 'crowd_noise'},
#    {'segment': [4.64, 8.12], 'label': 'crowd_noise'},
#    {'segment': [0.04, 9.52], 'label': 'long_noise'},
#    {'segment': [1.32, 2.76], 'label': 'jump'},
#    {'segment': [3.56, 4.6], 'label': 'turn'}]},
#  'vid_842': {'duration_second': 7.2,
#   'duration_frame': 180,
#   'annotations': [{'segment': [0.04, 1.84], 'label': 'tyre_screech_noise'},
#    {'segment': [0.04, 7.2], 'label': 'long_noise'},
#    {'segment': [1.88, 2.92], 'label': 'jump'},
#    {'segment': [2.76, 3.8], 'label': 'crowd_noise'},
#    {'segment': [4.76, 5.72], 'label': 'turn'}]},
#  'vid_843': {'duration_second': 7.56,
#   'duration_frame': 189,
#   'annotations': [{'segment': [0.04, 1.04], 'label': 'crowd_noise'},
#    {'segment': [5.48, 7.56], 'label': 'crowd_noise'},
#    {'segment': [0.04, 7.56], 'label': 'long_noise'},
#    {'segment': [1.08, 2.04], 'label': 'jump'}]},
#  'vid_844': {'duration_second': 5.24,
#   'duration_frame': 131,
#   'annotations': [{'segment': [0.04, 0.48], 'label': 'crowd_noise'},
#    {'segment': [3.56, 5.24], 'label': 'crowd_noise'},
#    {'segment': [0.04, 3.52], 'label': 'long_noise'},
#    {'segment': [0.52, 1.76], 'label': 'jump'}]},
#  'vid_845': {'duration_second': 7.88,
#   'duration_frame': 197,
#   'annotations': [{'segment': [0.04, 1.52], 'label': 'crowd_noise'},
#    {'segment': [5.92, 7.88], 'label': 'crowd_noise'},
#    {'segment': [1.64, 7.88], 'label': 'long_noise'},
#    {'segment': [1.56, 2.92], 'label': 'jump'}]},
#  'vid_846': {'duration_second': 6.8,
#   'duration_frame': 170,
#   'annotations': [{'segment': [0.04, 6.8], 'label': 'long_noise'},
#    {'segment': [1.56, 2.48], 'label': 'jump'},
#    {'segment': [2.84, 3.56], 'label': 'turn'}]},
#  'vid_847': {'duration_second': 5.56,
#   'duration_frame': 139,
#   'annotations': [{'segment': [0.44, 1.68], 'label': 'jump'},
#    {'segment': [1.12, 2.4], 'label': 'crowd_noise'},
#    {'segment': [0.04, 5.56], 'label': 'long_noise'}]},
#  'vid_848': {'duration_second': 9.2,
#   'duration_frame': 230,
#   'annotations': [{'segment': [0.04, 9.2], 'label': 'long_noise'},
#    {'segment': [1.08, 1.8], 'label': 'jump'},
#    {'segment': [1.8, 3.28], 'label': 'crowd_noise'},
#    {'segment': [3.68, 4.36], 'label': 'turn'},
#    {'segment': [6.96, 7.56], 'label': 'turn'}]},
#  'vid_849': {'duration_second': 7.52,
#   'duration_frame': 188,
#   'annotations': [{'segment': [0.04, 1.64], 'label': 'crowd_noise'},
#    {'segment': [2.24, 4.16], 'label': 'crowd_noise'},
#    {'segment': [6.52, 7.52], 'label': 'crowd_noise'},
#    {'segment': [1.0, 7.52], 'label': 'long_noise'},
#    {'segment': [1.68, 2.72], 'label': 'jump'},
#    {'segment': [2.76, 3.36], 'label': 'tyre_screech_noise'},
#    {'segment': [3.4, 4.6], 'label': 'drift'}]},
#  'vid_850': {'duration_second': 6.64,
#   'duration_frame': 166,
# ...
#    {'segment': [15.52, 16.88], 'label': 'turn'}]},
#  'vid_965': {'duration_second': 17.84,
#   'duration_frame': 446,
#   'annotations': [{'segment': [2.04, 17.84], 'label': 'long_noise'},
#    {'segment': [8.04, 8.96], 'label': 'turn'},
#    {'segment': [10.04, 11.72], 'label': 'turn'},
#    {'segment': [10.16, 11.56], 'label': 'tyre_screech_noise'},
#    {'segment': [10.68, 11.6], 'label': 'drift'}]},
#  'vid_966': {'duration_second': 17.96,
#   'duration_frame': 449,
#   'annotations': [{'segment': [0.04, 17.96], 'label': 'long_noise'},
#    {'segment': [2.0, 3.08], 'label': 'turn'},
#    {'segment': [4.16, 5.16], 'label': 'turn'},
#    {'segment': [9.0, 10.0], 'label': 'turn'},
#    {'segment': [14.72, 15.88], 'label': 'turn'}]},
#  'vid_967': {'duration_second': 29.12,
#   'duration_frame': 728,
#   'annotations': [{'segment': [1.32, 29.12], 'label': 'long_noise'},
#    {'segment': [7.68, 8.28], 'label': 'turn'},
#    {'segment': [9.52, 11.12], 'label': 'turn'},
#    {'segment': [20.68, 21.68], 'label': 'turn'},
#    {'segment': [23.12, 25.0], 'label': 'turn'},
#    {'segment': [9.32, 10.92], 'label': 'tyre_screech_noise'},
#    {'segment': [22.56, 23.96], 'label': 'tyre_screech_noise'},
#    {'segment': [10.84, 11.56], 'label': 'drift'}]},
#  'vid_968': {'duration_second': 9.44,
#   'duration_frame': 236,
#   'annotations': [{'segment': [0.04, 9.44], 'label': 'long_noise'},
#    {'segment': [0.8, 1.68], 'label': 'turn'},
#    {'segment': [7.92, 9.16], 'label': 'turn'}]},
#  'vid_969': {'duration_second': 16.68,
#   'duration_frame': 417,
#   'annotations': [{'segment': [0.04, 16.68], 'label': 'long_noise'},
#    {'segment': [1.52, 2.84], 'label': 'turn'},
#    {'segment': [3.6, 4.84], 'label': 'turn'},
#    {'segment': [8.4, 9.2], 'label': 'turn'},
#    {'segment': [14.12, 15.16], 'label': 'turn'}]},
#  'vid_970': {'duration_second': 16.32,
#   'duration_frame': 408,
#   'annotations': [{'segment': [0.04, 16.32], 'label': 'long_noise'},
#    {'segment': [1.72, 2.88], 'label': 'turn'},
#    {'segment': [3.36, 4.44], 'label': 'turn'},
#    {'segment': [8.08, 8.96], 'label': 'turn'},
#    {'segment': [13.28, 14.28], 'label': 'turn'}]},
#  'vid_971': {'duration_second': 16.52,
#   'duration_frame': 413,
#   'annotations': [{'segment': [0.04, 16.52], 'label': 'long_noise'},
#    {'segment': [8.48, 9.32], 'label': 'turn'},
#    {'segment': [10.36, 11.4], 'label': 'turn'},
#    {'segment': [10.56, 11.48], 'label': 'tyre_screech_noise'}]},
#  'vid_972': {'duration_second': 7.28,
#   'duration_frame': 182,
#   'annotations': [{'segment': [0.04, 7.28], 'label': 'long_noise'}]},
#  'vid_973': {'duration_second': 11.96,
#   'duration_frame': 299,
#   'annotations': [{'segment': [0.96, 11.96], 'label': 'long_noise'},
#    {'segment': [5.68, 6.4], 'label': 'turn'},
#    {'segment': [8.36, 9.48], 'label': 'turn'}]},
#  'vid_974': {'duration_second': 16.96,
#   'duration_frame': 424,
#   'annotations': [{'segment': [0.04, 16.96], 'label': 'long_noise'},
#    {'segment': [1.4, 2.6], 'label': 'turn'},
#    {'segment': [3.52, 4.92], 'label': 'turn'},
#    {'segment': [8.48, 9.2], 'label': 'turn'},
#    {'segment': [13.64, 14.36], 'label': 'turn'}]},
#  'vid_975': {'duration_second': 14.72,
#   'duration_frame': 368,
#   'annotations': [{'segment': [1.84, 14.72], 'label': 'long_noise'},
#    {'segment': [7.44, 8.52], 'label': 'turn'},
#    {'segment': [9.48, 10.56], 'label': 'turn'}]},
#  'vid_976': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': [{'segment': [1.08, 12.08], 'label': 'long_noise'},
#    {'segment': [2.8, 3.56], 'label': 'turn'},
#    {'segment': [4.32, 4.88], 'label': 'turn'},
#    {'segment': [10.52, 11.4], 'label': 'turn'}]},
#  'vid_977': {'duration_second': 5.8,
#   'duration_frame': 145,
#   'annotations': [{'segment': [0.04, 5.8], 'label': 'long_noise'}]},
#  'vid_978': {'duration_second': 13.52,
#   'duration_frame': 338,
#   'annotations': [{'segment': [0.04, 13.52], 'label': 'long_noise'},
#    {'segment': [0.76, 2.0], 'label': 'drift'},
#    {'segment': [5.08, 6.44], 'label': 'turn'},
#    {'segment': [7.28, 8.64], 'label': 'turn'}]},
#  'vid_979': {'duration_second': 17.52,
#   'duration_frame': 438,
#   'annotations': [{'segment': [0.08, 17.52], 'label': 'long_noise'},
#    {'segment': [2.28, 3.84], 'label': 'turn'},
#    {'segment': [4.84, 6.36], 'label': 'turn'},
#    {'segment': [9.84, 11.08], 'label': 'turn'},
#    {'segment': [15.48, 16.44], 'label': 'turn'}]},
#  'vid_980': {'duration_second': 16.8,
#   'duration_frame': 420,
#   'annotations': [{'segment': [0.04, 1.04], 'label': 'turn'},
#    {'segment': [2.48, 3.4], 'label': 'turn'},
#    {'segment': [6.56, 7.64], 'label': 'turn'},
#    {'segment': [12.08, 13.12], 'label': 'turn'},
#    {'segment': [0.04, 16.8], 'label': 'long_noise'}]},
#  'vid_981': {'duration_second': 15.28,
#   'duration_frame': 382,
#   'annotations': [{'segment': [0.04, 15.28], 'label': 'long_noise'},
#    {'segment': [7.36, 8.28], 'label': 'turn'},
#    {'segment': [9.2, 10.36], 'label': 'turn'},
#    {'segment': [10.0, 11.32], 'label': 'drift'},
#    {'segment': [8.88, 9.84], 'label': 'tyre_screech_noise'}]},
#  'vid_982': {'duration_second': 6.24,
#   'duration_frame': 156,
#   'annotations': [{'segment': [0.04, 6.24], 'label': 'long_noise'}]},
#  'vid_983': {'duration_second': 13.92,
#   'duration_frame': 348,
#   'annotations': [{'segment': [0.04, 13.92], 'label': 'long_noise'},
#    {'segment': [5.84, 7.12], 'label': 'turn'},
#    {'segment': [9.0, 9.88], 'label': 'turn'}]},
#  'vid_984': {'duration_second': 18.16,
#   'duration_frame': 454,
#   'annotations': [{'segment': [0.04, 18.16], 'label': 'long_noise'},
#    {'segment': [2.08, 2.84], 'label': 'turn'},
#    {'segment': [4.04, 5.2], 'label': 'turn'},
#    {'segment': [8.72, 9.68], 'label': 'turn'},
#    {'segment': [13.88, 14.64], 'label': 'turn'}]},
#  'vid_985': {'duration_second': 14.8,
#   'duration_frame': 370,
#   'annotations': [{'segment': [0.04, 14.8], 'label': 'long_noise'},
#    {'segment': [7.88, 8.36], 'label': 'turn'},
#    {'segment': [9.64, 10.72], 'label': 'turn'}]},
#  'vid_986': {'duration_second': 9.2,
#   'duration_frame': 230,
#   'annotations': [{'segment': [0.04, 9.2], 'label': 'long_noise'},
#    {'segment': [4.08, 5.0], 'label': 'turn'},
#    {'segment': [7.92, 9.2], 'label': 'turn'},
#    {'segment': [3.24, 4.32], 'label': 'tyre_screech_noise'}]},
#  'vid_987': {'duration_second': 8.56,
#   'duration_frame': 214,
#   'annotations': [{'segment': [0.04, 8.56], 'label': 'long_noise'},
#    {'segment': [0.68, 1.52], 'label': 'turn'},
#    {'segment': [7.64, 8.56], 'label': 'turn'}]},
#  'vid_988': {'duration_second': 6.28,
#   'duration_frame': 157,
#   'annotations': [{'segment': [0.04, 6.28], 'label': 'long_noise'}]},
#  'vid_989': {'duration_second': 11.12,
#   'duration_frame': 278,
#   'annotations': [{'segment': [0.04, 11.12], 'label': 'long_noise'},
#    {'segment': [4.92, 6.16], 'label': 'turn'},
#    {'segment': [8.48, 9.6], 'label': 'turn'},
#    {'segment': [4.92, 6.2], 'label': 'drift'}]},
#  'vid_990': {'duration_second': 16.24,
#   'duration_frame': 406,
#   'annotations': [{'segment': [0.04, 16.24], 'label': 'long_noise'},
#    {'segment': [1.32, 2.24], 'label': 'turn'},
#    {'segment': [3.24, 4.72], 'label': 'turn'},
#    {'segment': [8.04, 8.72], 'label': 'turn'},
#    {'segment': [13.44, 14.04], 'label': 'turn'}]},
#  'vid_991': {'duration_second': 14.48,
#   'duration_frame': 362,
#   'annotations': [{'segment': [0.04, 14.48], 'label': 'long_noise'},
#    {'segment': [6.72, 7.6], 'label': 'turn'},
#    {'segment': [8.68, 9.48], 'label': 'turn'},
#    {'segment': [8.88, 9.64], 'label': 'tyre_screech_noise'}]},
#  'vid_992': {'duration_second': 12.68,
#   'duration_frame': 317,
#   'annotations': [{'segment': [0.92, 12.68], 'label': 'long_noise'},
#    {'segment': [3.36, 3.68], 'label': 'turn'},
#    {'segment': [4.52, 5.64], 'label': 'turn'}]},
#  'vid_993': {'duration_second': 6.52,
#   'duration_frame': 163,
#   'annotations': [{'segment': [0.04, 6.52], 'label': 'long_noise'}]},
#  'vid_994': {'duration_second': 13.24,
#   'duration_frame': 331,
#   'annotations': [{'segment': [0.04, 13.24], 'label': 'long_noise'},
#    {'segment': [8.56, 9.36], 'label': 'turn'},
#    {'segment': [4.92, 6.48], 'label': 'drift'}]},
#  'vid_995': {'duration_second': 17.24,
#   'duration_frame': 431,
#   'annotations': [{'segment': [0.04, 17.24], 'label': 'long_noise'},
#    {'segment': [1.72, 2.8], 'label': 'turn'},
#    {'segment': [3.88, 5.08], 'label': 'turn'},
#    {'segment': [8.48, 9.24], 'label': 'turn'},
#    {'segment': [13.88, 14.68], 'label': 'turn'}]},
#  'vid_996': {'duration_second': 15.44,
#   'duration_frame': 386,
#   'annotations': [{'segment': [0.04, 1.12], 'label': 'turn'},
#    {'segment': [2.08, 3.16], 'label': 'turn'},
#    {'segment': [6.32, 6.92], 'label': 'turn'},
#    {'segment': [11.28, 12.08], 'label': 'turn'},
#    {'segment': [0.04, 15.44], 'label': 'long_noise'}]},
#  'vid_997': {'duration_second': 23.16,
#   'duration_frame': 579,
#   'annotations': [{'segment': [0.04, 8.2], 'label': 'long_noise'},
#    {'segment': [8.84, 9.8], 'label': 'long_noise'},
#    {'segment': [10.88, 14.12], 'label': 'long_noise'},
#    {'segment': [14.76, 15.88], 'label': 'long_noise'},
#    {'segment': [16.36, 17.4], 'label': 'long_noise'},
#    {'segment': [18.2, 23.16], 'label': 'long_noise'},
#    {'segment': [8.24, 8.8], 'label': 'turn'},
#    {'segment': [9.84, 10.68], 'label': 'turn'},
#    {'segment': [15.92, 16.32], 'label': 'turn'},
#    {'segment': [17.44, 18.16], 'label': 'turn'},
#    {'segment': [9.72, 10.56], 'label': 'tyre_screech_noise'},
#    {'segment': [17.04, 18.04], 'label': 'tyre_screech_noise'},
#    {'segment': [10.24, 10.84], 'label': 'drift'}]},
#  'vid_998': {'duration_second': 16.76,
#   'duration_frame': 419,
#   'annotations': [{'segment': [1.32, 2.6], 'label': 'turn'},
#    {'segment': [3.6, 4.96], 'label': 'turn'},
#    {'segment': [8.24, 8.96], 'label': 'turn'},
#    {'segment': [13.6, 14.52], 'label': 'turn'},
#    {'segment': [0.68, 16.76], 'label': 'long_noise'}]},
#  'vid_999': {'duration_second': 9.16,
#   'duration_frame': 229,
#   'annotations': [{'segment': [0.04, 1.52], 'label': 'turn'},
#    {'segment': [8.0, 9.16], 'label': 'turn'},
#    {'segment': [0.04, 9.16], 'label': 'long_noise'}]},
#  'vid_1000': {'duration_second': 14.52,
#   'duration_frame': 363,
#   'annotations': [{'segment': [0.04, 14.52], 'label': 'long_noise'},
#    {'segment': [6.04, 7.08], 'label': 'turn'},
#    {'segment': [8.6, 9.52], 'label': 'turn'}]},
#  'vid_1001': {'duration_second': 16.12,
#   'duration_frame': 403,
#   'annotations': [{'segment': [0.04, 16.12], 'label': 'long_noise'},
#    {'segment': [1.48, 2.8], 'label': 'turn'},
#    {'segment': [3.76, 5.04], 'label': 'turn'},
#    {'segment': [8.4, 9.24], 'label': 'turn'},
#    {'segment': [13.68, 14.32], 'label': 'turn'}]},
#  'vid_1002': {'duration_second': 12.08,
#   'duration_frame': 302,
#   'annotations': [{'segment': [0.04, 12.08], 'label': 'long_noise'},
#    {'segment': [2.64, 3.2], 'label': 'turn'},
#    {'segment': [4.12, 4.76], 'label': 'turn'},
#    {'segment': [11.04, 12.08], 'label': 'turn'}]},
#  'vid_1003': {'duration_second': 11.56,
#   'duration_frame': 289,
#   'annotations': [{'segment': [0.04, 11.56], 'label': 'long_noise'},
#    {'segment': [5.04, 6.32], 'label': 'turn'},
#    {'segment': [8.36, 9.6], 'label': 'turn'},
#    {'segment': [4.2, 7.12], 'label': 'drift'}]},
#  'vid_1004': {'duration_second': 19.08,
#   'duration_frame': 477,
#   'annotations': [{'segment': [0.04, 19.08], 'label': 'long_noise'},
#    {'segment': [1.8, 2.92], 'label': 'turn'},
#    {'segment': [3.92, 5.56], 'label': 'turn'},
#    {'segment': [9.2, 10.2], 'label': 'turn'},
#    {'segment': [15.32, 16.12], 'label': 'turn'}]},
#  'vid_1005': {'duration_second': 20.92,
#   'duration_frame': 523,
#   'annotations': [{'segment': [0.04, 20.92], 'label': 'long_noise'},
#    {'segment': [4.64, 5.8], 'label': 'turn'},
#    {'segment': [12.84, 13.84], 'label': 'turn'},
#    {'segment': [6.0, 7.84], 'label': 'spin'}]},
#  'vid_1006': {'duration_second': 18.88,
#   'duration_frame': 472,
#   'annotations': [{'segment': [0.04, 18.88], 'label': 'long_noise'},
#    {'segment': [1.16, 2.24], 'label': 'turn'},
#    {'segment': [3.16, 4.88], 'label': 'turn'},
#    {'segment': [8.16, 9.04], 'label': 'turn'},
#    {'segment': [14.52, 15.2], 'label': 'turn'}]},
#  'vid_1007': {'duration_second': 14.84,
#   'duration_frame': 371,
#   'annotations': [{'segment': [1.04, 14.84], 'label': 'long_noise'},
#    {'segment': [3.64, 4.2], 'label': 'turn'},
#    {'segment': [5.4, 6.12], 'label': 'turn'},
#    {'segment': [13.32, 14.84], 'label': 'turn'}]},
#  'vid_1008': {'duration_second': 7.0,
#   'duration_frame': 175,
#   'annotations': [{'segment': [0.04, 7.0], 'label': 'long_noise'}]},
#  'vid_1009': {'duration_second': 13.96,
#   'duration_frame': 349,
#   'annotations': [{'segment': [0.04, 13.96], 'label': 'long_noise'},
#    {'segment': [6.24, 7.64], 'label': 'turn'},
#    {'segment': [9.2, 10.16], 'label': 'turn'},
#    {'segment': [6.0, 7.84], 'label': 'drift'}]},
#  'vid_1010': {'duration_second': 16.2,
#   'duration_frame': 405,
#   'annotations': [{'segment': [0.04, 1.4], 'label': 'turn'},
#    {'segment': [2.6, 3.96], 'label': 'turn'},
#    {'segment': [7.24, 8.12], 'label': 'turn'},
#    {'segment': [12.68, 13.64], 'label': 'turn'},
#    {'segment': [0.04, 16.2], 'label': 'long_noise'}]},
#  'vid_1011': {'duration_second': 14.76,
#   'duration_frame': 369,
#   'annotations': [{'segment': [0.04, 14.76], 'label': 'long_noise'},
#    {'segment': [1.0, 1.88], 'label': 'turn'},
#    {'segment': [2.96, 4.24], 'label': 'turn'}]},
#  'vid_1012': {'duration_second': 12.8,
#   'duration_frame': 320,
#   'annotations': [{'segment': [0.04, 12.8], 'label': 'long_noise'},
#    {'segment': [5.28, 6.68], 'label': 'turn'},
#    {'segment': [8.04, 9.36], 'label': 'turn'},
#    {'segment': [5.24, 6.68], 'label': 'drift'}]},
#  'vid_1013': {'duration_second': 18.36,
#   'duration_frame': 459,
#   'annotations': [{'segment': [0.04, 18.36], 'label': 'long_noise'},
#    {'segment': [1.48, 2.48], 'label': 'turn'},
#    {'segment': [3.56, 5.12], 'label': 'turn'},
#    {'segment': [8.68, 9.48], 'label': 'turn'},
#    {'segment': [14.76, 15.52], 'label': 'turn'}]},
#  'vid_1014': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': [{'segment': [0.04, 13.08], 'label': 'long_noise'},
#    {'segment': [4.92, 7.04], 'label': 'turn'},
#    {'segment': [4.88, 6.88], 'label': 'drift'}]},
#  'vid_1015': {'duration_second': 13.08,
#   'duration_frame': 327,
#   'annotations': [{'segment': [0.04, 13.08], 'label': 'long_noise'},
#    {'segment': [3.36, 4.08], 'label': 'turn'},
#    {'segment': [5.08, 5.96], 'label': 'turn'},
#    {'segment': [12.64, 13.08], 'label': 'turn'}]},
#  'vid_1016': {'duration_second': 21.28,
#   'duration_frame': 532,
#   'annotations': [{'segment': [0.04, 21.28], 'label': 'long_noise'},
#    {'segment': [1.36, 2.56], 'label': 'turn'},
#    {'segment': [5.2, 8.28], 'label': 'turn'},
#    {'segment': [12.8, 13.48], 'label': 'turn'},
#    {'segment': [19.04, 19.64], 'label': 'turn'},
#    {'segment': [2.6, 5.16], 'label': 'cut'},
#    {'segment': [3.56, 4.56], 'label': 'crowd_noise'}]},
#  'vid_1017': {'duration_second': 5.233333333333333,
#   'duration_frame': 157,
#   'annotations': [{'segment': [0.03, 5.23], 'label': 'long_noise'},
#    {'segment': [0.6, 2.03], 'label': 'spin'},
#    {'segment': [2.9, 3.33], 'label': 'turn'}]},
#  'vid_1018': {'duration_second': 8.166666666666666,
#   'duration_frame': 245,
#   'annotations': [{'segment': [0.03, 8.17], 'label': 'long_noise'},
#    {'segment': [3.13, 4.87], 'label': 'spin'},
#    {'segment': [6.07, 7.37], 'label': 'turn'}]},
#  'vid_1019': {'duration_second': 8.4,
#   'duration_frame': 252,
#   'annotations': [{'segment': [0.03, 8.4], 'label': 'long_noise'},
#    {'segment': [4.0, 5.53], 'label': 'spin'},
#    {'segment': [6.8, 7.6], 'label': 'turn'}]},
#  'vid_1020': {'duration_second': 8.566666666666666,
#   'duration_frame': 257,
#   'annotations': [{'segment': [0.03, 8.57], 'label': 'long_noise'},
#    {'segment': [4.57, 5.7], 'label': 'spin'},
#    {'segment': [6.5, 7.23], 'label': 'turn'}]},
#  'vid_766': {'duration_second': 8.7,
#   'duration_frame': 261,
#   'annotations': [{'segment': [0.07, 8.7], 'label': 'long_noise'},
#    {'segment': [6.03, 7.23], 'label': 'turn'},
#    {'segment': [6.4, 7.23], 'label': 'spin'},
#    {'segment': [5.07, 6.37], 'label': 'drift'}]}}

# %%
PROCESSED_DATA_PATH = "processed_data.json"

with open(PROCESSED_DATA_PATH, "w") as json_file:
    json.dump(processed_data, json_file, indent=4)

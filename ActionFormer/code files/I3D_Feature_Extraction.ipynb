# %% [markdown]
# <figure>
#   <img src="https://github.com/v-iashin/video_features/raw/master/docs/_assets/i3d.png" width="300" />
# </figure>
#
# The `video_features` library allows you to extract features from
# raw videos in parallel with multiple GPUs.
# It supports several extractors that capture visual appearance,
# optical flow, and audio features. See more details in the
# [GitHub repository](https://github.com/v-iashin/video_features).
#
# See more feature extraction examples in colaboratory notebooks:
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1Zd7r8uKGLGSxlil4PPnXk_4I3KOsjPpO?usp=sharing) – CLIP
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1HUlYcOJf_dArOcAaR9jaQHuM5CAZiNZc?usp=sharing) – S3D
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1LKoytZmNxtC-EuCp7pHDM6sFvK1XdwlW?usp=sharing) – I3D
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1csJgkVQ3E2qOyVlcOM-ACHGgPBBKwE2Y?usp=sharing) – R(2+1)D
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/18I95Rn1B3a2ISfD9b-o4o93m3XuHbcIY?usp=sharing) – RAFT
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/17VLdf4abQT2eoMjc6ziJ9UaRaOklTlP0?usp=sharing) – ResNet
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1r_8OnmwXKwmH0n4RxBfuICVBgpbJt_Fs?usp=sharing) – VGGish
# * [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/16QEwNMqiwqlmBhJCJmNeeEP8gitom0I-?usp=sharing) – [timm](https://huggingface.co/timm) models

# %%
! git clone https://github.com/v-iashin/video_features.git
! pip install omegaconf==2.0.6
# Out:
# Cloning into 'video_features'...
# remote: Enumerating objects: 1401, done.
# remote: Counting objects: 100% (512/512), done.
# remote: Compressing objects: 100% (222/222), done.
# remote: Total 1401 (delta 311), reused 413 (delta 264), pack-reused 889
# Receiving objects: 100% (1401/1401), 288.67 MiB | 14.05 MiB/s, done.
# Resolving deltas: 100% (725/725), done.
# Updating files: 100% (94/94), done.
# Collecting omegaconf==2.0.6
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf==2.0.6) (6.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf==2.0.6) (4.5.0)
# Installing collected packages: omegaconf
# Successfully installed omegaconf-2.0.6

# %%
# %cd video_features
# Out:
# /content/video_features

# %%
from models.i3d.extract_i3d import ExtractI3D
from utils.utils import build_cfg_path
from omegaconf import OmegaConf
import torch
import os
import glob
import numpy as np

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA RTX A5000'

# %%
# Select the feature type
feature_type = 'i3d'

# Load and patch the config
args = OmegaConf.load(build_cfg_path(feature_type))
args.video_paths = ['./sample/v_GGSY1Qvo990.mp4']
# args.show_pred = True
# args.stack_size = 24
# args.step_size = 24
# args.extraction_fps = 25
args.flow_type = 'raft'
# args.streams = 'flow'

# Load the model
extractor = ExtractI3D(args)

# Extract features
for video_path in args.video_paths:
    print(f'Extracting for {video_path}')
    feature_dict = extractor.extract(video_path)
    [(print(k), print(v.shape), print(v)) for k, v in feature_dict.items()]
# Out:
# Extracting for ./sample/v_GGSY1Qvo990.mp4
# rgb
# (5, 1024)
# [[0.08103889 0.21957842 0.05395147 ... 0.08913269 0.23047689 0.99085313]
#  [0.0409274  0.24209626 0.06408894 ... 0.025497   0.29888856 0.7770645 ]
#  [0.12468136 0.25410837 0.14176841 ... 0.16713181 0.18788038 0.68860632]
#  [0.14245597 0.27374679 0.17478532 ... 0.06249548 0.1518133  0.22951038]
#  [0.21149462 0.18290371 0.27646333 ... 0.14340422 0.24316043 0.07378176]]
# flow
# (5, 1024)
# [[2.65111979e-02 3.36236879e-02 7.64859915e-02 ... 4.90684528e-03
#   2.16035038e-01 1.64430283e-04]
#  [4.73523773e-02 3.64455394e-02 3.65564190e-02 ... 9.21847001e-02
#   1.54263407e-01 4.10271697e-02]
#  [7.00380579e-02 3.25835533e-02 2.63346955e-02 ... 1.47759795e-01
#   4.30818908e-02 2.66177085e-05]
#  [5.56781664e-02 2.76811384e-02 4.36474644e-02 ... 2.31218822e-02
#   5.60098467e-03 1.34896953e-02]
#  [3.38178650e-02 4.64935936e-02 2.61394493e-02 ... 1.90966100e-01
#   5.25541417e-02 6.30479259e-03]]
# fps
# ()
# 19.62
# timestamps_ms
# (5,)
# [ 3261.9775739   6523.95514781  9785.93272171 13047.91029562
#  16309.88786952]

# %%
! pip freeze
# Out:
# absl-py==1.4.0
# aiohttp==3.9.1
# aiosignal==1.3.1
# alabaster==0.7.16
# albumentations==1.3.1
# altair==4.2.2
# anyio==3.7.1
# appdirs==1.4.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array-record==0.5.0
# arviz==0.15.1
# astropy==5.3.4
# astunparse==1.6.3
# async-timeout==4.0.3
# atpublic==4.0
# attrs==23.2.0
# audioread==3.0.1
# autograd==1.6.2
# Babel==2.14.0
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bidict==0.22.1
# bigframes==0.19.1
# bleach==6.1.0
# blinker==1.4
# blis==0.7.11
# blosc2==2.0.0
# bokeh==3.3.3
# bqplot==0.12.42
# branca==0.7.0
# build==1.0.3
# CacheControl==0.13.1
# cachetools==5.3.2
# catalogue==2.0.10
# certifi==2023.11.17
# cffi==1.16.0
# chardet==5.2.0
# charset-normalizer==3.3.2
# chex==0.1.7
# click==8.1.7
# click-plugins==1.1.1
# cligj==0.7.2
# cloudpickle==2.2.1
# cmake==3.27.9
# cmdstanpy==1.2.0
# colorcet==3.0.1
# colorlover==0.3.0
# colour==0.1.5
# community==1.0.0b1
# confection==0.1.4
# cons==0.4.6
# contextlib2==21.6.0
# contourpy==1.2.0
# cryptography==41.0.7
# cufflinks==0.17.3
# cupy-cuda12x==12.2.0
# cvxopt==1.3.2
# cvxpy==1.3.2
# cycler==0.12.1
# cymem==2.0.8
# Cython==3.0.8
# dask==2023.8.1
# datascience==0.17.6
# db-dtypes==1.2.0
# dbus-python==1.2.18
# debugpy==1.6.6
# decorator==4.4.2
# defusedxml==0.7.1
# diskcache==5.6.3
# distributed==2023.8.1
# distro==1.7.0
# dlib==19.24.2
# dm-tree==0.1.8
# docutils==0.18.1
# dopamine-rl==4.0.6
# duckdb==0.9.2
# earthengine-api==0.1.385
# easydict==1.11
# ecos==2.0.12
# editdistance==0.6.2
# eerepr==0.0.4
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl#sha256=83276fc78a70045627144786b52e1f2728ad5e29e5e43916ec37ea9c26a11212
# entrypoints==0.4
# et-xmlfile==1.1.0
# etils==1.6.0
# etuples==0.3.9
# exceptiongroup==1.2.0
# fastai==2.7.13
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.19.1
# fastprogress==1.0.3
# fastrlock==0.8.2
# filelock==3.13.1
# fiona==1.9.5
# firebase-admin==5.3.0
# Flask==2.2.5
# flatbuffers==23.5.26
# flax==0.7.5
# folium==0.14.0
# fonttools==4.47.2
# frozendict==2.4.0
# frozenlist==1.4.1
# fsspec==2023.6.0
# future==0.18.3
# gast==0.5.4
# gcsfs==2023.6.0
# GDAL==3.4.3
# gdown==4.6.6
# geemap==0.30.4
# gensim==4.3.2
# geocoder==1.38.1
# geographiclib==2.0
# geopandas==0.13.2
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-ai-generativelanguage==0.4.0
# google-api-core==2.11.1
# google-api-python-client==2.84.0
# google-auth==2.17.3
# google-auth-httplib2==0.1.1
# google-auth-oauthlib==1.2.0
# google-cloud-aiplatform==1.39.0
# google-cloud-bigquery==3.12.0
# google-cloud-bigquery-connection==1.12.1
# google-cloud-bigquery-storage==2.24.0
# google-cloud-core==2.3.3
# google-cloud-datastore==2.15.2
# google-cloud-firestore==2.11.1
# google-cloud-functions==1.13.3
# google-cloud-iam==2.13.0
# google-cloud-language==2.9.1
# google-cloud-resource-manager==1.11.0
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.3
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz#sha256=8a8adcd0618fcdab16ee0442d46a604e7f676885d2fde98c604abf6501495e8b
# google-crc32c==1.5.0
# google-generativeai==0.3.2
# google-pasta==0.2.0
# google-resumable-media==2.7.0
# googleapis-common-protos==1.62.0
# googledrivedownloader==0.4
# graphviz==0.20.1
# greenlet==3.0.3
# grpc-google-iam-v1==0.13.0
# grpcio==1.60.0
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.3.1
# gym==0.25.2
# gym-notices==0.0.8
# h5netcdf==1.3.0
# h5py==3.9.0
# holidays==0.41
# holoviews==1.17.1
# html5lib==1.1
# httpimport==1.3.1
# httplib2==0.22.0
# huggingface-hub==0.20.2
# humanize==4.7.0
# hyperopt==0.2.7
# ibis-framework==7.1.0
# idna==3.6
# imageio==2.31.6
# imageio-ffmpeg==0.4.9
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib-metadata==7.0.1
# importlib-resources==6.1.1
# imutils==0.5.4
# inflect==7.0.0
# iniconfig==2.0.0
# install==1.3.5
# intel-openmp==2023.2.3
# ipyevents==2.0.2
# ipyfilechooser==0.6.0
# ipykernel==5.5.6
# ipyleaflet==0.18.1
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipytree==0.2.2
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.23
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.23+cuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl#sha256=8e42000672599e7ec0ea7f551acfcc95dcdd0e22b05a1d1f12f97b56a9fce4a8
# jeepney==0.7.1
# jieba==0.42.1
# Jinja2==3.1.3
# joblib==1.3.2
# jsonpickle==3.0.2
# jsonschema==4.19.2
# jsonschema-specifications==2023.12.1
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-server==1.24.0
# jupyter_core==5.7.1
# jupyterlab-widgets==3.0.9
# jupyterlab_pygments==0.3.0
# kaggle==1.5.16
# kagglehub==0.1.5
# keras==2.15.0
# keyring==23.5.0
# kiwisolver==1.4.5
# langcodes==3.3.0
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lazy_loader==0.3
# libclang==16.0.6
# librosa==0.10.1
# lida==0.0.10
# lightgbm==4.1.0
# linkify-it-py==2.0.2
# llmx==0.0.15a0
# llvmlite==0.41.1
# locket==1.0.0
# logical-unification==0.4.6
# lxml==4.9.4
# malloy==2023.1067
# Markdown==3.5.2
# markdown-it-py==3.0.0
# MarkupSafe==2.1.3
# matplotlib==3.7.1
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.9
# mdit-py-plugins==0.4.0
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.9.3
# mkl==2023.2.0
# ml-dtypes==0.2.0
# mlxtend==0.22.0
# more-itertools==10.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.7
# multidict==6.0.4
# multipledispatch==1.0.0
# multitasking==0.0.11
# murmurhash==1.0.10
# music21==9.1.0
# natsort==8.4.0
# nbclassic==1.0.0
# nbclient==0.9.0
# nbconvert==6.5.4
# nbformat==5.9.2
# nest-asyncio==1.5.9
# networkx==3.2.1
# nibabel==4.0.2
# nltk==3.8.1
# notebook==6.5.5
# notebook_shim==0.2.3
# numba==0.58.1
# numexpr==2.8.8
# numpy==1.23.5
# oauth2client==4.1.3
# oauthlib==3.2.2
# omegaconf==2.0.6
# opencv-contrib-python==4.8.0.76
# opencv-python==4.8.0.76
# opencv-python-headless==4.9.0.80
# openpyxl==3.1.2
# opt-einsum==3.3.0
# optax==0.1.8
# orbax-checkpoint==0.4.4
# osqp==0.6.2.post8
# packaging==23.2
# pandas==1.5.3
# pandas-datareader==0.10.0
# pandas-gbq==0.19.2
# pandas-stubs==1.5.3.230304
# pandocfilters==1.5.0
# panel==1.3.6
# param==2.0.1
# parso==0.8.3
# parsy==2.1
# partd==1.4.1
# pathlib==1.0.1
# pathlib_abc==0.1.1
# pathy==0.11.0
# patsy==0.5.6
# peewee==3.17.0
# pexpect==4.9.0
# pickleshare==0.7.5
# Pillow==9.4.0
# pins==0.8.4
# pip-tools==6.13.0
# platformdirs==4.1.0
# plotly==5.15.0
# plotnine==0.12.4
# pluggy==1.3.0
# polars==0.17.3
# pooch==1.8.0
# portpicker==1.5.2
# prefetch-generator==1.0.3
# preshed==3.0.9
# prettytable==3.9.0
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus-client==0.19.0
# promise==2.3
# prompt-toolkit==3.0.43
# prophet==1.1.5
# proto-plus==1.23.0
# protobuf==3.20.3
# psutil==5.9.5
# psycopg2==2.9.9
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==10.0.1
# pyarrow-hotfix==0.6
# pyasn1==0.5.1
# pyasn1-modules==0.3.0
# pycocotools==2.0.7
# pycparser==2.21
# pyct==0.5.0
# pydantic==1.10.13
# pydata-google-auth==1.8.2
# pydot==1.4.2
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# PyDrive2==1.6.3
# pyerfa==2.0.1.1
# pygame==2.5.2
# Pygments==2.16.1
# PyGObject==3.42.1
# PyJWT==2.3.0
# pymc==5.7.2
# pymystem3==0.2.0
# PyOpenGL==3.1.7
# pyOpenSSL==23.3.0
# pyparsing==3.1.1
# pyperclip==1.8.2
# pyproj==3.6.1
# pyproject_hooks==1.0.0
# pyshp==2.3.1
# PySocks==1.7.1
# pytensor==2.14.2
# pytest==7.4.4
# python-apt==0.0.0
# python-box==7.1.1
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.1
# python-utils==3.8.1
# pytz==2023.3.post1
# pyviz_comms==3.0.1
# PyWavelets==1.5.0
# PyYAML==6.0.1
# pyzmq==23.2.1
# qdldl==0.1.7.post0
# qudida==0.0.4
# ratelim==0.1.6
# referencing==0.32.1
# regex==2023.6.3
# requests==2.31.0
# requests-oauthlib==1.3.1
# requirements-parser==0.5.0
# rich==13.7.0
# rpds-py==0.17.1
# rpy2==3.4.2
# rsa==4.9
# safetensors==0.4.1
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.11.4
# scooby==0.9.2
# scs==3.2.4.post1
# seaborn==0.13.1
# SecretStorage==3.3.1
# Send2Trash==1.8.2
# shapely==2.0.2
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.4.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.5
# soxr==0.3.7
# spacy==3.6.1
# spacy-legacy==3.0.12
# spacy-loggers==1.0.5
# Sphinx==5.0.2
# sphinxcontrib-applehelp==1.0.8
# sphinxcontrib-devhelp==1.0.6
# sphinxcontrib-htmlhelp==2.0.5
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.7
# sphinxcontrib-serializinghtml==1.1.10
# SQLAlchemy==2.0.24
# sqlglot==19.9.0
# sqlparse==0.4.4
# srsly==2.4.8
# stanio==0.3.0
# statsmodels==0.14.1
# sympy==1.12
# tables==3.8.0
# tabulate==0.9.0
# tbb==2021.11.0
# tblib==3.0.0
# tenacity==8.2.3
# tensorboard==2.15.1
# tensorboard-data-server==0.7.2
# tensorflow==2.15.0
# tensorflow-datasets==4.9.4
# tensorflow-estimator==2.15.0
# tensorflow-gcs-config==2.15.0
# tensorflow-hub==0.15.0
# tensorflow-io-gcs-filesystem==0.35.0
# tensorflow-metadata==1.14.0
# tensorflow-probability==0.22.0
# tensorstore==0.1.45
# termcolor==2.4.0
# terminado==0.18.0
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# thinc==8.1.12
# threadpoolctl==3.2.0
# tifffile==2023.12.9
# tinycss2==1.2.1
# tokenizers==0.15.0
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch @ https://download.pytorch.org/whl/cu121/torch-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=0d4e8c52a1fcf5ed6cfc256d9a370fcf4360958fc79d0b08a51d55e70914df46
# torchaudio @ https://download.pytorch.org/whl/cu121/torchaudio-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=676bda4042734eda99bc59b2d7f761f345d3cde0cad492ad34e3aefde688c6d8
# torchdata==0.7.0
# torchsummary==1.5.1
# torchtext==0.16.0
# torchvision @ https://download.pytorch.org/whl/cu121/torchvision-0.16.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=e76e78d0ad43636c9884b3084ffaea8a8b61f21129fbfa456a5fe734f0affea9
# tornado==6.3.2
# tqdm==4.66.1
# traitlets==5.7.1
# traittypes==0.2.1
# transformers==4.35.2
# triton==2.1.0
# tweepy==4.14.0
# typer==0.9.0
# types-pytz==2023.3.1.1
# types-setuptools==69.0.0.20240115
# typing_extensions==4.5.0
# tzlocal==5.2
# uc-micro-py==1.0.2
# uritemplate==4.1.1
# urllib3==2.0.7
# vega-datasets==0.9.0
# wadllib==1.3.6
# wasabi==1.1.2
# wcwidth==0.2.13
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.7.0
# Werkzeug==3.0.1
# widgetsnbextension==3.6.6
# wordcloud==1.9.3
# wrapt==1.14.1
# xarray==2023.7.0
# xarray-einstats==0.6.0
# xgboost==2.0.3
# xlrd==2.0.1
# xxhash==3.4.1
# xyzservices==2023.10.1
# yarl==1.9.4
# yellowbrick==1.5
# yfinance==0.2.35
# zict==3.0.0
# zipp==3.17.0

# %%
# --- Configuration ---
VIDEO_FOLDER = './videos'  # Folder containing your .mp4 rally videos
OUTPUT_FOLDER = './rally_features_i3d_stride_4' # Where to save the .npy files
FEATURE_TYPE = 'i3d' # Keep this as 'i3d'

# --- Create Output Directory ---
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# --- Load and Configure Feature Extractor ---

# Load the base config for 'i3d'
args = OmegaConf.load(build_cfg_path(FEATURE_TYPE))

# --- Crucial Settings for ActionFormer Compatibility ---
# 1. stack_size: Use the default 64, as this is standard for I3D Kinetics models.
#    While you mentioned 16 frames *per vector*, stack_size refers to the
#    I3D *input* window. The output stride is controlled by step_size.
#    Changing stack_size might make the pre-trained model perform poorly.
args.stack_size = 16 # Keep default unless you have specific reasons

# 2. step_size: Set to 4 to get 1 feature vector per 4 frames.
args.step_size = 4 # CRITICAL for ActionFormer stride=4 requirement

# 3. streams: Use default (null) for two-stream (RGB + Flow) -> 2048D output
args.streams = None # Ensures both rgb and flow are extracted

# 4. extraction_fps: Use default (null) to keep original video FPS.
args.extraction_fps = None

# 5. flow_type: Default 'raft' is fine.
args.flow_type = 'raft'

# 6. on_extraction: Set to 'print' (or None if that works) so the script
#    *returns* the dictionary, allowing us to manually concatenate and save.
#    DO NOT use 'save_numpy' here, as it might only save one stream.
args.on_extraction = 'print' # Or try None if print is too verbose

# 7. device: Set your computation device
args.device = device

# 8. output_path: This argument might be used internally by the extractor
#    if 'on_extraction' was set to save, but we'll define our own saving path.
#    Set it anyway in case the extractor uses it for temporary files.
args.output_path = os.path.join(OUTPUT_FOLDER, "temp_extractor_out") # Or args.tmp_path

# --- Instantiate the Extractor ---
print("Initializing I3D Extractor...")
extractor = ExtractI3D(args)
print("Extractor Initialized.")

# --- Find Video Files ---
video_extensions = ["*.mp4", "*.avi", "*.mov", "*.mkv"] # Add other extensions if needed
video_paths = []
for ext in video_extensions:
    video_paths.extend(glob.glob(os.path.join(VIDEO_FOLDER, ext)))

if not video_paths:
    print(f"Error: No video files found in {VIDEO_FOLDER}")
    exit()

print(f"Found {len(video_paths)} videos to process.")

# --- Process Each Video ---
for video_path in video_paths:
    print(f"\nProcessing: {video_path}")
    try:
        # Extract features - this returns a dictionary
        feature_dict = extractor.extract(video_path)

        # Check if extraction was successful and returned expected keys
        if feature_dict and 'rgb' in feature_dict and 'flow' in feature_dict:
            rgb_features = feature_dict['rgb']
            flow_features = feature_dict['flow']

            # --- Verification ---
            print(f"  RGB shape: {rgb_features.shape}")   # Should be (T, 1024)
            print(f"  Flow shape: {flow_features.shape}")  # Should be (T, 1024)
            if rgb_features.shape[0] != flow_features.shape[0]:
                 print(f"  Warning: Mismatch in temporal length between RGB ({rgb_features.shape[0]}) and Flow ({flow_features.shape[0]}) for {video_path}. Skipping concatenation.")
                 continue
            if rgb_features.shape[1] != 1024 or flow_features.shape[1] != 1024:
                print(f"  Warning: Unexpected feature dimension for {video_path}. RGB: {rgb_features.shape[1]}, Flow: {flow_features.shape[1]}. Expected 1024. Skipping.")
                continue

            # --- Concatenate RGB and Flow Features ---
            # Result shape: (T, 2048) - This is what ActionFormer needs
            combined_features = np.concatenate((rgb_features, flow_features), axis=1)
            print(f"  Combined shape: {combined_features.shape}") # Should be (T, 2048)

            # --- Save to .npy file ---
            video_basename = os.path.basename(video_path)
            video_filename_no_ext = os.path.splitext(video_basename)[0]
            output_npy_filename = f"{video_filename_no_ext}.npy"
            output_filepath = os.path.join(OUTPUT_FOLDER, output_npy_filename)

            np.save(output_filepath, combined_features)
            print(f"  Successfully saved features to: {output_filepath}")

        else:
            print(f"  Warning: Feature extraction failed or did not return 'rgb' and 'flow' keys for {video_path}.")

    except Exception as e:
        print(f"  Error processing {video_path}: {e}")

print("\nFeature extraction completed.")
# Out:
# Initializing I3D Extractor...
# Extractor Initialized.
# Found 315 videos to process.
#
# Processing: ./videos/vid_766.mp4
#   RGB shape: (62, 1024)
#   Flow shape: (62, 1024)
#   Combined shape: (62, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_766.npy
#
# Processing: ./videos/vid_1020.mp4
#   RGB shape: (61, 1024)
#   Flow shape: (61, 1024)
#   Combined shape: (61, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1020.npy
#
# Processing: ./videos/vid_1019.mp4
#   RGB shape: (59, 1024)
#   Flow shape: (59, 1024)
#   Combined shape: (59, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1019.npy
#
# Processing: ./videos/vid_1018.mp4
#   RGB shape: (58, 1024)
#   Flow shape: (58, 1024)
#   Combined shape: (58, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1018.npy
#
# Processing: ./videos/vid_1017.mp4
#   RGB shape: (36, 1024)
#   Flow shape: (36, 1024)
#   Combined shape: (36, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1017.npy
#
# Processing: ./videos/vid_1016.mp4
#   RGB shape: (129, 1024)
#   Flow shape: (129, 1024)
#   Combined shape: (129, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1016.npy
#
# Processing: ./videos/vid_1015.mp4
#   RGB shape: (78, 1024)
#   Flow shape: (78, 1024)
#   Combined shape: (78, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1015.npy
#
# Processing: ./videos/vid_1014.mp4
#   RGB shape: (78, 1024)
#   Flow shape: (78, 1024)
#   Combined shape: (78, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1014.npy
#
# Processing: ./videos/vid_1013.mp4
#   RGB shape: (111, 1024)
#   Flow shape: (111, 1024)
#   Combined shape: (111, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1013.npy
#
# Processing: ./videos/vid_1012.mp4
#   RGB shape: (76, 1024)
#   Flow shape: (76, 1024)
#   Combined shape: (76, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1012.npy
#
# Processing: ./videos/vid_1011.mp4
#   RGB shape: (89, 1024)
#   Flow shape: (89, 1024)
#   Combined shape: (89, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1011.npy
#
# Processing: ./videos/vid_1010.mp4
#   RGB shape: (98, 1024)
#   Flow shape: (98, 1024)
#   Combined shape: (98, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1010.npy
#
# Processing: ./videos/vid_1009.mp4
#   RGB shape: (84, 1024)
#   Flow shape: (84, 1024)
#   Combined shape: (84, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1009.npy
#
# Processing: ./videos/vid_1008.mp4
#   RGB shape: (40, 1024)
#   Flow shape: (40, 1024)
#   Combined shape: (40, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1008.npy
#
# Processing: ./videos/vid_1007.mp4
#   RGB shape: (89, 1024)
#   Flow shape: (89, 1024)
#   Combined shape: (89, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1007.npy
#
# Processing: ./videos/vid_1006.mp4
#   RGB shape: (114, 1024)
#   Flow shape: (114, 1024)
#   Combined shape: (114, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1006.npy
#
# Processing: ./videos/vid_1005.mp4
#   RGB shape: (127, 1024)
#   Flow shape: (127, 1024)
#   Combined shape: (127, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1005.npy
#
# Processing: ./videos/vid_1004.mp4
#   RGB shape: (116, 1024)
#   Flow shape: (116, 1024)
#   Combined shape: (116, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1004.npy
#
# Processing: ./videos/vid_1003.mp4
#   RGB shape: (69, 1024)
#   Flow shape: (69, 1024)
#   Combined shape: (69, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1003.npy
#
# Processing: ./videos/vid_1002.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1002.npy
#
# Processing: ./videos/vid_1001.mp4
#   RGB shape: (97, 1024)
#   Flow shape: (97, 1024)
#   Combined shape: (97, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1001.npy
#
# Processing: ./videos/vid_1000.mp4
#   RGB shape: (87, 1024)
#   Flow shape: (87, 1024)
#   Combined shape: (87, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_1000.npy
#
# Processing: ./videos/vid_999.mp4
#   RGB shape: (54, 1024)
#   Flow shape: (54, 1024)
#   Combined shape: (54, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_999.npy
#
# Processing: ./videos/vid_998.mp4
#   RGB shape: (101, 1024)
#   Flow shape: (101, 1024)
#   Combined shape: (101, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_998.npy
#
# Processing: ./videos/vid_997.mp4
#   RGB shape: (141, 1024)
#   Flow shape: (141, 1024)
#   Combined shape: (141, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_997.npy
#
# Processing: ./videos/vid_996.mp4
#   RGB shape: (93, 1024)
#   Flow shape: (93, 1024)
#   Combined shape: (93, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_996.npy
#
# Processing: ./videos/vid_995.mp4
#   RGB shape: (104, 1024)
#   Flow shape: (104, 1024)
#   Combined shape: (104, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_995.npy
#
# Processing: ./videos/vid_994.mp4
#   RGB shape: (79, 1024)
#   Flow shape: (79, 1024)
#   Combined shape: (79, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_994.npy
#
# Processing: ./videos/vid_993.mp4
#   RGB shape: (37, 1024)
#   Flow shape: (37, 1024)
#   Combined shape: (37, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_993.npy
#
# Processing: ./videos/vid_992.mp4
#   RGB shape: (76, 1024)
#   Flow shape: (76, 1024)
#   Combined shape: (76, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_992.npy
#
# Processing: ./videos/vid_991.mp4
#   RGB shape: (87, 1024)
#   Flow shape: (87, 1024)
#   Combined shape: (87, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_991.npy
#
# Processing: ./videos/vid_990.mp4
#   RGB shape: (98, 1024)
#   Flow shape: (98, 1024)
#   Combined shape: (98, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_990.npy
#
# Processing: ./videos/vid_989.mp4
#   RGB shape: (66, 1024)
#   Flow shape: (66, 1024)
#   Combined shape: (66, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_989.npy
#
# Processing: ./videos/vid_988.mp4
#   RGB shape: (36, 1024)
#   Flow shape: (36, 1024)
#   Combined shape: (36, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_988.npy
#
# Processing: ./videos/vid_987.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_987.npy
#
# Processing: ./videos/vid_986.mp4
#   RGB shape: (54, 1024)
#   Flow shape: (54, 1024)
#   Combined shape: (54, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_986.npy
#
# Processing: ./videos/vid_985.mp4
#   RGB shape: (89, 1024)
#   Flow shape: (89, 1024)
#   Combined shape: (89, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_985.npy
#
# Processing: ./videos/vid_984.mp4
#   RGB shape: (110, 1024)
#   Flow shape: (110, 1024)
#   Combined shape: (110, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_984.npy
#
# Processing: ./videos/vid_983.mp4
#   RGB shape: (83, 1024)
#   Flow shape: (83, 1024)
#   Combined shape: (83, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_983.npy
#
# Processing: ./videos/vid_982.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_982.npy
#
# Processing: ./videos/vid_981.mp4
#   RGB shape: (92, 1024)
#   Flow shape: (92, 1024)
#   Combined shape: (92, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_981.npy
#
# Processing: ./videos/vid_980.mp4
#   RGB shape: (101, 1024)
#   Flow shape: (101, 1024)
#   Combined shape: (101, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_980.npy
#
# Processing: ./videos/vid_979.mp4
#   RGB shape: (106, 1024)
#   Flow shape: (106, 1024)
#   Combined shape: (106, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_979.npy
#
# Processing: ./videos/vid_978.mp4
#   RGB shape: (81, 1024)
#   Flow shape: (81, 1024)
#   Combined shape: (81, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_978.npy
#
# Processing: ./videos/vid_977.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_977.npy
#
# Processing: ./videos/vid_976.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_976.npy
#
# Processing: ./videos/vid_975.mp4
#   RGB shape: (88, 1024)
#   Flow shape: (88, 1024)
#   Combined shape: (88, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_975.npy
#
# Processing: ./videos/vid_974.mp4
#   RGB shape: (102, 1024)
#   Flow shape: (102, 1024)
#   Combined shape: (102, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_974.npy
#
# Processing: ./videos/vid_973.mp4
#   RGB shape: (71, 1024)
#   Flow shape: (71, 1024)
#   Combined shape: (71, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_973.npy
#
# Processing: ./videos/vid_972.mp4
#   RGB shape: (42, 1024)
#   Flow shape: (42, 1024)
#   Combined shape: (42, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_972.npy
#
# Processing: ./videos/vid_971.mp4
#   RGB shape: (100, 1024)
#   Flow shape: (100, 1024)
#   Combined shape: (100, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_971.npy
#
# Processing: ./videos/vid_970.mp4
#   RGB shape: (98, 1024)
#   Flow shape: (98, 1024)
#   Combined shape: (98, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_970.npy
#
# Processing: ./videos/vid_969.mp4
#   RGB shape: (101, 1024)
#   Flow shape: (101, 1024)
#   Combined shape: (101, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_969.npy
#
# Processing: ./videos/vid_968.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_968.npy
#
# Processing: ./videos/vid_967.mp4
#   RGB shape: (178, 1024)
#   Flow shape: (178, 1024)
#   Combined shape: (178, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_967.npy
#
# Processing: ./videos/vid_966.mp4
#   RGB shape: (109, 1024)
#   Flow shape: (109, 1024)
#   Combined shape: (109, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_966.npy
#
# Processing: ./videos/vid_965.mp4
#   RGB shape: (108, 1024)
#   Flow shape: (108, 1024)
#   Combined shape: (108, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_965.npy
#
# Processing: ./videos/vid_964.mp4
#   RGB shape: (123, 1024)
#   Flow shape: (123, 1024)
#   Combined shape: (123, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_964.npy
#
# Processing: ./videos/vid_963.mp4
#   RGB shape: (106, 1024)
#   Flow shape: (106, 1024)
#   Combined shape: (106, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_963.npy
#
# Processing: ./videos/vid_962.mp4
#   RGB shape: (41, 1024)
#   Flow shape: (41, 1024)
#   Combined shape: (41, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_962.npy
#
# Processing: ./videos/vid_961.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_961.npy
#
# Processing: ./videos/vid_960.mp4
#   RGB shape: (88, 1024)
#   Flow shape: (88, 1024)
#   Combined shape: (88, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_960.npy
#
# Processing: ./videos/vid_959.mp4
#   RGB shape: (99, 1024)
#   Flow shape: (99, 1024)
#   Combined shape: (99, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_959.npy
#
# Processing: ./videos/vid_958.mp4
#   RGB shape: (81, 1024)
#   Flow shape: (81, 1024)
#   Combined shape: (81, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_958.npy
#
# Processing: ./videos/vid_957.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_957.npy
#
# Processing: ./videos/vid_956.mp4
#   RGB shape: (84, 1024)
#   Flow shape: (84, 1024)
#   Combined shape: (84, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_956.npy
#
# Processing: ./videos/vid_955.mp4
#   RGB shape: (91, 1024)
#   Flow shape: (91, 1024)
#   Combined shape: (91, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_955.npy
#
# Processing: ./videos/vid_954.mp4
#   RGB shape: (107, 1024)
#   Flow shape: (107, 1024)
#   Combined shape: (107, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_954.npy
#
# Processing: ./videos/vid_953.mp4
#   RGB shape: (95, 1024)
#   Flow shape: (95, 1024)
#   Combined shape: (95, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_953.npy
#
# Processing: ./videos/vid_952.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_952.npy
#
# Processing: ./videos/vid_951.mp4
#   RGB shape: (75, 1024)
#   Flow shape: (75, 1024)
#   Combined shape: (75, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_951.npy
#
# Processing: ./videos/vid_950.mp4
#   RGB shape: (90, 1024)
#   Flow shape: (90, 1024)
#   Combined shape: (90, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_950.npy
#
# Processing: ./videos/vid_949.mp4
#   RGB shape: (108, 1024)
#   Flow shape: (108, 1024)
#   Combined shape: (108, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_949.npy
#
# Processing: ./videos/vid_948.mp4
#   RGB shape: (76, 1024)
#   Flow shape: (76, 1024)
#   Combined shape: (76, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_948.npy
#
# Processing: ./videos/vid_947.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_947.npy
#
# Processing: ./videos/vid_946.mp4
#   RGB shape: (95, 1024)
#   Flow shape: (95, 1024)
#   Combined shape: (95, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_946.npy
#
# Processing: ./videos/vid_945.mp4
#   RGB shape: (81, 1024)
#   Flow shape: (81, 1024)
#   Combined shape: (81, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_945.npy
#
# Processing: ./videos/vid_944.mp4
#   RGB shape: (46, 1024)
#   Flow shape: (46, 1024)
#   Combined shape: (46, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_944.npy
#
# Processing: ./videos/vid_943.mp4
#   RGB shape: (100, 1024)
#   Flow shape: (100, 1024)
#   Combined shape: (100, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_943.npy
#
# Processing: ./videos/vid_942.mp4
#   RGB shape: (157, 1024)
#   Flow shape: (157, 1024)
#   Combined shape: (157, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_942.npy
#
# Processing: ./videos/vid_941.mp4
#   RGB shape: (117, 1024)
#   Flow shape: (117, 1024)
#   Combined shape: (117, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_941.npy
#
# Processing: ./videos/vid_940.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_940.npy
#
# Processing: ./videos/vid_939.mp4
#   RGB shape: (44, 1024)
#   Flow shape: (44, 1024)
#   Combined shape: (44, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_939.npy
#
# Processing: ./videos/vid_938.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_938.npy
#
# Processing: ./videos/vid_937.mp4
#   RGB shape: (102, 1024)
#   Flow shape: (102, 1024)
#   Combined shape: (102, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_937.npy
#
# Processing: ./videos/vid_936.mp4
#   RGB shape: (73, 1024)
#   Flow shape: (73, 1024)
#   Combined shape: (73, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_936.npy
#
# Processing: ./videos/vid_935.mp4
#   RGB shape: (37, 1024)
#   Flow shape: (37, 1024)
#   Combined shape: (37, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_935.npy
#
# Processing: ./videos/vid_934.mp4
#   RGB shape: (71, 1024)
#   Flow shape: (71, 1024)
#   Combined shape: (71, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_934.npy
#
# Processing: ./videos/vid_933.mp4
#   RGB shape: (111, 1024)
#   Flow shape: (111, 1024)
#   Combined shape: (111, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_933.npy
#
# Processing: ./videos/vid_932.mp4
#   RGB shape: (79, 1024)
#   Flow shape: (79, 1024)
#   Combined shape: (79, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_932.npy
#
# Processing: ./videos/vid_931.mp4
#   RGB shape: (79, 1024)
#   Flow shape: (79, 1024)
#   Combined shape: (79, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_931.npy
#
# Processing: ./videos/vid_930.mp4
#   RGB shape: (95, 1024)
#   Flow shape: (95, 1024)
#   Combined shape: (95, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_930.npy
#
# Processing: ./videos/vid_929.mp4
#   RGB shape: (110, 1024)
#   Flow shape: (110, 1024)
#   Combined shape: (110, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_929.npy
#
# Processing: ./videos/vid_928.mp4
#   RGB shape: (81, 1024)
#   Flow shape: (81, 1024)
#   Combined shape: (81, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_928.npy
#
# Processing: ./videos/vid_927.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_927.npy
#
# Processing: ./videos/vid_926.mp4
#   RGB shape: (88, 1024)
#   Flow shape: (88, 1024)
#   Combined shape: (88, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_926.npy
#
# Processing: ./videos/vid_925.mp4
#   RGB shape: (91, 1024)
#   Flow shape: (91, 1024)
#   Combined shape: (91, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_925.npy
#
# Processing: ./videos/vid_924.mp4
#   RGB shape: (79, 1024)
#   Flow shape: (79, 1024)
#   Combined shape: (79, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_924.npy
#
# Processing: ./videos/vid_923.mp4
#   RGB shape: (41, 1024)
#   Flow shape: (41, 1024)
#   Combined shape: (41, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_923.npy
#
# Processing: ./videos/vid_922.mp4
#   RGB shape: (103, 1024)
#   Flow shape: (103, 1024)
#   Combined shape: (103, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_922.npy
#
# Processing: ./videos/vid_921.mp4
#   RGB shape: (76, 1024)
#   Flow shape: (76, 1024)
#   Combined shape: (76, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_921.npy
#
# Processing: ./videos/vid_920.mp4
#   RGB shape: (107, 1024)
#   Flow shape: (107, 1024)
#   Combined shape: (107, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_920.npy
#
# Processing: ./videos/vid_919.mp4
#   RGB shape: (92, 1024)
#   Flow shape: (92, 1024)
#   Combined shape: (92, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_919.npy
#
# Processing: ./videos/vid_918.mp4
#   RGB shape: (38, 1024)
#   Flow shape: (38, 1024)
#   Combined shape: (38, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_918.npy
#
# Processing: ./videos/vid_917.mp4
#   RGB shape: (80, 1024)
#   Flow shape: (80, 1024)
#   Combined shape: (80, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_917.npy
#
# Processing: ./videos/vid_916.mp4
#   RGB shape: (97, 1024)
#   Flow shape: (97, 1024)
#   Combined shape: (97, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_916.npy
#
# Processing: ./videos/vid_915.mp4
#   RGB shape: (46, 1024)
#   Flow shape: (46, 1024)
#   Combined shape: (46, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_915.npy
#
# Processing: ./videos/vid_914.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_914.npy
#
# Processing: ./videos/vid_913.mp4
#   RGB shape: (87, 1024)
#   Flow shape: (87, 1024)
#   Combined shape: (87, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_913.npy
#
# Processing: ./videos/vid_912.mp4
#   RGB shape: (97, 1024)
#   Flow shape: (97, 1024)
#   Combined shape: (97, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_912.npy
#
# Processing: ./videos/vid_911.mp4
#   RGB shape: (61, 1024)
#   Flow shape: (61, 1024)
#   Combined shape: (61, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_911.npy
#
# Processing: ./videos/vid_910.mp4
#   RGB shape: (43, 1024)
#   Flow shape: (43, 1024)
#   Combined shape: (43, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_910.npy
#
# Processing: ./videos/vid_909.mp4
#   RGB shape: (77, 1024)
#   Flow shape: (77, 1024)
#   Combined shape: (77, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_909.npy
#
# Processing: ./videos/vid_908.mp4
#   RGB shape: (90, 1024)
#   Flow shape: (90, 1024)
#   Combined shape: (90, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_908.npy
#
# Processing: ./videos/vid_907.mp4
#   RGB shape: (105, 1024)
#   Flow shape: (105, 1024)
#   Combined shape: (105, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_907.npy
#
# Processing: ./videos/vid_906.mp4
#   RGB shape: (86, 1024)
#   Flow shape: (86, 1024)
#   Combined shape: (86, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_906.npy
#
# Processing: ./videos/vid_905.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_905.npy
#
# Processing: ./videos/vid_904.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_904.npy
#
# Processing: ./videos/vid_903.mp4
#   RGB shape: (171, 1024)
#   Flow shape: (171, 1024)
#   Combined shape: (171, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_903.npy
#
# Processing: ./videos/vid_902.mp4
#   RGB shape: (102, 1024)
#   Flow shape: (102, 1024)
#   Combined shape: (102, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_902.npy
#
# Processing: ./videos/vid_901.mp4
#   RGB shape: (97, 1024)
#   Flow shape: (97, 1024)
#   Combined shape: (97, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_901.npy
#
# Processing: ./videos/vid_900.mp4
#   RGB shape: (34, 1024)
#   Flow shape: (34, 1024)
#   Combined shape: (34, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_900.npy
#
# Processing: ./videos/vid_899.mp4
#   RGB shape: (71, 1024)
#   Flow shape: (71, 1024)
#   Combined shape: (71, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_899.npy
#
# Processing: ./videos/vid_898.mp4
#   RGB shape: (106, 1024)
#   Flow shape: (106, 1024)
#   Combined shape: (106, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_898.npy
#
# Processing: ./videos/vid_897.mp4
#   RGB shape: (66, 1024)
#   Flow shape: (66, 1024)
#   Combined shape: (66, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_897.npy
#
# Processing: ./videos/vid_896.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_896.npy
#
# Processing: ./videos/vid_895.mp4
#   RGB shape: (89, 1024)
#   Flow shape: (89, 1024)
#   Combined shape: (89, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_895.npy
#
# Processing: ./videos/vid_894.mp4
#   RGB shape: (95, 1024)
#   Flow shape: (95, 1024)
#   Combined shape: (95, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_894.npy
#
# Processing: ./videos/vid_893.mp4
#   RGB shape: (69, 1024)
#   Flow shape: (69, 1024)
#   Combined shape: (69, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_893.npy
#
# Processing: ./videos/vid_892.mp4
#   RGB shape: (47, 1024)
#   Flow shape: (47, 1024)
#   Combined shape: (47, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_892.npy
#
# Processing: ./videos/vid_891.mp4
#   RGB shape: (83, 1024)
#   Flow shape: (83, 1024)
#   Combined shape: (83, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_891.npy
#
# Processing: ./videos/vid_890.mp4
#   RGB shape: (100, 1024)
#   Flow shape: (100, 1024)
#   Combined shape: (100, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_890.npy
#
# Processing: ./videos/vid_889.mp4
#   RGB shape: (114, 1024)
#   Flow shape: (114, 1024)
#   Combined shape: (114, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_889.npy
#
# Processing: ./videos/vid_888.mp4
#   RGB shape: (70, 1024)
#   Flow shape: (70, 1024)
#   Combined shape: (70, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_888.npy
#
# Processing: ./videos/vid_887.mp4
#   RGB shape: (92, 1024)
#   Flow shape: (92, 1024)
#   Combined shape: (92, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_887.npy
#
# Processing: ./videos/vid_886.mp4
#   RGB shape: (85, 1024)
#   Flow shape: (85, 1024)
#   Combined shape: (85, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_886.npy
#
# Processing: ./videos/vid_885.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_885.npy
#
# Processing: ./videos/vid_884.mp4
#   RGB shape: (77, 1024)
#   Flow shape: (77, 1024)
#   Combined shape: (77, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_884.npy
#
# Processing: ./videos/vid_883.mp4
#   RGB shape: (85, 1024)
#   Flow shape: (85, 1024)
#   Combined shape: (85, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_883.npy
#
# Processing: ./videos/vid_882.mp4
#   RGB shape: (96, 1024)
#   Flow shape: (96, 1024)
#   Combined shape: (96, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_882.npy
#
# Processing: ./videos/vid_881.mp4
#   RGB shape: (65, 1024)
#   Flow shape: (65, 1024)
#   Combined shape: (65, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_881.npy
#
# Processing: ./videos/vid_880.mp4
#   RGB shape: (49, 1024)
#   Flow shape: (49, 1024)
#   Combined shape: (49, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_880.npy
#
# Processing: ./videos/vid_879.mp4
#   RGB shape: (70, 1024)
#   Flow shape: (70, 1024)
#   Combined shape: (70, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_879.npy
#
# Processing: ./videos/vid_878.mp4
#   RGB shape: (120, 1024)
#   Flow shape: (120, 1024)
#   Combined shape: (120, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_878.npy
#
# Processing: ./videos/vid_877.mp4
#   RGB shape: (94, 1024)
#   Flow shape: (94, 1024)
#   Combined shape: (94, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_877.npy
#
# Processing: ./videos/vid_876.mp4
#   RGB shape: (121, 1024)
#   Flow shape: (121, 1024)
#   Combined shape: (121, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_876.npy
#
# Processing: ./videos/vid_875.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_875.npy
#
# Processing: ./videos/vid_874.mp4
#   RGB shape: (89, 1024)
#   Flow shape: (89, 1024)
#   Combined shape: (89, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_874.npy
#
# Processing: ./videos/vid_873.mp4
#   RGB shape: (91, 1024)
#   Flow shape: (91, 1024)
#   Combined shape: (91, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_873.npy
#
# Processing: ./videos/vid_872.mp4
#   RGB shape: (316, 1024)
#   Flow shape: (316, 1024)
#   Combined shape: (316, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_872.npy
#
# Processing: ./videos/vid_871.mp4
#   RGB shape: (61, 1024)
#   Flow shape: (61, 1024)
#   Combined shape: (61, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_871.npy
#
# Processing: ./videos/vid_870.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_870.npy
#
# Processing: ./videos/vid_869.mp4
#   RGB shape: (41, 1024)
#   Flow shape: (41, 1024)
#   Combined shape: (41, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_869.npy
#
# Processing: ./videos/vid_868.mp4
#   RGB shape: (58, 1024)
#   Flow shape: (58, 1024)
#   Combined shape: (58, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_868.npy
#
# Processing: ./videos/vid_867.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_867.npy
#
# Processing: ./videos/vid_866.mp4
#   RGB shape: (68, 1024)
#   Flow shape: (68, 1024)
#   Combined shape: (68, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_866.npy
#
# Processing: ./videos/vid_865.mp4
#   RGB shape: (43, 1024)
#   Flow shape: (43, 1024)
#   Combined shape: (43, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_865.npy
#
# Processing: ./videos/vid_864.mp4
#   RGB shape: (38, 1024)
#   Flow shape: (38, 1024)
#   Combined shape: (38, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_864.npy
#
# Processing: ./videos/vid_863.mp4
#   RGB shape: (52, 1024)
#   Flow shape: (52, 1024)
#   Combined shape: (52, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_863.npy
#
# Processing: ./videos/vid_862.mp4
#   RGB shape: (53, 1024)
#   Flow shape: (53, 1024)
#   Combined shape: (53, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_862.npy
#
# Processing: ./videos/vid_861.mp4
#   RGB shape: (37, 1024)
#   Flow shape: (37, 1024)
#   Combined shape: (37, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_861.npy
#
# Processing: ./videos/vid_860.mp4
#   RGB shape: (51, 1024)
#   Flow shape: (51, 1024)
#   Combined shape: (51, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_860.npy
#
# Processing: ./videos/vid_859.mp4
#   RGB shape: (47, 1024)
#   Flow shape: (47, 1024)
#   Combined shape: (47, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_859.npy
#
# Processing: ./videos/vid_858.mp4
#   RGB shape: (66, 1024)
#   Flow shape: (66, 1024)
#   Combined shape: (66, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_858.npy
#
# Processing: ./videos/vid_857.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_857.npy
#
# Processing: ./videos/vid_856.mp4
#   RGB shape: (16, 1024)
#   Flow shape: (16, 1024)
#   Combined shape: (16, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_856.npy
#
# Processing: ./videos/vid_855.mp4
#   RGB shape: (32, 1024)
#   Flow shape: (32, 1024)
#   Combined shape: (32, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_855.npy
#
# Processing: ./videos/vid_854.mp4
#   RGB shape: (73, 1024)
#   Flow shape: (73, 1024)
#   Combined shape: (73, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_854.npy
#
# Processing: ./videos/vid_853.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_853.npy
#
# Processing: ./videos/vid_852.mp4
#   RGB shape: (36, 1024)
#   Flow shape: (36, 1024)
#   Combined shape: (36, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_852.npy
#
# Processing: ./videos/vid_851.mp4
#   RGB shape: (40, 1024)
#   Flow shape: (40, 1024)
#   Combined shape: (40, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_851.npy
#
# Processing: ./videos/vid_850.mp4
#   RGB shape: (38, 1024)
#   Flow shape: (38, 1024)
#   Combined shape: (38, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_850.npy
#
# Processing: ./videos/vid_849.mp4
#   RGB shape: (43, 1024)
#   Flow shape: (43, 1024)
#   Combined shape: (43, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_849.npy
#
# Processing: ./videos/vid_848.mp4
#   RGB shape: (54, 1024)
#   Flow shape: (54, 1024)
#   Combined shape: (54, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_848.npy
#
# Processing: ./videos/vid_847.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_847.npy
#
# Processing: ./videos/vid_846.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_846.npy
#
# Processing: ./videos/vid_845.mp4
#   RGB shape: (46, 1024)
#   Flow shape: (46, 1024)
#   Combined shape: (46, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_845.npy
#
# Processing: ./videos/vid_844.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_844.npy
#
# Processing: ./videos/vid_843.mp4
#   RGB shape: (44, 1024)
#   Flow shape: (44, 1024)
#   Combined shape: (44, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_843.npy
#
# Processing: ./videos/vid_842.mp4
#   RGB shape: (41, 1024)
#   Flow shape: (41, 1024)
#   Combined shape: (41, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_842.npy
#
# Processing: ./videos/vid_841.mp4
#   RGB shape: (56, 1024)
#   Flow shape: (56, 1024)
#   Combined shape: (56, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_841.npy
#
# Processing: ./videos/vid_840.mp4
#   RGB shape: (48, 1024)
#   Flow shape: (48, 1024)
#   Combined shape: (48, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_840.npy
#
# Processing: ./videos/vid_839.mp4
#   RGB shape: (54, 1024)
#   Flow shape: (54, 1024)
#   Combined shape: (54, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_839.npy
#
# Processing: ./videos/vid_838.mp4
#   RGB shape: (78, 1024)
#   Flow shape: (78, 1024)
#   Combined shape: (78, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_838.npy
#
# Processing: ./videos/vid_837.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_837.npy
#
# Processing: ./videos/vid_836.mp4
#   RGB shape: (21, 1024)
#   Flow shape: (21, 1024)
#   Combined shape: (21, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_836.npy
#
# Processing: ./videos/vid_835.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_835.npy
#
# Processing: ./videos/vid_834.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_834.npy
#
# Processing: ./videos/vid_833.mp4
#   RGB shape: (49, 1024)
#   Flow shape: (49, 1024)
#   Combined shape: (49, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_833.npy
#
# Processing: ./videos/vid_832.mp4
#   RGB shape: (65, 1024)
#   Flow shape: (65, 1024)
#   Combined shape: (65, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_832.npy
#
# Processing: ./videos/vid_831.mp4
#   RGB shape: (36, 1024)
#   Flow shape: (36, 1024)
#   Combined shape: (36, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_831.npy
#
# Processing: ./videos/vid_830.mp4
#   RGB shape: (60, 1024)
#   Flow shape: (60, 1024)
#   Combined shape: (60, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_830.npy
#
# Processing: ./videos/vid_829.mp4
#   RGB shape: (34, 1024)
#   Flow shape: (34, 1024)
#   Combined shape: (34, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_829.npy
#
# Processing: ./videos/vid_828.mp4
#   RGB shape: (27, 1024)
#   Flow shape: (27, 1024)
#   Combined shape: (27, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_828.npy
#
# Processing: ./videos/vid_827.mp4
#   RGB shape: (75, 1024)
#   Flow shape: (75, 1024)
#   Combined shape: (75, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_827.npy
#
# Processing: ./videos/vid_826.mp4
#   RGB shape: (51, 1024)
#   Flow shape: (51, 1024)
#   Combined shape: (51, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_826.npy
#
# Processing: ./videos/vid_825.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_825.npy
#
# Processing: ./videos/vid_824.mp4
#   RGB shape: (37, 1024)
#   Flow shape: (37, 1024)
#   Combined shape: (37, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_824.npy
#
# Processing: ./videos/vid_823.mp4
#   RGB shape: (61, 1024)
#   Flow shape: (61, 1024)
#   Combined shape: (61, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_823.npy
#
# Processing: ./videos/vid_822.mp4
#   RGB shape: (44, 1024)
#   Flow shape: (44, 1024)
#   Combined shape: (44, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_822.npy
#
# Processing: ./videos/vid_821.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_821.npy
#
# Processing: ./videos/vid_820.mp4
#   RGB shape: (45, 1024)
#   Flow shape: (45, 1024)
#   Combined shape: (45, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_820.npy
#
# Processing: ./videos/vid_819.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_819.npy
#
# Processing: ./videos/vid_818.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_818.npy
#
# Processing: ./videos/vid_817.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_817.npy
#
# Processing: ./videos/vid_816.mp4
#   RGB shape: (56, 1024)
#   Flow shape: (56, 1024)
#   Combined shape: (56, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_816.npy
#
# Processing: ./videos/vid_815.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_815.npy
#
# Processing: ./videos/vid_814.mp4
#   RGB shape: (32, 1024)
#   Flow shape: (32, 1024)
#   Combined shape: (32, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_814.npy
#
# Processing: ./videos/vid_813.mp4
#   RGB shape: (45, 1024)
#   Flow shape: (45, 1024)
#   Combined shape: (45, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_813.npy
#
# Processing: ./videos/vid_812.mp4
#   RGB shape: (57, 1024)
#   Flow shape: (57, 1024)
#   Combined shape: (57, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_812.npy
#
# Processing: ./videos/vid_811.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_811.npy
#
# Processing: ./videos/vid_810.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_810.npy
#
# Processing: ./videos/vid_809.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_809.npy
#
# Processing: ./videos/vid_808.mp4
#   RGB shape: (48, 1024)
#   Flow shape: (48, 1024)
#   Combined shape: (48, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_808.npy
#
# Processing: ./videos/vid_807.mp4
#   RGB shape: (77, 1024)
#   Flow shape: (77, 1024)
#   Combined shape: (77, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_807.npy
#
# Processing: ./videos/vid_806.mp4
#   RGB shape: (30, 1024)
#   Flow shape: (30, 1024)
#   Combined shape: (30, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_806.npy
#
# Processing: ./videos/vid_805.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_805.npy
#
# Processing: ./videos/vid_804.mp4
#   RGB shape: (73, 1024)
#   Flow shape: (73, 1024)
#   Combined shape: (73, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_804.npy
#
# Processing: ./videos/vid_803.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_803.npy
#
# Processing: ./videos/vid_802.mp4
#   RGB shape: (57, 1024)
#   Flow shape: (57, 1024)
#   Combined shape: (57, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_802.npy
#
# Processing: ./videos/vid_801.mp4
#   RGB shape: (60, 1024)
#   Flow shape: (60, 1024)
#   Combined shape: (60, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_801.npy
#
# Processing: ./videos/vid_800.mp4
#   RGB shape: (46, 1024)
#   Flow shape: (46, 1024)
#   Combined shape: (46, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_800.npy
#
# Processing: ./videos/vid_799.mp4
#   RGB shape: (38, 1024)
#   Flow shape: (38, 1024)
#   Combined shape: (38, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_799.npy
#
# Processing: ./videos/vid_798.mp4
#   RGB shape: (40, 1024)
#   Flow shape: (40, 1024)
#   Combined shape: (40, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_798.npy
#
# Processing: ./videos/vid_797.mp4
#   RGB shape: (44, 1024)
#   Flow shape: (44, 1024)
#   Combined shape: (44, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_797.npy
#
# Processing: ./videos/vid_796.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_796.npy
#
# Processing: ./videos/vid_795.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_795.npy
#
# Processing: ./videos/vid_794.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_794.npy
#
# Processing: ./videos/vid_793.mp4
#   RGB shape: (34, 1024)
#   Flow shape: (34, 1024)
#   Combined shape: (34, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_793.npy
#
# Processing: ./videos/vid_792.mp4
#   RGB shape: (53, 1024)
#   Flow shape: (53, 1024)
#   Combined shape: (53, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_792.npy
#
# Processing: ./videos/vid_791.mp4
#   RGB shape: (25, 1024)
#   Flow shape: (25, 1024)
#   Combined shape: (25, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_791.npy
#
# Processing: ./videos/vid_790.mp4
#   RGB shape: (35, 1024)
#   Flow shape: (35, 1024)
#   Combined shape: (35, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_790.npy
#
# Processing: ./videos/vid_789.mp4
#   RGB shape: (32, 1024)
#   Flow shape: (32, 1024)
#   Combined shape: (32, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_789.npy
#
# Processing: ./videos/vid_788.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_788.npy
#
# Processing: ./videos/vid_787.mp4
#   RGB shape: (70, 1024)
#   Flow shape: (70, 1024)
#   Combined shape: (70, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_787.npy
#
# Processing: ./videos/vid_786.mp4
#   RGB shape: (24, 1024)
#   Flow shape: (24, 1024)
#   Combined shape: (24, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_786.npy
#
# Processing: ./videos/vid_785.mp4
#   RGB shape: (53, 1024)
#   Flow shape: (53, 1024)
#   Combined shape: (53, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_785.npy
#
# Processing: ./videos/vid_710.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_710.npy
#
# Processing: ./videos/vid_709.mp4
#   RGB shape: (57, 1024)
#   Flow shape: (57, 1024)
#   Combined shape: (57, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_709.npy
#
# Processing: ./videos/vid_708.mp4
#   RGB shape: (61, 1024)
#   Flow shape: (61, 1024)
#   Combined shape: (61, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_708.npy
#
# Processing: ./videos/vid_707.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_707.npy
#
# Processing: ./videos/vid_645.mp4
#   RGB shape: (77, 1024)
#   Flow shape: (77, 1024)
#   Combined shape: (77, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_645.npy
#
# Processing: ./videos/vid_613.mp4
#   RGB shape: (65, 1024)
#   Flow shape: (65, 1024)
#   Combined shape: (65, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_613.npy
#
# Processing: ./videos/vid_611.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_611.npy
#
# Processing: ./videos/vid_590.mp4
#   RGB shape: (84, 1024)
#   Flow shape: (84, 1024)
#   Combined shape: (84, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_590.npy
#
# Processing: ./videos/vid_784.mp4
#   RGB shape: (27, 1024)
#   Flow shape: (27, 1024)
#   Combined shape: (27, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_784.npy
#
# Processing: ./videos/vid_783.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_783.npy
#
# Processing: ./videos/vid_782.mp4
#   RGB shape: (14, 1024)
#   Flow shape: (14, 1024)
#   Combined shape: (14, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_782.npy
#
# Processing: ./videos/vid_781.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_781.npy
#
# Processing: ./videos/vid_780.mp4
#   RGB shape: (45, 1024)
#   Flow shape: (45, 1024)
#   Combined shape: (45, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_780.npy
#
# Processing: ./videos/vid_779.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_779.npy
#
# Processing: ./videos/vid_778.mp4
#   RGB shape: (72, 1024)
#   Flow shape: (72, 1024)
#   Combined shape: (72, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_778.npy
#
# Processing: ./videos/vid_777.mp4
#   RGB shape: (60, 1024)
#   Flow shape: (60, 1024)
#   Combined shape: (60, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_777.npy
#
# Processing: ./videos/vid_776.mp4
#   RGB shape: (48, 1024)
#   Flow shape: (48, 1024)
#   Combined shape: (48, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_776.npy
#
# Processing: ./videos/vid_775.mp4
#   RGB shape: (63, 1024)
#   Flow shape: (63, 1024)
#   Combined shape: (63, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_775.npy
#
# Processing: ./videos/vid_774.mp4
#   RGB shape: (74, 1024)
#   Flow shape: (74, 1024)
#   Combined shape: (74, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_774.npy
#
# Processing: ./videos/vid_773.mp4
#   RGB shape: (26, 1024)
#   Flow shape: (26, 1024)
#   Combined shape: (26, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_773.npy
#
# Processing: ./videos/vid_772.mp4
#   RGB shape: (70, 1024)
#   Flow shape: (70, 1024)
#   Combined shape: (70, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_772.npy
#
# Processing: ./videos/vid_770.mp4
#   RGB shape: (94, 1024)
#   Flow shape: (94, 1024)
#   Combined shape: (94, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_770.npy
#
# Processing: ./videos/vid_769.mp4
#   RGB shape: (27, 1024)
#   Flow shape: (27, 1024)
#   Combined shape: (27, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_769.npy
#
# Processing: ./videos/vid_768.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_768.npy
#
# Processing: ./videos/vid_767.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_767.npy
#
# Processing: ./videos/vid_765.mp4
#   RGB shape: (68, 1024)
#   Flow shape: (68, 1024)
#   Combined shape: (68, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_765.npy
#
# Processing: ./videos/vid_764.mp4
#   RGB shape: (53, 1024)
#   Flow shape: (53, 1024)
#   Combined shape: (53, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_764.npy
#
# Processing: ./videos/vid_763.mp4
#   RGB shape: (51, 1024)
#   Flow shape: (51, 1024)
#   Combined shape: (51, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_763.npy
#
# Processing: ./videos/vid_762.mp4
#   RGB shape: (40, 1024)
#   Flow shape: (40, 1024)
#   Combined shape: (40, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_762.npy
#
# Processing: ./videos/vid_761.mp4
#   RGB shape: (56, 1024)
#   Flow shape: (56, 1024)
#   Combined shape: (56, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_761.npy
#
# Processing: ./videos/vid_760.mp4
#   RGB shape: (68, 1024)
#   Flow shape: (68, 1024)
#   Combined shape: (68, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_760.npy
#
# Processing: ./videos/vid_759.mp4
#   RGB shape: (59, 1024)
#   Flow shape: (59, 1024)
#   Combined shape: (59, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_759.npy
#
# Processing: ./videos/vid_758.mp4
#   RGB shape: (43, 1024)
#   Flow shape: (43, 1024)
#   Combined shape: (43, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_758.npy
#
# Processing: ./videos/vid_757.mp4
#   RGB shape: (91, 1024)
#   Flow shape: (91, 1024)
#   Combined shape: (91, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_757.npy
#
# Processing: ./videos/vid_756.mp4
#   RGB shape: (27, 1024)
#   Flow shape: (27, 1024)
#   Combined shape: (27, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_756.npy
#
# Processing: ./videos/vid_755.mp4
#   RGB shape: (65, 1024)
#   Flow shape: (65, 1024)
#   Combined shape: (65, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_755.npy
#
# Processing: ./videos/vid_754.mp4
#   RGB shape: (49, 1024)
#   Flow shape: (49, 1024)
#   Combined shape: (49, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_754.npy
#
# Processing: ./videos/vid_753.mp4
#   RGB shape: (54, 1024)
#   Flow shape: (54, 1024)
#   Combined shape: (54, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_753.npy
#
# Processing: ./videos/vid_752.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_752.npy
#
# Processing: ./videos/vid_751.mp4
#   RGB shape: (58, 1024)
#   Flow shape: (58, 1024)
#   Combined shape: (58, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_751.npy
#
# Processing: ./videos/vid_750.mp4
#   RGB shape: (39, 1024)
#   Flow shape: (39, 1024)
#   Combined shape: (39, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_750.npy
#
# Processing: ./videos/vid_749.mp4
#   RGB shape: (63, 1024)
#   Flow shape: (63, 1024)
#   Combined shape: (63, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_749.npy
#
# Processing: ./videos/vid_748.mp4
#   RGB shape: (34, 1024)
#   Flow shape: (34, 1024)
#   Combined shape: (34, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_748.npy
#
# Processing: ./videos/vid_747.mp4
#   RGB shape: (76, 1024)
#   Flow shape: (76, 1024)
#   Combined shape: (76, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_747.npy
#
# Processing: ./videos/vid_746.mp4
#   RGB shape: (84, 1024)
#   Flow shape: (84, 1024)
#   Combined shape: (84, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_746.npy
#
# Processing: ./videos/vid_745.mp4
#   RGB shape: (103, 1024)
#   Flow shape: (103, 1024)
#   Combined shape: (103, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_745.npy
#
# Processing: ./videos/vid_744.mp4
#   RGB shape: (60, 1024)
#   Flow shape: (60, 1024)
#   Combined shape: (60, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_744.npy
#
# Processing: ./videos/vid_743.mp4
#   RGB shape: (51, 1024)
#   Flow shape: (51, 1024)
#   Combined shape: (51, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_743.npy
#
# Processing: ./videos/vid_742.mp4
#   RGB shape: (122, 1024)
#   Flow shape: (122, 1024)
#   Combined shape: (122, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_742.npy
#
# Processing: ./videos/vid_741.mp4
#   RGB shape: (47, 1024)
#   Flow shape: (47, 1024)
#   Combined shape: (47, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_741.npy
#
# Processing: ./videos/vid_740.mp4
#   RGB shape: (25, 1024)
#   Flow shape: (25, 1024)
#   Combined shape: (25, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_740.npy
#
# Processing: ./videos/vid_739.mp4
#   RGB shape: (38, 1024)
#   Flow shape: (38, 1024)
#   Combined shape: (38, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_739.npy
#
# Processing: ./videos/vid_738.mp4
#   RGB shape: (29, 1024)
#   Flow shape: (29, 1024)
#   Combined shape: (29, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_738.npy
#
# Processing: ./videos/vid_737.mp4
#   RGB shape: (33, 1024)
#   Flow shape: (33, 1024)
#   Combined shape: (33, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_737.npy
#
# Processing: ./videos/vid_736.mp4
#   RGB shape: (68, 1024)
#   Flow shape: (68, 1024)
#   Combined shape: (68, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_736.npy
#
# Processing: ./videos/vid_583.mp4
#   RGB shape: (44, 1024)
#   Flow shape: (44, 1024)
#   Combined shape: (44, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_583.npy
#
# Processing: ./videos/vid_582.mp4
#   RGB shape: (32, 1024)
#   Flow shape: (32, 1024)
#   Combined shape: (32, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_582.npy
#
# Processing: ./videos/vid_581.mp4
#   RGB shape: (73, 1024)
#   Flow shape: (73, 1024)
#   Combined shape: (73, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_581.npy
#
# Processing: ./videos/vid_580.mp4
#   RGB shape: (59, 1024)
#   Flow shape: (59, 1024)
#   Combined shape: (59, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_580.npy
#
# Processing: ./videos/vid_579.mp4
#   RGB shape: (59, 1024)
#   Flow shape: (59, 1024)
#   Combined shape: (59, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_579.npy
#
# Processing: ./videos/vid_578.mp4
#   RGB shape: (48, 1024)
#   Flow shape: (48, 1024)
#   Combined shape: (48, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_578.npy
#
# Processing: ./videos/vid_577.mp4
#   RGB shape: (53, 1024)
#   Flow shape: (53, 1024)
#   Combined shape: (53, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_577.npy
#
# Processing: ./videos/vid_576.mp4
#   RGB shape: (31, 1024)
#   Flow shape: (31, 1024)
#   Combined shape: (31, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_576.npy
#
# Processing: ./videos/vid_575.mp4
#   RGB shape: (68, 1024)
#   Flow shape: (68, 1024)
#   Combined shape: (68, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_575.npy
#
# Processing: ./videos/vid_574.mp4
#   RGB shape: (107, 1024)
#   Flow shape: (107, 1024)
#   Combined shape: (107, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_574.npy
#
# Processing: ./videos/vid_573.mp4
#   RGB shape: (48, 1024)
#   Flow shape: (48, 1024)
#   Combined shape: (48, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_573.npy
#
# Processing: ./videos/vid_570.mp4
#   RGB shape: (56, 1024)
#   Flow shape: (56, 1024)
#   Combined shape: (56, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_570.npy
#
# Processing: ./videos/vid_569.mp4
#   RGB shape: (55, 1024)
#   Flow shape: (55, 1024)
#   Combined shape: (55, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_569.npy
#
# Processing: ./videos/vid_568.mp4
#   RGB shape: (73, 1024)
#   Flow shape: (73, 1024)
#   Combined shape: (73, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_568.npy
#
# Processing: ./videos/vid_567.mp4
#   RGB shape: (67, 1024)
#   Flow shape: (67, 1024)
#   Combined shape: (67, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_567.npy
#
# Processing: ./videos/vid_566.mp4
#   RGB shape: (32, 1024)
#   Flow shape: (32, 1024)
#   Combined shape: (32, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_566.npy
#
# Processing: ./videos/vid_565.mp4
#   RGB shape: (50, 1024)
#   Flow shape: (50, 1024)
#   Combined shape: (50, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_565.npy
#
# Processing: ./videos/vid_564.mp4
#   RGB shape: (46, 1024)
#   Flow shape: (46, 1024)
#   Combined shape: (46, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_564.npy
#
# Processing: ./videos/vid_563.mp4
#   RGB shape: (18, 1024)
#   Flow shape: (18, 1024)
#   Combined shape: (18, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_563.npy
#
# Processing: ./videos/vid_562.mp4
#   RGB shape: (42, 1024)
#   Flow shape: (42, 1024)
#   Combined shape: (42, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_562.npy
#
# Processing: ./videos/vid_561.mp4
#   RGB shape: (18, 1024)
#   Flow shape: (18, 1024)
#   Combined shape: (18, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_561.npy
#
# Processing: ./videos/vid_555.mp4
#   RGB shape: (20, 1024)
#   Flow shape: (20, 1024)
#   Combined shape: (20, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_555.npy
#
# Processing: ./videos/vid_554.mp4
#   RGB shape: (34, 1024)
#   Flow shape: (34, 1024)
#   Combined shape: (34, 2048)
#   Successfully saved features to: ./rally_features_i3d_stride_4/vid_554.npy
#
# Feature extraction completed.

# %%
import ndjson
import json
import os
from audio_extract import extract_audio
import requests

# %%
META_DATA_PATH = 'LabelBox/crowd_noise_videos.ndjson'
VIDEOS_DIRECTORY = 'Videos'
AUDIOS_DIRECTORY = 'Audios'
TIMESTAMP_ANNOTATIONS = 'timestamp_annotations.json'

# %%
def download_video(video_url, video_name, video_path):
    """
    Downloads a video from the given URL and saves it with the specified name in the videos folder.
    
    Args:
        video_url (str): The URL of the video to be downloaded.
        video_name (str): The name of the video file.
        videos_folder (str): The path to the folder where the video will be saved.
    """
    if os.path.exists(video_path):
        print(f"Video '{video_path}' already exists. Skipping download.")
        return
    
    
    try:
        response = requests.get(video_url, stream=True)
        if response.status_code == 200:
            with open(video_path, 'wb') as file:
                for chunk in response.iter_content(chunk_size=1024):
                    file.write(chunk)
            print(f"Video '{video_name}' downloaded successfully.")
        else:
            print(f"Error downloading video '{video_name}': {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading video '{video_name}': {e}")

# %%
def video_to_audio(video_path, audio_path):
    """
    Convert a video file to an audio file in .wav format.
    Args:
        video_path (str): Path to the input video file.
        audio_path (str): Path to save the output .wav file.
    """
    try:
        extract_audio(input_path=video_path, output_path=audio_path)

    except Exception as e:
        print(f"An error occurred: {e}")

# %%
processed_data = {}
with open (META_DATA_PATH, 'r') as file:
    metadata = ndjson.load(file)
    for item in metadata:
        video_url = item['data_row']['row_data']
        video_name = item['data_row']['external_id']
        
        video_path = os.path.join(VIDEOS_DIRECTORY, video_name)
        download_video(video_url, video_name, video_path)
        
        audio_name = video_name[:-3] + 'mp3'
        audio_path = os.path.join(AUDIOS_DIRECTORY, audio_name)
        
        video_to_audio(video_path, audio_path)
        video_frame_rate = item['media_attributes']['frame_rate']
        frames = item["projects"]["cloq6ol0d05hp07xvfiy99gg5"]["labels"][0]["annotations"]["frames"]
        
        # Loop through and extract frame numbers
        activities = {}
        for frame, annotations in frames.items():
            frame = int(frame)
            classifications = annotations.get("classifications", [])
            for classification in classifications:
                label_value = classification["value"]
                if label_value not in activities:
                    activities[label_value] = []
                activities[label_value].append(round(frame / video_frame_rate, 1))
        
        for key, times_array in activities.items():
            times_array.sort()
            
            activities[key] = [times_array[i: i + 2] for i in range(0, len(times_array), 2)]
        
        processed_data[audio_name] = activities
# Out:
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F0cf4fef1-0875-4a85-8321-8e88fe76511a-vid_1.mp4?Expires=1733409535986&KeyName=labelbox-assets-key-3&Signature=W8_0KY_8f7l0s0aJGA7v-5q5rBc
# vid_1.mp4
# Videos\vid_1.mp4
# Video 'Videos\vid_1.mp4' already exists. Skipping download.
# An error occurred: File already exists in output path: d:\VS Code Folders\audio_activity_detection\Audios\vid_1.mp3.
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F70001f41-5720-1261-235f-8d4cef947f4a-vid_5.mp4?Expires=1733409535987&KeyName=labelbox-assets-key-3&Signature=jE5oZznYR-Z3Om2jJFAFwZ3_q68
# vid_5.mp4
# Videos\vid_5.mp4
# Video 'vid_5.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_5.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F55f787e3-8d66-ce08-abe1-b658028cd581-vid_7.mp4?Expires=1733409535987&KeyName=labelbox-assets-key-3&Signature=SYiVmg4ZHktP1WyRk7Jg7gyhw1Q
# vid_7.mp4
# Videos\vid_7.mp4
# Video 'vid_7.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_7.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F82af7e33-3868-8ec0-30c0-7b1cd07a6193-vid_17.mp4?Expires=1733409535990&KeyName=labelbox-assets-key-3&Signature=e82TY1p92w5vutXH9FROmsU_B_o
# vid_17.mp4
# Videos\vid_17.mp4
# Video 'vid_17.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_17.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2829e33f-8927-c1ef-ca1d-9b832604e664-vid_32.mp4?Expires=1733409535989&KeyName=labelbox-assets-key-3&Signature=d0MddqGlXQWBi3eURz7hGOLbeIA
# vid_32.mp4
# Videos\vid_32.mp4
# Video 'vid_32.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_32.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2b5a31e1-0f16-6f0d-76a4-c571ca5fd278-vid_35.mp4?Expires=1733409535989&KeyName=labelbox-assets-key-3&Signature=jczL7f_5JhcJRXuzE-6gRpmzfwU
# vid_35.mp4
# Videos\vid_35.mp4
# Video 'vid_35.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_35.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd102d8a7-2139-da17-9bda-bfeba632b6c8-vid_42.mp4?Expires=1733409535995&KeyName=labelbox-assets-key-3&Signature=YUgzaL7c-ig0c1ETmhQvubo4kh4
# vid_42.mp4
# Videos\vid_42.mp4
# Video 'vid_42.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_42.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F323bb328-0b89-f10e-d979-b986f2577602-vid_58.mp4?Expires=1733409535992&KeyName=labelbox-assets-key-3&Signature=T1bwQGGZzDn_Ys5gt_qu9Ahvl5Y
# vid_58.mp4
# Videos\vid_58.mp4
# Video 'vid_58.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_58.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F73493f99-61cd-f7bd-80ee-996a89e01351-vid_65.mp4?Expires=1733409535992&KeyName=labelbox-assets-key-3&Signature=PEiggCwOhL1bCiTZx3vbt1hRcac
# vid_65.mp4
# Videos\vid_65.mp4
# Video 'vid_65.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_65.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2761dd19-ee41-80d3-fba1-190c1e16c350-vid_70.mp4?Expires=1733409535993&KeyName=labelbox-assets-key-3&Signature=LxF1UfYt0SaKI5657FG_wRe3aCk
# vid_70.mp4
# Videos\vid_70.mp4
# Video 'vid_70.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_70.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F92fc03bc-e919-9c01-c0ce-01a86b06729f-vid_71.mp4?Expires=1733409536002&KeyName=labelbox-assets-key-3&Signature=FJ-Scf6ezDAaOLOG_nAEJIxZZQA
# vid_71.mp4
# Videos\vid_71.mp4
# Video 'vid_71.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_71.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb16b60be-3032-49b0-a820-6b0cc187c2a4-vid_79.mp4?Expires=1733409536003&KeyName=labelbox-assets-key-3&Signature=M61H9mGXx_cbodcQfr36VmewS6M
# vid_79.mp4
# Videos\vid_79.mp4
# Video 'vid_79.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_79.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2a18db4a-8ac4-0bc3-b202-6fb171e39b8b-vid_90.mp4?Expires=1733409536003&KeyName=labelbox-assets-key-3&Signature=uCNZ92Mo8iDdl3BP57AOIaQOiDA
# vid_90.mp4
# Videos\vid_90.mp4
# Video 'vid_90.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_90.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F8e39ee77-34c5-e203-b37c-135bf1be692e-vid_93.mp4?Expires=1733409536008&KeyName=labelbox-assets-key-3&Signature=pJi60COOw_OoaNTs5KUJKm2xpIw
# vid_93.mp4
# Videos\vid_93.mp4
# Video 'vid_93.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_93.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Faae5da5d-5fc4-77e0-1047-568a129d8f49-vid_95.mp4?Expires=1733409536010&KeyName=labelbox-assets-key-3&Signature=Je5DAgPdoveJtdkH6aYApcoKtn0
# vid_95.mp4
# Videos\vid_95.mp4
# Video 'vid_95.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_95.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F90c50acb-e881-a6c4-1ff0-766f0dcfd58f-vid_96.mp4?Expires=1733409536011&KeyName=labelbox-assets-key-3&Signature=dORsOFuIbJJoFEslmIQsrbw8wls
# vid_96.mp4
# Videos\vid_96.mp4
# Video 'vid_96.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_96.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F93127c5a-eacb-fdbd-28c3-846ce223f7b6-vid_97.mp4?Expires=1733409536012&KeyName=labelbox-assets-key-3&Signature=fbdfauo9WDq2UGve9l5mFyEXOrM
# vid_97.mp4
# Videos\vid_97.mp4
# Video 'vid_97.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_97.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F8f8ee024-e142-6232-01bd-38264dfee031-vid_98.mp4?Expires=1733409536013&KeyName=labelbox-assets-key-3&Signature=JcMnYe1tTIhTTSC6YcpBBWmtyGs
# vid_98.mp4
# Videos\vid_98.mp4
# Video 'vid_98.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_98.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd2deb11a-7360-dfe8-4400-d87794a00a3c-vid_99.mp4?Expires=1733409536014&KeyName=labelbox-assets-key-3&Signature=Q3-x-MCi5GXNqYJrEOTpGWIzvco
# vid_99.mp4
# Videos\vid_99.mp4
# Video 'vid_99.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_99.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fdfc4ca2e-e775-8531-ec74-f012c57c26b5-vid_101.mp4?Expires=1733409536017&KeyName=labelbox-assets-key-3&Signature=2h4S3Xeh-Q6duL6aL6pl0-fcPp8
# vid_101.mp4
# Videos\vid_101.mp4
# Video 'vid_101.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_101.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fec2c9cee-a92b-1a4b-fe81-70686979f752-vid_102.mp4?Expires=1733409536018&KeyName=labelbox-assets-key-3&Signature=3yxQOowPcd4M3XoazoHlxPoDENE
# vid_102.mp4
# Videos\vid_102.mp4
# Video 'vid_102.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_102.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F73e9a7fb-563c-43e0-6a3c-2d6f0abe13a3-vid_103.mp4?Expires=1733409536018&KeyName=labelbox-assets-key-3&Signature=91W_eQfrT075OIUXdSWZQ-kvVm0
# vid_103.mp4
# Videos\vid_103.mp4
# Video 'vid_103.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_103.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fbbf4fc1c-48b6-7c41-a1cf-b3d5f5bbef2f-vid_104.mp4?Expires=1733409536023&KeyName=labelbox-assets-key-3&Signature=42uQZmsko3KHoVzXyZC-tf95S7U
# vid_104.mp4
# Videos\vid_104.mp4
# Video 'vid_104.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_104.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2b05bc98-31ad-9c76-a10e-6542ad6b7370-vid_105.mp4?Expires=1733409536023&KeyName=labelbox-assets-key-3&Signature=0U4434PmDw9L9qsJQo4gOew-KVA
# vid_105.mp4
# Videos\vid_105.mp4
# Video 'vid_105.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_105.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F3c7ee6c9-48fb-6a66-c9bc-235a6938c30a-vid_109.mp4?Expires=1733409536024&KeyName=labelbox-assets-key-3&Signature=ptC2HCIzf7-LUBuZd4ojwOsJrHI
# vid_109.mp4
# Videos\vid_109.mp4
# Video 'vid_109.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_109.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F79c5859c-9b9b-14a0-a38a-a46f781182e8-vid_111.mp4?Expires=1733409536024&KeyName=labelbox-assets-key-3&Signature=OAg30xD7e7M87F_JaYse8NV_szE
# vid_111.mp4
# Videos\vid_111.mp4
# Video 'vid_111.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_111.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F38a9a22c-a850-43df-4935-4b06bec6eeb5-vid_114.mp4?Expires=1733409536028&KeyName=labelbox-assets-key-3&Signature=SGfXrg1VZXoe3jslSReZQRYtEwk
# vid_114.mp4
# Videos\vid_114.mp4
# Video 'vid_114.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_114.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F01b89020-3747-5169-3e26-88e221f23497-vid_115.mp4?Expires=1733409536028&KeyName=labelbox-assets-key-3&Signature=Ekxil5xiHneTnF8RkcusVNACp_Y
# vid_115.mp4
# Videos\vid_115.mp4
# Video 'vid_115.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_115.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fdcd4e03d-4a21-8ecb-0712-3e505c7d07c7-vid_117.mp4?Expires=1733409536027&KeyName=labelbox-assets-key-3&Signature=oo3DRaKRkvXO99uXjZs2SDUhzvE
# vid_117.mp4
# Videos\vid_117.mp4
# Video 'vid_117.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_117.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F88a96d93-7c15-b307-3819-0da5b7565bbd-vid_118.mp4?Expires=1733409536031&KeyName=labelbox-assets-key-3&Signature=ev3Coy8FNcfA2YUc5oKttHtVNO0
# vid_118.mp4
# Videos\vid_118.mp4
# Video 'vid_118.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_118.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F7924d1ca-4d95-6d23-cff9-5f52f6bb0e2a-vid_121.mp4?Expires=1733409536031&KeyName=labelbox-assets-key-3&Signature=xyvgOVFLwmcSTUodpAXtV3zXang
# vid_121.mp4
# Videos\vid_121.mp4
# Video 'vid_121.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_121.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fec1ef9e8-07d8-1b7a-7564-c8aa0db3df8a-vid_123.mp4?Expires=1733409536036&KeyName=labelbox-assets-key-3&Signature=tN71M9nfnmvuMjrEpgZa9aSSgo8
# vid_123.mp4
# Videos\vid_123.mp4
# Video 'vid_123.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_123.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fcf2189dc-e84e-3218-e0d6-b15bd42a2686-vid_125.mp4?Expires=1733409536036&KeyName=labelbox-assets-key-3&Signature=HVjRfBlQa1aTboR93GmB7653X_8
# vid_125.mp4
# Videos\vid_125.mp4
# Video 'vid_125.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_125.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2bf64b49-3170-5eba-e6ca-3cb8c514dce0-vid_127.mp4?Expires=1733409536035&KeyName=labelbox-assets-key-3&Signature=jVyvQtNHCH59STd9aI7WeGYX0Bw
# vid_127.mp4
# Videos\vid_127.mp4
# Video 'vid_127.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_127.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Ffd302af7-2ef3-a435-5304-dd56842a3858-vid_130.mp4?Expires=1733409536038&KeyName=labelbox-assets-key-3&Signature=gzggK2tCTz0yJxmcMmpbNviQLlI
# vid_130.mp4
# Videos\vid_130.mp4
# Video 'vid_130.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_130.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F1dea26a1-cfd7-641c-1ee4-ac130b365573-vid_131.mp4?Expires=1733409536039&KeyName=labelbox-assets-key-3&Signature=I1kQSc2yaa_LdPtbemSp3Z0nvno
# vid_131.mp4
# Videos\vid_131.mp4
# Video 'vid_131.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_131.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb3951ebc-2a14-02c8-b3ae-5275aedc37a0-vid_132.mp4?Expires=1733409536039&KeyName=labelbox-assets-key-3&Signature=td0hyXd9I-D6zvuQQaTKH-5QsX0
# vid_132.mp4
# Videos\vid_132.mp4
# Video 'vid_132.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_132.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F26471c63-4a1c-a46e-cc06-a0a9ea7b298c-vid_133.mp4?Expires=1733409536040&KeyName=labelbox-assets-key-3&Signature=n4dk-1NoPuCVS_efA3uNCQ_59uU
# vid_133.mp4
# Videos\vid_133.mp4
# Video 'vid_133.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_133.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd0067201-4f71-2cb6-8ff3-1c511ea99571-vid_134.mp4?Expires=1733409536041&KeyName=labelbox-assets-key-3&Signature=us72WCnFS9J_qVBbvn1ka2g-X28
# vid_134.mp4
# Videos\vid_134.mp4
# Video 'vid_134.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_134.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F7d3b66db-309f-f64f-8e0d-5a700211ebf3-vid_137.mp4?Expires=1733409536041&KeyName=labelbox-assets-key-3&Signature=fgWrsNJNBWJHfNPR4SZr9WlkpMg
# vid_137.mp4
# Videos\vid_137.mp4
# Video 'vid_137.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_137.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F937a2154-2ee5-1876-7d8d-b0188901008e-vid_138.mp4?Expires=1733409536040&KeyName=labelbox-assets-key-3&Signature=3xVFlHg8f-H3dKJlwmTB8vi7ZUk
# vid_138.mp4
# Videos\vid_138.mp4
# Video 'vid_138.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_138.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F8117bb88-b8cc-8686-bfed-d86a7c599636-vid_141.mp4?Expires=1733409536046&KeyName=labelbox-assets-key-3&Signature=hZ8o0155E9Ze80-ono0sht3tpco
# vid_141.mp4
# Videos\vid_141.mp4
# Video 'vid_141.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_141.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Faf639fc1-22ef-05ab-9278-c12f4db4bebc-vid_142.mp4?Expires=1733409536047&KeyName=labelbox-assets-key-3&Signature=cfTR1QvrEef2z6RVWt18HBjKWKY
# vid_142.mp4
# Videos\vid_142.mp4
# Video 'vid_142.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_142.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F4a43f042-5d7e-e7ac-fa98-a2d730f2da1c-vid_143.mp4?Expires=1733409536048&KeyName=labelbox-assets-key-3&Signature=oJrvFLQ7w4PT-5DC7OOrjCFSkOY
# vid_143.mp4
# Videos\vid_143.mp4
# Video 'vid_143.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_143.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F1dd1c630-a6a1-dc15-0a9f-c1be1ab5dacc-vid_144.mp4?Expires=1733409536048&KeyName=labelbox-assets-key-3&Signature=z-w3sbW5OyhWo34b8MH4TT-DpF8
# vid_144.mp4
# Videos\vid_144.mp4
# Video 'vid_144.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_144.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F5f568a41-54e4-3887-94e0-9091a4749e64-vid_146.mp4?Expires=1733409536047&KeyName=labelbox-assets-key-3&Signature=UDsdFPd69iEfynepMvFd6lts4BQ
# vid_146.mp4
# Videos\vid_146.mp4
# Video 'vid_146.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_146.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F14c865df-b6e7-8425-4948-32cfcb47e652-vid_148.mp4?Expires=1733409536051&KeyName=labelbox-assets-key-3&Signature=3ypb7_I4hp65DK18nrS2dwz9B40
# vid_148.mp4
# Videos\vid_148.mp4
# Video 'vid_148.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_148.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Ff8dc978d-2cc5-81b2-74e5-17c74088b22f-vid_150.mp4?Expires=1733409536052&KeyName=labelbox-assets-key-3&Signature=vODIJQj9c6ouPZAEsJtzFkazwZs
# vid_150.mp4
# Videos\vid_150.mp4
# Video 'vid_150.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_150.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F29adcf2b-6591-d3bb-d4fa-df36b2d36562-vid_152.mp4?Expires=1733409536052&KeyName=labelbox-assets-key-3&Signature=WyQSRILu_wqQSs_1XYyIMb8ZcD0
# vid_152.mp4
# Videos\vid_152.mp4
# Video 'vid_152.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_152.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F1b784ed6-97f8-bb3c-d879-6f9b14a577f8-vid_153.mp4?Expires=1733409536053&KeyName=labelbox-assets-key-3&Signature=nEScgp9TU-Qa5P1e0z-MOg1Biyg
# vid_153.mp4
# Videos\vid_153.mp4
# Video 'vid_153.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_153.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb30d2ee8-2bfb-d3ba-6b16-90389e15f1c2-vid_157.mp4?Expires=1733409536057&KeyName=labelbox-assets-key-3&Signature=KUz_5kMtAEkR3fe8A9DlDhh26Is
# vid_157.mp4
# Videos\vid_157.mp4
# Video 'vid_157.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_157.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F7fa70078-5ebe-5ea3-d573-c6ea238f2bd9-vid_160.mp4?Expires=1733409536057&KeyName=labelbox-assets-key-3&Signature=gFbKTZfJv0OxtPJAt_nvCNlPp8I
# vid_160.mp4
# Videos\vid_160.mp4
# Video 'vid_160.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_160.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F0ae80337-c1aa-4348-7b48-022474ca0e97-vid_170.mp4?Expires=1733409536056&KeyName=labelbox-assets-key-3&Signature=T2OtcSDQVTR6D2kja21gCkFYfFQ
# vid_170.mp4
# Videos\vid_170.mp4
# Video 'vid_170.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_170.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F3f561251-c251-6e39-02a7-bbb387a2b3cd-vid_171.mp4?Expires=1733409536059&KeyName=labelbox-assets-key-3&Signature=5TwNVmVzdZldN1hnoq2MhSVe5us
# vid_171.mp4
# Videos\vid_171.mp4
# Video 'vid_171.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_171.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fbeb5834d-8886-a1ed-cc74-289efa15f281-vid_125.mp4?Expires=1733409536060&KeyName=labelbox-assets-key-3&Signature=9rxp6WRzjsCnOREeOvjaYFLDylA
# vid_125.mp4
# Videos\vid_125.mp4
# Video 'Videos\vid_125.mp4' already exists. Skipping download.
# An error occurred: File already exists in output path: d:\VS Code Folders\audio_activity_detection\Audios\vid_125.mp3.
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb045236d-13bd-04cc-47a5-e28f0451b047-vid_172.mp4?Expires=1733409536065&KeyName=labelbox-assets-key-3&Signature=Zm2Rv6s070Ei6rw4W-hvOx8Prxc
# vid_172.mp4
# Videos\vid_172.mp4
# Video 'vid_172.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_172.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F8d8d3f85-cf29-a555-d49e-d61891d01676-vid_173.mp4?Expires=1733409536065&KeyName=labelbox-assets-key-3&Signature=vGXbGKcijaZ8XVi51hvGWGcWMPo
# vid_173.mp4
# Videos\vid_173.mp4
# Video 'vid_173.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_173.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb22d670a-3419-48fd-b73a-0369fba8dd48-vid_174.mp4?Expires=1733409536064&KeyName=labelbox-assets-key-3&Signature=0TJ0cRlFXQgZGph7TYtQuOJpmlY
# vid_174.mp4
# Videos\vid_174.mp4
# Video 'vid_174.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_174.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F32d49c8f-5456-a44b-beb3-797c6f2a8b19-vid_175.mp4?Expires=1733409536073&KeyName=labelbox-assets-key-3&Signature=OEmo-m93-VOm_r5Mo2Ae42zOhVY
# vid_175.mp4
# Videos\vid_175.mp4
# Video 'vid_175.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_175.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2f110b3e-43c1-fefb-7050-37176f225c21-vid_179.mp4?Expires=1733409536074&KeyName=labelbox-assets-key-3&Signature=j_6L6-9JOSYBv7b7x-yEtOj0yoA
# vid_179.mp4
# Videos\vid_179.mp4
# Video 'vid_179.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_179.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb216b233-c6d8-e516-8e45-7d2c11d7c04c-vid_182.mp4?Expires=1733409536074&KeyName=labelbox-assets-key-3&Signature=cXl-Kmcu3NvpNHFtxuml_CGODFQ
# vid_182.mp4
# Videos\vid_182.mp4
# Video 'vid_182.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_182.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fe0725b3a-d1a0-b132-9439-313337b60d62-vid_183.mp4?Expires=1733409536075&KeyName=labelbox-assets-key-3&Signature=OqdIvxWFklpIEe8bMDPkcqV0-HA
# vid_183.mp4
# Videos\vid_183.mp4
# Video 'vid_183.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_183.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fa40371f4-75dd-3e39-6d69-ef4a2f00d57b-vid_184.mp4?Expires=1733409536076&KeyName=labelbox-assets-key-3&Signature=IPwpepeL9y_asi7se6gR7Tw4O7g
# vid_184.mp4
# Videos\vid_184.mp4
# Video 'vid_184.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_184.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F6ad4b23a-19af-a65a-77f7-ff6a6762ecf8-vid_177.mp4?Expires=1733409536076&KeyName=labelbox-assets-key-3&Signature=2O4n-s-9tRI-m3z8uOvURGdMkgw
# vid_177.mp4
# Videos\vid_177.mp4
# Video 'vid_177.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_177.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F62d8dfab-a26e-c780-5c2f-37308b676f2d-vid_178.mp4?Expires=1733409536076&KeyName=labelbox-assets-key-3&Signature=vlF1htzalakJtsz67wCaBXtOM_0
# vid_178.mp4
# Videos\vid_178.mp4
# Video 'vid_178.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_178.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F12ffc163-2fd8-b746-c721-358d7b9104e0-vid_180.mp4?Expires=1733409536080&KeyName=labelbox-assets-key-3&Signature=kJwUuskafBpA3VfGp2mkufF6axI
# vid_180.mp4
# Videos\vid_180.mp4
# Video 'vid_180.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_180.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Ffbc7b430-9602-d379-21b2-d475344992e1-vid_181.mp4?Expires=1733409536081&KeyName=labelbox-assets-key-3&Signature=519FHTvy5XxgIo0AuZDtCnHOH9Y
# vid_181.mp4
# Videos\vid_181.mp4
# Video 'vid_181.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_181.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F86dbcab0-caab-9ca9-acc2-6a426d6dd0fb-vid_196.mp4?Expires=1733409536083&KeyName=labelbox-assets-key-3&Signature=Ik5B_wEYd-pVKrvheg2UAKGvKd8
# vid_196.mp4
# Videos\vid_196.mp4
# Video 'vid_196.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_196.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F7020daef-3843-d68e-a525-a6b964fd62e1-vid_208.mp4?Expires=1733409536082&KeyName=labelbox-assets-key-3&Signature=igQ4_iSQmGIVM1Js-TKNMnMIJpM
# vid_208.mp4
# Videos\vid_208.mp4
# Video 'vid_208.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_208.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F6259d98c-aa97-42d4-584c-f456657d917b-vid_237.mp4?Expires=1733409536082&KeyName=labelbox-assets-key-3&Signature=x_SYLZLuJCu-qbE8o9UX263p4CY
# vid_237.mp4
# Videos\vid_237.mp4
# Video 'vid_237.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_237.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fddd501d4-82b7-2c07-f21b-513c16acbca1-vid_240.mp4?Expires=1733409536086&KeyName=labelbox-assets-key-3&Signature=54p5IbnL8C9bpUlZlRAE9yZ_RHI
# vid_240.mp4
# Videos\vid_240.mp4
# Video 'vid_240.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_240.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F99bf6fea-ca32-48c3-63e9-94aa1ea79f20-vid_198.mp4?Expires=1733409536087&KeyName=labelbox-assets-key-3&Signature=saee99fJPeZp0zxb8qjO7PyA-Nk
# vid_198.mp4
# Videos\vid_198.mp4
# Video 'vid_198.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_198.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fe90d7b5b-c664-c683-6860-5592e66e4b2a-vid_472.mp4?Expires=1733409536087&KeyName=labelbox-assets-key-3&Signature=hHKq3xcvXBD8ajM1GjBspPakd60
# vid_472.mp4
# Videos\vid_472.mp4
# Video 'vid_472.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_472.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fb069a6c7-6411-c4fd-0949-41571176aa4a-vid_475.mp4?Expires=1733409536088&KeyName=labelbox-assets-key-3&Signature=qQpPGYJD-3zVKXhPHL173UuJXc4
# vid_475.mp4
# Videos\vid_475.mp4
# Video 'vid_475.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_475.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F083f90f8-a1f1-350c-c7ad-dfdedfaf63ab-vid_427.mp4?Expires=1733409536089&KeyName=labelbox-assets-key-3&Signature=J8C2qeH9DTpxvMuEMeuu6V3xKAI
# vid_427.mp4
# Videos\vid_427.mp4
# Video 'vid_427.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_427.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F92fb434e-fd6a-4678-0ea8-b5d396a4216b-vid_433.mp4?Expires=1733409536089&KeyName=labelbox-assets-key-3&Signature=OtOmuFbBa3_O5LGpnKHPUwKCMRA
# vid_433.mp4
# Videos\vid_433.mp4
# Video 'vid_433.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_433.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2c8f4cc4-0b9a-1bab-6428-532b62646293-vid_446.mp4?Expires=1733409536088&KeyName=labelbox-assets-key-3&Signature=d0fQ7x3oJswq8b5LpKPZmRVSn5M
# vid_446.mp4
# Videos\vid_446.mp4
# Video 'vid_446.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_446.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F8c9b5093-9944-f42d-34ac-9c9280edaa2d-vid_458.mp4?Expires=1733409536094&KeyName=labelbox-assets-key-3&Signature=m6nALnzz3wQQbs36ceQQ2d-WgVo
# vid_458.mp4
# Videos\vid_458.mp4
# Video 'vid_458.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_458.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fc73bbb0d-1333-19da-1a07-a7397696acc0-vid_295.mp4?Expires=1733409536095&KeyName=labelbox-assets-key-3&Signature=8l2jcw2YbbdG-v9pT8H0U9MvLho
# vid_295.mp4
# Videos\vid_295.mp4
# Video 'vid_295.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_295.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F88fc87fb-a2fe-e5f6-e9b8-fd682c016793-vid_304.mp4?Expires=1733409536096&KeyName=labelbox-assets-key-3&Signature=HVfSrvTIjvwfu72aH_nPAcfy5ek
# vid_304.mp4
# Videos\vid_304.mp4
# Video 'vid_304.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_304.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fc67782c7-f879-023f-55cc-2e6016a3d3a9-vid_317.mp4?Expires=1733409536096&KeyName=labelbox-assets-key-3&Signature=65KErCHS_w3vm5ry2ZtJHIvIbvo
# vid_317.mp4
# Videos\vid_317.mp4
# Video 'vid_317.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_317.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2d675cb2-832f-8347-74c4-000898012263-vid_320.mp4?Expires=1733409536095&KeyName=labelbox-assets-key-3&Signature=vc8W7CbtXueqBOYzFwNlxuf4g4Y
# vid_320.mp4
# Videos\vid_320.mp4
# Video 'vid_320.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_320.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2547d646-ad0a-591d-a355-5609411209c2-vid_325.mp4?Expires=1733409536099&KeyName=labelbox-assets-key-3&Signature=6upX_-cBZVEcrqxFr4IZty11RbM
# vid_325.mp4
# Videos\vid_325.mp4
# Video 'vid_325.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_325.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd58e63dc-0b52-12b5-d8ca-3e7a09a65e68-vid_331.mp4?Expires=1733409536100&KeyName=labelbox-assets-key-3&Signature=CFMiZnamZIQOqQKP6zvLTUxE4q0
# vid_331.mp4
# Videos\vid_331.mp4
# Video 'vid_331.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_331.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fe96089c8-8eb7-ce00-6e51-2f85c28d4c20-vid_344.mp4?Expires=1733409536100&KeyName=labelbox-assets-key-3&Signature=VCH5sFxtEqgA07GAOKX1XqIn-L8
# vid_344.mp4
# Videos\vid_344.mp4
# Video 'vid_344.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_344.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Ff529b106-3db2-4266-ca0c-b2a731ece135-vid_351.mp4?Expires=1733409536101&KeyName=labelbox-assets-key-3&Signature=yZkfQU_LNjl_lX-aPBpfOsEZLjI
# vid_351.mp4
# Videos\vid_351.mp4
# Video 'vid_351.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_351.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F16fed9f2-9a22-a255-4ee6-3114990e31ba-vid_352.mp4?Expires=1733409536102&KeyName=labelbox-assets-key-3&Signature=N_ixnbrlo2MfODEhiwLUiEiZhjA
# vid_352.mp4
# Videos\vid_352.mp4
# Video 'vid_352.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_352.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F87c57ffa-95a2-1b52-539d-c381b9b8b0d5-vid_372.mp4?Expires=1733409536101&KeyName=labelbox-assets-key-3&Signature=u5YxfvnjkZMaIMd946UPuOS2UZo
# vid_372.mp4
# Videos\vid_372.mp4
# Video 'vid_372.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_372.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F11dfe3a1-2b1b-71ac-4e19-2a2b9dca260a-vid_374.mp4?Expires=1733409536101&KeyName=labelbox-assets-key-3&Signature=6RG7PMu6MDCHrwNf33uQdGLvVvw
# vid_374.mp4
# Videos\vid_374.mp4
# Video 'vid_374.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_374.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd43ba806-3f25-a0ee-73ad-493cc716f304-vid_375.mp4?Expires=1733409536105&KeyName=labelbox-assets-key-3&Signature=YL1QFgfyxxt6vqaY2xNOuSxgbYg
# vid_375.mp4
# Videos\vid_375.mp4
# Video 'vid_375.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_375.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F29532b50-569c-5c6d-2202-39e27fba191d-vid_393.mp4?Expires=1733409536105&KeyName=labelbox-assets-key-3&Signature=HHv39i2WmEQwd3MKRMA4LREhdSE
# vid_393.mp4
# Videos\vid_393.mp4
# Video 'vid_393.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_393.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F2a849e1d-d38a-fa0e-a7fd-c575e1750656-vid_394.mp4?Expires=1733409536107&KeyName=labelbox-assets-key-3&Signature=2J4IX1yWR6OoAUPPzM_398qr8vc
# vid_394.mp4
# Videos\vid_394.mp4
# Video 'vid_394.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_394.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F5b3f0030-e3f8-a2f7-f8f7-d2124fca303b-vid_496.mp4?Expires=1733409536106&KeyName=labelbox-assets-key-3&Signature=Jx_1iFO8E9yI8sUnWtXl4RvhZxw
# vid_496.mp4
# Videos\vid_496.mp4
# Video 'vid_496.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_496.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F9e13d457-28fe-0e1d-5e0b-b94f3c7ca6a2-vid_500.mp4?Expires=1733409536106&KeyName=labelbox-assets-key-3&Signature=l-1EkYyXVRftSKTyTHjob8iLzq8
# vid_500.mp4
# Videos\vid_500.mp4
# Video 'vid_500.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_500.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F222a9bcf-13ef-a199-471d-6ab566e114ad-vid_506.mp4?Expires=1733409536109&KeyName=labelbox-assets-key-3&Signature=F-EX1QysPetDO-rw97P0GI6WJY4
# vid_506.mp4
# Videos\vid_506.mp4
# Video 'vid_506.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_506.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fd465b712-d5ae-bfb1-81bb-9ecbd5e0897e-vid_511.mp4?Expires=1733409536109&KeyName=labelbox-assets-key-3&Signature=aZ-u0yGz-23DBb-HGPARy9s5xOQ
# vid_511.mp4
# Videos\vid_511.mp4
# Video 'vid_511.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_511.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fec9c91b2-d1e0-5ebb-9139-c5576410eca7-vid_515.mp4?Expires=1733409536109&KeyName=labelbox-assets-key-3&Signature=v2jcs5zhz9U6UTs7pRErDM3c-X0
# vid_515.mp4
# Videos\vid_515.mp4
# Video 'vid_515.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_515.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fe68537d0-7394-2e80-e197-fe05fe1278ce-vid_516.mp4?Expires=1733409536110&KeyName=labelbox-assets-key-3&Signature=HoDiT3fcrwY3A9UnbliJSjRvXNA
# vid_516.mp4
# Videos\vid_516.mp4
# Video 'vid_516.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_516.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F3ee618f0-733a-ea66-e3f8-b71970b3bde8-vid_524.mp4?Expires=1733409536111&KeyName=labelbox-assets-key-3&Signature=KsrQDLTQflI9WqaeF-0rzPRI2bk
# vid_524.mp4
# Videos\vid_524.mp4
# Video 'vid_524.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_524.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F49fb9866-3f88-287c-39cb-3e2a067ba548-vid_527.mp4?Expires=1733409536110&KeyName=labelbox-assets-key-3&Signature=H4cWmix3docUPGWd87Ye-6AjsXQ
# vid_527.mp4
# Videos\vid_527.mp4
# Video 'vid_527.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_527.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Fa32d8328-064a-7d8b-f3c1-38e80e3abd65-vid_533.mp4?Expires=1733409536110&KeyName=labelbox-assets-key-3&Signature=iz9lnsaHwZxAMhO9E0LXqMfZQ08
# vid_533.mp4
# Videos\vid_533.mp4
# Video 'vid_533.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_533.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F7d1e8652-47d0-587e-276c-de61b69c7f63-vid_536.mp4?Expires=1733409536121&KeyName=labelbox-assets-key-3&Signature=boqnw8S7eZYOsygxp_3Y6tO-ARg
# vid_536.mp4
# Videos\vid_536.mp4
# Video 'vid_536.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_536.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F15686dda-159e-d8c0-d9c3-8db9428c8f6d-vid_541.mp4?Expires=1733409536121&KeyName=labelbox-assets-key-3&Signature=ae13mNi_i_erVa2gESjpxhT357k
# vid_541.mp4
# Videos\vid_541.mp4
# Video 'vid_541.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_541.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F0ee69a8c-1940-ab51-4e55-7973488671ff-vid_543.mp4?Expires=1733409536122&KeyName=labelbox-assets-key-3&Signature=xFXO6Oct7kBpyXjIaCQKmgsgyds
# vid_543.mp4
# Videos\vid_543.mp4
# Video 'vid_543.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_543.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F90239dc2-d826-e992-79c2-248827c15769-vid_546.mp4?Expires=1733409536122&KeyName=labelbox-assets-key-3&Signature=luux5CiD08Cp2FlgYIYu2Y-DpUY
# vid_546.mp4
# Videos\vid_546.mp4
# Video 'vid_546.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_546.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2F82c850fe-0549-0064-90d1-02601a55f03c-vid_389.mp4?Expires=1733409536122&KeyName=labelbox-assets-key-3&Signature=4axosvosKUyqNIe15sZZXb_wmNo
# vid_389.mp4
# Videos\vid_389.mp4
# Video 'vid_389.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_389.mp3".
# https://storage.labelbox.com/cloq65e7f04db07zja4dya06y%2Ffb2e5853-22e9-0aa5-72ab-dec294810d50-vid_531.mp4?Expires=1733409536125&KeyName=labelbox-assets-key-3&Signature=m37p1RbRdqXqhoWShnbvwB48kmQ
# vid_531.mp4
# Videos\vid_531.mp4
# Video 'vid_531.mp4' downloaded successfully.
# Success : audio file has been saved to "d:\VS Code Folders\audio_activity_detection\Audios\vid_531.mp3".

# %%
processed_data
# Out:
# {'vid_1.mp3': {'crowd_noise': [[6.5, 10.1]], 'long_noise': [[8.1, 10.1]]},
#  'vid_5.mp3': {'drift': [[0.1, 1.3]],
#   'high_speed': [[3.2, 4.7], [5.0, 6.5]],
#   'crowd_noise': [[11.5, 12.2]],
#   'long_noise': [[10.3, 11.1]],
#   'turn': [[0.1, 1.7]]},
#  'vid_7.mp3': {'high_speed': [[8.0, 18.0]],
#   'crowd_noise': [[18.5, 20.2]],
#   'turn': [[6.6, 9.0], [19.1, 19.9]]},
#  'vid_17.mp3': {'high_speed': [[0.9, 2.6]],
#   'turn': [[2.9, 6.2], [12.7, 14.3]],
#   'long_noise': [[3.2, 4.0], [6.0, 6.4]],
#   'crowd_noise': [[10.3, 13.9], [22.0, 24.1]]},
#  'vid_32.mp3': {'turn': [[1.2, 4.3]], 'crowd_noise': [[2.6, 3.2]]},
#  'vid_35.mp3': {'high_speed': [[2.0, 3.9], [10.1, 10.8]],
#   'turn': [[7.7, 8.7]],
#   'crowd_noise': [[5.4, 6.7]]},
#  'vid_42.mp3': {'drift': [[0.8, 1.6]], 'crowd_noise': [[7.0, 11.7]]},
#  'vid_58.mp3': {'crowd_noise': [[9.7, 11.7], [14.8, 15.3]]},
#  'vid_65.mp3': {'high_speed': [[3.8, 4.4]],
#   'crowd_noise': [[2.3, 2.6], [11.5, 20.4]],
#   'long_noise': [[10.2, 10.6]]},
#  'vid_70.mp3': {'turn': [[2.5, 2.9]], 'crowd_noise': [[6.8, 8.0]]},
#  'vid_71.mp3': {'turn': [[3.0, 3.9], [4.5, 5.9]],
#   'drift': [[4.9, 5.8]],
#   'crowd_noise': [[11.2, 27.3]],
#   'long_noise': [[7.5, 9.0], [10.3, 11.9]]},
#  'vid_79.mp3': {'high_speed': [[0.4, 2.6]],
#   'crowd_noise': [[5.2, 6.3]],
#   'turn': [[12.1, 14.7], [15.4, 17.7]],
#   'drift': [[16.6, 18.0]]},
#  'vid_90.mp3': {'crowd_noise': [[4.9, 6.1]],
#   'high_speed': [[2.7, 3.0]],
#   'jump': [[4.4, 4.9]]},
#  'vid_93.mp3': {'crowd_noise': [[3.1, 4.5]],
#   'high_speed': [[0.0, 4.5]],
#   'turn': [[1.0, 2.2]],
#   'cut': [[1.8, 2.2]],
#   'jump': [[2.3, 2.7]]},
#  'vid_95.mp3': {'turn': [[1.8, 4.1]],
#   'crash': [[3.8, 6.3]],
#   'long_noise': [[4.8, 6.3]],
#   'crowd_noise': [[3.9, 6.0]]},
#  'vid_96.mp3': {'crowd_noise': [[4.0, 4.8]],
#   'high_speed': [[0.4, 4.8]],
#   'turn': [[0.4, 1.2], [1.5, 3.8]],
#   'cut': [[0.4, 1.0], [3.0, 3.4]],
#   'jump': [[3.5, 3.8]]},
#  'vid_97.mp3': {'crowd_noise': [[6.7, 7.4]],
#   'turn': [[0.0, 0.8], [6.1, 7.4]],
#   'drift': [[3.0, 4.4], [4.8, 6.1]],
#   'cut': [[0.8, 6.3]],
#   'long_noise': [[1.7, 2.6]]},
#  'vid_98.mp3': {'high_speed': [[0.0, 5.2]],
#   'crowd_noise': [[3.5, 5.2]],
#   'jump': [[1.8, 2.2]],
#   'drift': [[2.7, 4.2]],
#   'long_noise': [[1.6, 2.7]]},
#  'vid_99.mp3': {'crowd_noise': [[1.2, 5.4]],
#   'jump': [[0.9, 2.0]],
#   'crash': [[0.8, 3.4]],
#   'long_noise': [[0.2, 1.2], [2.0, 4.5]]},
#  'vid_101.mp3': {'high_speed': [[0.0, 2.8]],
#   'drift': [[3.5, 6.1]],
#   'turn': [[6.1, 7.0]],
#   'crowd_noise': [[4.6, 7.3]],
#   'long_noise': [[0.5, 0.9], [4.2, 6.3]]},
#  'vid_102.mp3': {'high_speed': [[0.0, 3.6]],
#   'turn': [[0.8, 4.2]],
#   'drift': [[3.3, 6.0]],
#   'crash': [[6.0, 8.6]],
#   'crowd_noise': [[6.6, 8.6]],
#   'long_noise': [[4.3, 6.3]]},
#  'vid_103.mp3': {'crowd_noise': [[1.8, 2.3]],
#   'long_noise': [[0.6, 4.6]],
#   'high_speed': [[0.0, 1.2]],
#   'crash': [[1.2, 4.1]],
#   'turn': [[0.2, 1.0]],
#   'drift': [[0.4, 1.2]]},
#  'vid_104.mp3': {'high_speed': [[0.3, 0.6]],
#   'drift': [[0.3, 0.8], [1.9, 2.8]],
#   'turn': [[0.3, 0.6], [1.4, 3.4], [4.0, 4.6], [6.2]],
#   'crowd_noise': [[1.1, 2.6], [4.9, 6.2]],
#   'crash': [[0.7, 1.4]]},
#  'vid_105.mp3': {'crowd_noise': [[1.3, 2.1]],
#   'long_noise': [[0.8, 1.7]],
#   'high_speed': [[0.0, 0.4]],
#   'turn': [[0.0, 1.0]],
#   'drift': [[0.2, 1.0]],
#   'crash': [[1.0, 1.4]]},
#  'vid_109.mp3': {'crowd_noise': [[5.3, 8.4]],
#   'long_noise': [[0.5, 1.0], [2.1, 2.8]],
#   'high_speed': [[0.0, 1.9]],
#   'turn': [[0.8, 2.9]],
#   'drift': [[2.9, 3.2]],
#   'crash': [[3.7, 4.2]]},
#  'vid_111.mp3': {'crowd_noise': [[4.2, 4.7]],
#   'long_noise': [[3.9, 5.9]],
#   'breakdown': [[4.8, 5.9]],
#   'crash': [[4.0, 5.2]],
#   'turn': [[0.0, 0.2], [0.9, 3.3]],
#   'drift': [[3.5, 3.9]]},
#  'vid_114.mp3': {'crowd_noise': [[2.8, 5.8]],
#   'drift': [[0.3, 0.8], [3.3, 5.8]],
#   'turn': [[0.3, 0.7], [3.5, 5.8]]},
#  'vid_115.mp3': {'long_noise': [[0.0, 1.6]],
#   'crowd_noise': [[1.0, 3.2]],
#   'crash': [[1.4, 2.3]]},
#  'vid_117.mp3': {'long_noise': [[1.6, 2.8]],
#   'crowd_noise': [[4.1, 5.8]],
#   'crash': [[3.2, 5.8]],
#   'turn': [[0.0, 1.0]]},
#  'vid_118.mp3': {'crowd_noise': [[4.7, 5.1]],
#   'breakdown': [[2.5, 5.1]],
#   'turn': [[0.0, 1.8]],
#   'drift': [[0.5, 3.5]],
#   'long_noise': [[0.3, 4.1]]},
#  'vid_121.mp3': {'crowd_noise': [[3.3, 3.9], [5.0, 5.7]],
#   'turn': [[0.2, 3.5]],
#   'crash': [[4.2, 4.8]]},
#  'vid_123.mp3': {'crowd_noise': [[4.4, 6.5]],
#   'crash': [[4.4, 6.5]],
#   'turn': [[2.1, 4.3]],
#   'long_noise': [[2.5, 4.1]]},
#  'vid_125.mp3': {'crash': [[2.0, 5.3]],
#   'breakdown': [[2.0, 5.3]],
#   'veichal_issue': [[2.0, 5.3]],
#   'long_noise': [[0.8, 5.3]],
#   'crowd_noise': [[1.3, 1.6]]},
#  'vid_127.mp3': {'crowd_noise': [[1.4, 2.8], [4.5, 5.5]],
#   'long_noise': [[1.5, 1.8]],
#   'crash': [[1.5, 4.8]],
#   'drift': [[0.8, 1.4]]},
#  'vid_130.mp3': {'high_speed': [[0.2, 0.6]],
#   'turn': [[0.2, 0.6]],
#   'crowd_noise': [[0.7, 0.8]],
#   'crash': [[1.1, 1.4], [1.9, 2.8]]},
#  'vid_131.mp3': {'crowd_noise': [[2.8, 3.5]],
#   'high_speed': [[0.0, 2.0]],
#   'jump': [[1.5, 2.0]],
#   'drift': [[2.2, 2.9]],
#   'turn': [[2.2, 3.0]]},
#  'vid_132.mp3': {'high_speed': [[0.0, 10.5]],
#   'turn': [[0.4, 1.6], [1.9, 3.5], [4.0, 5.3], [7.2, 9.1]],
#   'crowd_noise': [[11.2, 12.2]]},
#  'vid_133.mp3': {'long_noise': [[3.9, 6.1]],
#   'crowd_noise': [[4.6, 6.1]],
#   'turn': [[0.7, 1.9], [3.8, 5.1]],
#   'high_speed': [[2.0, 3.7]],
#   'drift': [[3.8, 5.0]],
#   'crash': [[5.0, 5.8]],
#   'breakdown': [[4.5, 5.8]]},
#  'vid_134.mp3': {'long_noise': [[3.4, 5.1]],
#   'crowd_noise': [[4.8, 5.5]],
#   'breakdown': [[4.0, 5.5]],
#   'turn': [[0.0, 1.4], [2.0, 4.6]],
#   'drift': [[2.6, 5.4]]},
#  'vid_137.mp3': {'crowd_noise': [[3.0, 5.3]],
#   'breakdown': [[1.5, 5.3]],
#   'long_noise': [[1.0, 2.6]],
#   'drift': [[0.9, 2.6]],
#   'turn': [[0.9, 1.8]],
#   'veichal_issue': [[4.8, 5.0]]},
#  'vid_138.mp3': {'crowd_noise': [[9.5, 10.0]],
#   'crash': [[8.7, 9.5]],
#   'turn': [[0.0, 1.3]],
#   'high_speed': [[2.0, 6.4]],
#   'jump': [[2.2, 2.6]],
#   'drift': [[7.0, 8.6]]},
#  'vid_141.mp3': {'long_noise': [[1.1, 5.9]],
#   'crash': [[1.1, 5.9]],
#   'veichal_issue': [[1.7, 5.9]],
#   'crowd_noise': [[4.0, 5.9]]},
#  'vid_142.mp3': {'crash': [[2.8, 4.5]],
#   'crowd_noise': [[3.3, 4.5]],
#   'long_noise': [[3.5, 3.6]]},
#  'vid_143.mp3': {'crowd_noise': [[2.5, 4.8]],
#   'long_noise': [[2.6, 4.2]],
#   'crash': [[2.7, 4.8]]},
#  'vid_144.mp3': {'long_noise': [[1.5, 6.0]],
#   'high_speed': [[1.6, 10.9]],
#   'drift': [[8.8, 10.1]],
#   'crowd_noise': [[8.8, 10.9]]},
#  'vid_146.mp3': {'drift': [[0.0, 1.3]],
#   'crash': [[1.3, 4.1]],
#   'crowd_noise': [[1.5, 4.1]]},
#  'vid_148.mp3': {'long_noise': [[0.1, 3.6]],
#   'jump': [[1.6, 2.0], [2.2, 2.6]],
#   'high_speed': [[1.6, 5.5]],
#   'crowd_noise': [[2.8, 4.4]]},
#  'vid_150.mp3': {'crowd_noise': [[2.8, 4.6]], 'crash': [[3.1, 4.6]]},
#  'vid_152.mp3': {'crowd_noise': [[6.2, 7.7]],
#   'crash': [[6.3, 7.7]],
#   'breakdown': [[6.2, 7.7]],
#   'long_noise': [[0.8, 1.6]],
#   'turn': [[2.4, 5.4]]},
#  'vid_153.mp3': {'long_noise': [[3.4, 5.8]],
#   'drift': [[3.6, 5.8]],
#   'crowd_noise': [[5.1, 6.5]],
#   'turn': [[3.1, 5.1]],
#   'crash': [[4.6, 6.5]]},
#  'vid_157.mp3': {'high_speed': [[0.0, 4.9]],
#   'crowd_noise': [[6.9, 7.8]],
#   'turn': [[2.2, 3.3], [4.5, 6.7]],
#   'drift': [[6.2, 6.7]],
#   'cut': [[2.3, 3.1]]},
#  'vid_160.mp3': {'long_noise': [[2.3, 4.0]],
#   'crowd_noise': [[2.8, 4.0]],
#   'breakdown': [[2.9, 4.0]]},
#  'vid_170.mp3': {'turn': [[2.5, 10.8]],
#   'drift': [[3.9, 7.0]],
#   'crowd_noise': [[5.7, 9.9]],
#   'high_speed': [[0.1, 6.6]]},
#  'vid_171.mp3': {'turn': [[0.7, 1.6], [2.1, 3.0]],
#   'long_noise': [[2.6, 2.8], [3.1, 12.0]],
#   'crash': [[3.0, 12.0]],
#   'jump': [[3.0, 6.5]],
#   'crowd_noise': [[8.4, 10.1], [11.6, 12.0]]},
#  'vid_172.mp3': {'high_speed': [[0.5, 3.9]],
#   'turn': [[0.5, 1.3], [2.5, 3.9]],
#   'drift': [[2.3, 3.9]],
#   'crowd_noise': [[3.9, 5.3]]},
#  'vid_173.mp3': {'high_speed': [[4.6, 6.1], [6.3, 6.9]],
#   'drift': [[5.7, 6.1], [6.3, 6.9]],
#   'crowd_noise': [[7.2, 8.9]]},
#  'vid_174.mp3': {'high_speed': [[0.0, 0.3], [0.5, 0.9], [1.4, 2.9]],
#   'jump': [[1.5, 2.9]],
#   'crowd_noise': [[3.3, 4.6]]},
#  'vid_175.mp3': {'high_speed': [[4.5, 5.0], [6.2, 6.3]],
#   'drift': [[4.5, 5.0], [6.2, 6.3]],
#   'crowd_noise': [[0.5, 2.0], [5.5, 8.0]]},
#  'vid_179.mp3': {'turn': [[2.1, 3.2]],
#   'high_speed': [[2.1, 4.9]],
#   'drift': [[2.4, 3.5]],
#   'crowd_noise': [[3.2, 5.9]]},
#  'vid_182.mp3': {'drift': [[0.2, 1.3], [2.0, 2.5]],
#   'turn': [[0.2, 1.4], [2.2, 2.5]],
#   'high_speed': [[0.2, 2.6]],
#   'crowd_noise': [[2.7, 4.1]]},
#  'vid_183.mp3': {'high_speed': [[4.3, 5.0], [5.1, 5.6]],
#   'drift': [[5.2, 5.6]],
#   'crowd_noise': [[6.2, 9.9]]},
#  'vid_184.mp3': {'high_speed': [[4.4, 6.2]],
#   'drift': [[4.5, 5.0], [5.3, 6.2]],
#   'crowd_noise': [[6.2, 8.7]]},
#  'vid_177.mp3': {'high_speed': [[1.2, 3.3]],
#   'drift': [[1.7, 3.3]],
#   'crowd_noise': [[2.9, 5.5]]},
#  'vid_178.mp3': {'high_speed': [[2.2, 4.2], [4.3, 5.3]],
#   'turn': [[2.2, 3.5]],
#   'drift': [[3.9, 4.2], [4.3, 5.3]],
#   'crowd_noise': [[4.9, 8.9]]},
#  'vid_180.mp3': {'high_speed': [[0.4, 5.1]],
#   'turn': [[2.2, 3.5]],
#   'drift': [[2.4, 3.5]],
#   'crowd_noise': [[3.2, 5.9]]},
#  'vid_181.mp3': {'high_speed': [[3.6, 5.3]],
#   'turn': [[3.7, 4.9]],
#   'drift': [[3.8, 4.7]],
#   'crowd_noise': [[3.8, 5.9]]},
#  'vid_196.mp3': {'high_speed': [[0.0, 4.8]],
#   'long_noise': [[4.9, 6.3]],
#   'crowd_noise': [[8.1, 10.8]]},
#  'vid_208.mp3': {'high_speed': [[7.8, 10.3]],
#   'turn': [[14.1, 14.9], [15.8, 17.1]],
#   'crowd_noise': [[0.6, 1.6]]},
#  'vid_237.mp3': {'drift': [[3.9, 4.3]],
#   'crash': [[5.5, 6.0]],
#   'breakdown': [[5.9, 8.9]],
#   'crowd_noise': [[4.9, 5.3], [6.2, 6.5], [10.8, 12.8]]},
#  'vid_240.mp3': {'drift': [[0.2, 0.6]],
#   'breakdown': [[0.5, 0.9]],
#   'long_noise': [[0.5, 2.4]],
#   'crowd_noise': [[1.3, 3.4]]},
#  'vid_198.mp3': {'crowd_noise': [[2.0, 5.7], [17.6, 18.2]],
#   'high_speed': [[7.0, 8.8]],
#   'long_noise': [[8.5, 10.0], [10.5, 10.9], [12.1, 12.4]],
#   'turn': [[13.7, 14.8], [16.6, 17.3]]},
#  'vid_472.mp3': {'high_speed': [[1.0, 7.0]],
#   'turn': [[3.4, 4.8], [6.8, 7.7], [8.8, 10.0]],
#   'jump': [[4.3, 4.6]],
#   'crowd_noise': [[8.2, 9.1]]},
#  'vid_475.mp3': {'crowd_noise': [[0.3, 1.6]],
#   'turn': [[2.7, 4.0], [8.1, 9.1]],
#   'drift': [[7.2, 9.1]]},
#  'vid_427.mp3': {'jump': [[1.1, 1.5]],
#   'drift': [[1.8, 3.0], [3.6, 5.9], [6.3, 7.6]],
#   'turn': [[2.5, 3.2], [6.7, 7.6]],
#   'long_noise': [[2.9, 4.1]],
#   'crowd_noise': [[9.1, 9.9]]},
#  'vid_433.mp3': {'jump': [[1.7, 2.0]],
#   'drift': [[2.4, 2.8], [3.0, 3.3], [4.0, 7.5]],
#   'long_noise': [[2.4, 4.7]],
#   'turn': [[2.9, 3.7], [7.1, 8.1]],
#   'crowd_noise': [[10.6, 11.2]]},
#  'vid_446.mp3': {'drift': [[1.3, 2.2], [4.9, 5.8]],
#   'high_speed': [[1.3, 2.5]],
#   'jump': [[1.7, 2.0]],
#   'crowd_noise': [[2.4, 3.5]],
#   'turn': [[5.4, 6.1], [7.2, 8.9]]},
#  'vid_458.mp3': {'drift': [[1.8, 2.7], [5.2, 6.8], [7.2, 7.7]],
#   'crowd_noise': [[0.0, 2.1]],
#   'turn': [[6.0, 6.9], [8.1, 9.8]]},
#  'vid_295.mp3': {'high_speed': [[2.0, 4.2]], 'crowd_noise': [[0.0, 0.1]]},
#  'vid_304.mp3': {'crowd_noise': [[0.1, 0.6]],
#   'drift': [[1.3, 2.3]],
#   'turn': [[2.1, 5.5]]},
#  'vid_317.mp3': {'turn': [[0.0, 1.1]], 'crowd_noise': [[0.9, 1.7]]},
#  'vid_320.mp3': {'turn': [[0.0, 0.1], [4.4, 6.9]],
#   'drift': [[0.3, 1.3]],
#   'crowd_noise': [[0.6, 2.3]]},
#  'vid_325.mp3': {'turn': [[2.3, 3.7], [6.6, 8.5]],
#   'cut': [[2.3, 3.1]],
#   'drift': [[2.8, 4.0]],
#   'crowd_noise': [[3.6, 4.2]]},
#  'vid_331.mp3': {'turn': [[2.1, 5.3]],
#   'drift': [[3.2, 4.8]],
#   'crowd_noise': [[7.1, 7.4]]},
#  'vid_344.mp3': {'crowd_noise': [[1.2, 2.7]]},
#  'vid_351.mp3': {'high_speed': [[0.5, 3.4]], 'crowd_noise': [[0.4, 0.8]]},
#  'vid_352.mp3': {'high_speed': [[0.8, 1.4], [1.6, 3.4]],
#   'crowd_noise': [[0.0, 0.2]]},
#  'vid_372.mp3': {'high_speed': [[6.4, 9.5]], 'crowd_noise': [[3.2, 4.8]]},
#  'vid_374.mp3': {'crowd_noise': [[0.0, 0.8]]},
#  'vid_375.mp3': {'high_speed': [[0.4, 3.7], [3.9, 6.2]],
#   'crowd_noise': [[0.3, 0.7]],
#   'turn': [[1.7, 2.7]]},
#  'vid_393.mp3': {'crowd_noise': [[2.4, 4.4]], 'turn': [[3.4, 4.7]]},
#  'vid_394.mp3': {'veichal_issue': [[0.0, 7.0]],
#   'breakdown': [[0.0, 7.0]],
#   'long_noise': [[2.0, 5.5]],
#   'crowd_noise': [[5.3, 5.9]]},
#  'vid_496.mp3': {'high_speed': [[0.8, 3.3]],
#   'jump': [[1.1, 1.6]],
#   'crowd_noise': [[0.4, 1.4]],
#   'turn': [[4.8, 5.6], [6.5, 8.5]]},
#  'vid_500.mp3': {'high_speed': [[1.2, 3.8]],
#   'crowd_noise': [[0.7, 2.5]],
#   'turn': [[5.9, 6.6], [7.6, 8.5]]},
#  'vid_506.mp3': {'high_speed': [[1.2, 4.0]],
#   'crowd_noise': [[1.2, 3.3]],
#   'turn': [[5.9, 6.8], [8.3, 10.5]]},
#  'vid_511.mp3': {'crowd_noise': [[0.0, 1.8], [3.0, 3.6], [11.0, 12.2]],
#   'turn': [[6.7, 7.7], [9.0, 10.0], [15.1, 16.0], [17.0, 19.3]],
#   'high_speed': [[11.3, 14.1]]},
#  'vid_515.mp3': {'crowd_noise': [[0.7, 1.8]],
#   'turn': [[2.0, 2.2], [2.8, 4.2], [7.8, 9.1]],
#   'long_noise': [[3.2, 4.8]],
#   'drift': [[5.2, 6.0]]},
#  'vid_516.mp3': {'crowd_noise': [[0.0, 4.2]],
#   'turn': [[5.8, 6.8], [8.0, 9.2]],
#   'drift': [[6.5, 8.0]]},
#  'vid_524.mp3': {'high_speed': [[0.8, 3.6], [3.8, 4.2]],
#   'crowd_noise': [[0.9, 2.2]],
#   'turn': [[5.0, 5.7], [6.7, 8.4]]},
#  'vid_527.mp3': {'crowd_noise': [[1.6, 3.9]],
#   'turn': [[5.4, 6.6], [7.2, 9.0]]},
#  'vid_533.mp3': {'high_speed': [[1.2, 5.0]],
#   'crowd_noise': [[0.0, 3.4]],
#   'turn': [[5.4, 6.3], [7.7, 9.3]]},
#  'vid_536.mp3': {'drift': [[2.2, 3.0], [5.1, 5.8], [8.7, 9.6]],
#   'crash': [[3.0, 3.4]],
#   'turn': [[3.1, 3.6], [8.9, 10.0]],
#   'crowd_noise': [[4.1, 5.8]],
#   'long_noise': [[5.9, 6.3]]},
#  'vid_541.mp3': {'veichal_issue': [[1.0, 3.7]],
#   'crowd_noise': [[0.8, 3.6]],
#   'turn': [[5.2, 6.7], [7.5, 9.3]]},
#  'vid_543.mp3': {'turn': [[3.2, 4.1], [7.8, 9.0]],
#   'crowd_noise': [[7.2, 8.4]]},
#  'vid_546.mp3': {'crowd_noise': [[0.0, 3.3]],
#   'turn': [[5.1, 6.0], [7.2, 9.0]]},
#  'vid_389.mp3': {'turn': [[2.3, 4.3]], 'crowd_noise': [[4.9, 6.0]]},
#  'vid_531.mp3': {'high_speed': [[1.4, 4.7]],
#   'crowd_noise': [[0.0, 3.9]],
#   'turn': [[5.4, 5.8], [7.1, 8.6]]}}

# %%
with open(TIMESTAMP_ANNOTATIONS, 'w') as output_file:
    json.dump(processed_data, output_file)
